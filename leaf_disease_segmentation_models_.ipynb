# %% [markdown]
# Abstract— 	Smart agriculture leverages advanced technologies such as the Internet of Things (IoT), deep learning, and computer vision to address challenges in pest and disease detection.Semantic image segmentation has emerged as a vital tool for monitoring plant health, enabling the detection of subtle anomalies and patterns through visual data analysis. Deep encoder-decoder architectures, such as U-Net, have shown significant potential in this domain. However, challenges in the encoding phase, including the loss of low-level features, incomplete texture analysis, and weak edge detection, often limit segmentation accuracy.To overcome these limitations, this study introduces an enhanced U-Net model that integrates ResNet-50 as the encoder and incorporates a channel-spatial attention block in the decoding phase.This attention block first compresses channel features and subsequently amplifies spatial features across different regions, improving the preservation and recovery of low-level features.This enhancement enables more precise and distinguishable segmentation of diseased regions in plant leaves. Experimental results highlight the effectiveness of the proposed approach, achieving an Intersection over Union (IoU) of 93.35% and a Dice coefficient of 0.9645% in plant disease segmentation tasks.These advancements demonstrate significant potential for real-world applications, facilitating accurate disease detection and efficient crop management in smart agriculture.
#
# Keywords— Convolutional Neural Networks, Edge Detection, Feature Representation, Low-Level Features, Plant Leaf Segmentation

# %% [markdown]
# *Note: This section has already been completed, and the dataset has been prepared. It serves only as a guide to how the dataset was built, so you can proceed directly to Section 2 and skip Section 1.*

# %% [markdown]
# # **My Model Predictions**

# %% [markdown]
# ![download (5).png](data:image/png;base64,...)

# %% [markdown]
# ![download (3).png](data:image/png;base64,...)

# %% [markdown]
# # **A comparison between all implemented models**

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Base on the picture the performance of various models, including the proposed approach, was evaluated on three samples of disease-affected plant leaves. In the figure, the segmented regions are highlighted with boxes. The results demonstrate that the proposed method, leveraging edge detection, effectively enhances the separation between affected and healthy areas. This improvement is particularly evident in complex images, indicating that the model performs well in identifying and segmenting disease-affected regions.

# %% [markdown]
# #Section1:Data loading and creating

# %%
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 501M/503M [00:21<00:00, 18.4MB/s]
# 100% 503M/503M [00:21<00:00, 24.5MB/s]

# %%
# !unzip "/content/leaf-disease-segmentation-dataset.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: aug_data/aug_data/images/00411_1.jpg
#   inflating: aug_data/aug_data/images/00411_2.jpg
#   inflating: aug_data/aug_data/images/00411_3.jpg
#   inflating: aug_data/aug_data/images/00411_4.jpg
#   inflating: aug_data/aug_data/images/00412_0.jpg
#   inflating: aug_data/aug_data/images/00412_1.jpg
#   inflating: aug_data/aug_data/images/00412_2.jpg
#   inflating: aug_data/aug_data/images/00412_3.jpg
#   inflating: aug_data/aug_data/images/00412_4.jpg
#   inflating: aug_data/aug_data/images/00413_0.jpg
#   inflating: aug_data/aug_data/images/00413_1.jpg
#   inflating: aug_data/aug_data/images/00413_2.jpg
#   inflating: aug_data/aug_data/images/00413_3.jpg
#   inflating: aug_data/aug_data/images/00413_4.jpg
#   inflating: aug_data/aug_data/images/00414_0.jpg
#   inflating: aug_data/aug_data/images/00414_1.jpg
#   inflating: aug_data/aug_data/images/00414_2.jpg
#   inflating: aug_data/aug_data/images/00414_3.jpg
#   inflating: aug_data/aug_data/images/00414_4.jpg
#   inflating: aug_data/aug_data/images/00415_0.jpg
#   inflating: aug_data/aug_data/images/00415_1.jpg
#   inflating: aug_data/aug_data/images/00415_2.jpg
#   inflating: aug_data/aug_data/images/00415_3.jpg
#   inflating: aug_data/aug_data/images/00415_4.jpg
#   inflating: aug_data/aug_data/images/00416_0.jpg
#   inflating: aug_data/aug_data/images/00416_1.jpg
#   inflating: aug_data/aug_data/images/00416_2.jpg
#   inflating: aug_data/aug_data/images/00416_3.jpg
#   inflating: aug_data/aug_data/images/00416_4.jpg
#   inflating: aug_data/aug_data/images/00417_0.jpg
#   inflating: aug_data/aug_data/images/00417_1.jpg
#   inflating: aug_data/aug_data/images/00417_2.jpg
#   inflating: aug_data/aug_data/images/00417_3.jpg
#   inflating: aug_data/aug_data/images/00417_4.jpg
#   inflating: aug_data/aug_data/images/00418_0.jpg
#   inflating: aug_data/aug_data/images/00418_1.jpg
#   inflating: aug_data/aug_data/images/00418_2.jpg
#   inflating: aug_data/aug_data/images/00418_3.jpg
#   inflating: aug_data/aug_data/images/00418_4.jpg
#   inflating: aug_data/aug_data/images/00419_0.jpg
#   inflating: aug_data/aug_data/images/00419_1.jpg
#   inflating: aug_data/aug_data/images/00419_2.jpg
#   inflating: aug_data/aug_data/images/00419_3.jpg
#   inflating: aug_data/aug_data/images/00419_4.jpg
#   inflating: aug_data/aug_data/images/00420_0.jpg
#   inflating: aug_data/aug_data/images/00420_1.jpg
#   inflating: aug_data/aug_data/images/00420_2.jpg
#   inflating: aug_data/aug_data/images/00420_3.jpg
#   inflating: aug_data/aug_data/images/00420_4.jpg
#   inflating: aug_data/aug_data/images/00421_0.jpg
#   inflating: aug_data/aug_data/images/00421_1.jpg
#   inflating: aug_data/aug_data/images/00421_2.jpg
#   inflating: aug_data/aug_data/images/00421_3.jpg
#   inflating: aug_data/aug_data/images/00421_4.jpg
#   inflating: aug_data/aug_data/images/00422_0.jpg
#   inflating: aug_data/aug_data/images/00422_1.jpg
#   inflating: aug_data/aug_data/images/00422_2.jpg
#   inflating: aug_data/aug_data/images/00422_3.jpg
#   inflating: aug_data/aug_data/images/00422_4.jpg
#   inflating: aug_data/aug_data/images/00423_0.jpg
#   inflating: aug_data/aug_data/images/00423_1.jpg
#   inflating: aug_data/aug_data/images/00423_2.jpg
#   inflating: aug_data/aug_data/images/00423_3.jpg
#   inflating: aug_data/aug_data/images/00423_4.jpg
#   inflating: aug_data/aug_data/images/00424_0.jpg
#   inflating: aug_data/aug_data/images/00424_1.jpg
#   inflating: aug_data/aug_data/images/00424_2.jpg
#   inflating: aug_data/aug_data/images/00424_3.jpg
#   inflating: aug_data/aug_data/images/00424_4.jpg
#   inflating: aug_data/aug_data/images/00425_0.jpg
#   inflating: aug_data/aug_data/images/00425_1.jpg
#   inflating: aug_data/aug_data/images/00425_2.jpg
#   inflating: aug_data/aug_data/images/00425_3.jpg
#   inflating: aug_data/aug_data/images/00425_4.jpg
#   inflating: aug_data/aug_data/images/00426_0.jpg
#   inflating: aug_data/aug_data/images/00426_1.jpg
#   inflating: aug_data/aug_data/images/00426_2.jpg
#   inflating: aug_data/aug_data/images/00426_3.jpg
#   inflating: aug_data/aug_data/images/00426_4.jpg
#   inflating: aug_data/aug_data/images/00427_0.jpg
#   inflating: aug_data/aug_data/images/00427_1.jpg
#   inflating: aug_data/aug_data/images/00427_2.jpg
#   inflating: aug_data/aug_data/images/00427_3.jpg
#   inflating: aug_data/aug_data/images/00427_4.jpg
#   inflating: aug_data/aug_data/images/00428_0.jpg
#   inflating: aug_data/aug_data/images/00428_1.jpg
#   inflating: aug_data/aug_data/images/00428_2.jpg
#   inflating: aug_data/aug_data/images/00428_3.jpg
#   inflating: aug_data/aug_data/images/00428_4.jpg
#   inflating: aug_data/aug_data/images/00429_0.jpg
#   inflating: aug_data/aug_data/images/00429_1.jpg
#   inflating: aug_data/aug_data/images/00429_2.jpg
#   inflating: aug_data/aug_data/images/00429_3.jpg
#   inflating: aug_data/aug_data/images/00429_4.jpg
#   inflating: aug_data/aug_data/images/00430_0.jpg
#   inflating: aug_data/aug_data/images/00430_1.jpg
#   inflating: aug_data/aug_data/images/00430_2.jpg
#   inflating: aug_data/aug_data/images/00430_3.jpg
#   inflating: aug_data/aug_data/images/00430_4.jpg
#   inflating: aug_data/aug_data/images/00431_0.jpg
#   inflating: aug_data/aug_data/images/00431_1.jpg
#   inflating: aug_data/aug_data/images/00431_2.jpg
#   inflating: aug_data/aug_data/images/00431_3.jpg
#   inflating: aug_data/aug_data/images/00431_4.jpg
#   inflating: aug_data/aug_data/images/00432_0.jpg
#   inflating: aug_data/aug_data/images/00432_1.jpg
#   inflating: aug_data/aug_data/images/00432_2.jpg
#   inflating: aug_data/aug_data/images/00432_3.jpg
#   inflating: aug_data/aug_data/images/00432_4.jpg
#   inflating: aug_data/aug_data/images/00433_0.jpg
#   inflating: aug_data/aug_data/images/00433_1.jpg
#   inflating: aug_data/aug_data/images/00433_2.jpg
#   inflating: aug_data/aug_data/images/00433_3.jpg
#   inflating: aug_data/aug_data/images/00433_4.jpg
#   inflating: aug_data/aug_data/images/00434_0.jpg
#   inflating: aug_data/aug_data/images/00434_1.jpg
#   inflating: aug_data/aug_data/images/00434_2.jpg
#   inflating: aug_data/aug_data/images/00434_3.jpg
#   inflating: aug_data/aug_data/images/00434_4.jpg
#   inflating: aug_data/aug_data/images/00435_0.jpg
#   inflating: aug_data/aug_data/images/00435_1.jpg
#   inflating: aug_data/aug_data/images/00435_2.jpg
#   inflating: aug_data/aug_data/images/00435_3.jpg
#   inflating: aug_data/aug_data/images/00435_4.jpg
#   inflating: aug_data/aug_data/images/00436_0.jpg
#   inflating: aug_data/aug_data/images/00436_1.jpg
#   inflating: aug_data/aug_data/images/00436_2.jpg
#   inflating: aug_data/aug_data/images/00436_3.jpg
#   inflating: aug_data/aug_data/images/00436_4.jpg
#   inflating: aug_data/aug_data/images/00437_0.jpg
#   inflating: aug_data/aug_data/images/00437_1.jpg
#   inflating: aug_data/aug_data/images/00437_2.jpg
#   inflating: aug_data/aug_data/images/00437_3.jpg
#   inflating: aug_data/aug_data/images/00437_4.jpg
#   inflating: aug_data/aug_data/images/00438_0.jpg
#   inflating: aug_data/aug_data/images/00438_1.jpg
#   inflating: aug_data/aug_data/images/00438_2.jpg
#   inflating: aug_data/aug_data/images/00438_3.jpg
#   inflating: aug_data/aug_data/images/00438_4.jpg
#   inflating: aug_data/aug_data/images/00439_0.jpg
#   inflating: aug_data/aug_data/images/00439_1.jpg
#   inflating: aug_data/aug_data/images/00439_2.jpg
#   inflating: aug_data/aug_data/images/00439_3.jpg
#   inflating: aug_data/aug_data/images/00439_4.jpg
#   inflating: aug_data/aug_data/images/00440_0.jpg
#   inflating: aug_data/aug_data/images/00440_1.jpg
#   inflating: aug_data/aug_data/images/00440_2.jpg
#   inflating: aug_data/aug_data/images/00440_3.jpg
#   inflating: aug_data/aug_data/images/00440_4.jpg
#   inflating: aug_data/aug_data/images/00441_0.jpg
#   inflating: aug_data/aug_data/images/00441_1.jpg
#   inflating: aug_data/aug_data/images/00441_2.jpg
#   inflating: aug_data/aug_data/images/00441_3.jpg
#   inflating: aug_data/aug_data/images/00441_4.jpg
#   inflating: aug_data/aug_data/images/00442_0.jpg
#   inflating: aug_data/aug_data/images/00442_1.jpg
#   inflating: aug_data/aug_data/images/00442_2.jpg
#   inflating: aug_data/aug_data/images/00442_3.jpg
#   inflating: aug_data/aug_data/images/00442_4.jpg
#   inflating: aug_data/aug_data/images/00443_0.jpg
#   inflating: aug_data/aug_data/images/00443_1.jpg
#   inflating: aug_data/aug_data/images/00443_2.jpg
#   inflating: aug_data/aug_data/images/00443_3.jpg
#   inflating: aug_data/aug_data/images/00443_4.jpg
#   inflating: aug_data/aug_data/images/00444_0.jpg
#   inflating: aug_data/aug_data/images/00444_1.jpg
#   inflating: aug_data/aug_data/images/00444_2.jpg
#   inflating: aug_data/aug_data/images/00444_3.jpg
#   inflating: aug_data/aug_data/images/00444_4.jpg
#   inflating: aug_data/aug_data/images/00445_0.jpg
#   inflating: aug_data/aug_data/images/00445_1.jpg
#   inflating: aug_data/aug_data/images/00445_2.jpg
#   inflating: aug_data/aug_data/images/00445_3.jpg
#   inflating: aug_data/aug_data/images/00445_4.jpg
#   inflating: aug_data/aug_data/images/00446_0.jpg
#   inflating: aug_data/aug_data/images/00446_1.jpg
#   inflating: aug_data/aug_data/images/00446_2.jpg
#   inflating: aug_data/aug_data/images/00446_3.jpg
#   inflating: aug_data/aug_data/images/00446_4.jpg
#   inflating: aug_data/aug_data/images/00447_0.jpg
#   inflating: aug_data/aug_data/images/00447_1.jpg
#   inflating: aug_data/aug_data/images/00447_2.jpg
#   inflating: aug_data/aug_data/images/00447_3.jpg
#   inflating: aug_data/aug_data/images/00447_4.jpg
#   inflating: aug_data/aug_data/images/00448_0.jpg
#   inflating: aug_data/aug_data/images/00448_1.jpg
#   inflating: aug_data/aug_data/images/00448_2.jpg
#   inflating: aug_data/aug_data/images/00448_3.jpg
#   inflating: aug_data/aug_data/images/00448_4.jpg
#   inflating: aug_data/aug_data/images/00449_0.jpg
#   inflating: aug_data/aug_data/images/00449_1.jpg
#   inflating: aug_data/aug_data/images/00449_2.jpg
#   inflating: aug_data/aug_data/images/00449_3.jpg
#   inflating: aug_data/aug_data/images/00449_4.jpg
#   inflating: aug_data/aug_data/images/00450_0.jpg
#   inflating: aug_data/aug_data/images/00450_1.jpg
#   inflating: aug_data/aug_data/images/00450_2.jpg
#   inflating: aug_data/aug_data/images/00450_3.jpg
#   inflating: aug_data/aug_data/images/00450_4.jpg
#   inflating: aug_data/aug_data/images/00451_0.jpg
#   inflating: aug_data/aug_data/images/00451_1.jpg
#   inflating: aug_data/aug_data/images/00451_2.jpg
#   inflating: aug_data/aug_data/images/00451_3.jpg
#   inflating: aug_data/aug_data/images/00451_4.jpg
#   inflating: aug_data/aug_data/images/00452_0.jpg
#   inflating: aug_data/aug_data/images/00452_1.jpg
#   inflating: aug_data/aug_data/images/00452_2.jpg
#   inflating: aug_data/aug_data/images/00452_3.jpg
#   inflating: aug_data/aug_data/images/00452_4.jpg
#   inflating: aug_data/aug_data/images/00453_0.jpg
#   inflating: aug_data/aug_data/images/00453_1.jpg
#   inflating: aug_data/aug_data/images/00453_2.jpg
#   inflating: aug_data/aug_data/images/00453_3.jpg
#   inflating: aug_data/aug_data/images/00453_4.jpg
#   inflating: aug_data/aug_data/images/00454_0.jpg
#   inflating: aug_data/aug_data/images/00454_1.jpg
#   inflating: aug_data/aug_data/images/00454_2.jpg
#   inflating: aug_data/aug_data/images/00454_3.jpg
#   inflating: aug_data/aug_data/images/00454_4.jpg
#   inflating: aug_data/aug_data/images/00455_0.jpg
#   inflating: aug_data/aug_data/images/00455_1.jpg
#   inflating: aug_data/aug_data/images/00455_2.jpg
#   inflating: aug_data/aug_data/images/00455_3.jpg
#   inflating: aug_data/aug_data/images/00455_4.jpg
#   inflating: aug_data/aug_data/images/00456_0.jpg
#   inflating: aug_data/aug_data/images/00456_1.jpg
#   inflating: aug_data/aug_data/images/00456_2.jpg
#   inflating: aug_data/aug_data/images/00456_3.jpg
#   inflating: aug_data/aug_data/images/00456_4.jpg
#   inflating: aug_data/aug_data/images/00457_0.jpg
#   inflating: aug_data/aug_data/images/00457_1.jpg
#   inflating: aug_data/aug_data/images/00457_2.jpg
#   inflating: aug_data/aug_data/images/00457_3.jpg
#   inflating: aug_data/aug_data/images/00457_4.jpg
#   inflating: aug_data/aug_data/images/00458_0.jpg
#   inflating: aug_data/aug_data/images/00458_1.jpg
#   inflating: aug_data/aug_data/images/00458_2.jpg
#   inflating: aug_data/aug_data/images/00458_3.jpg
#   inflating: aug_data/aug_data/images/00458_4.jpg
#   inflating: aug_data/aug_data/images/00459_0.jpg
#   inflating: aug_data/aug_data/images/00459_1.jpg
#   inflating: aug_data/aug_data/images/00459_2.jpg
#   inflating: aug_data/aug_data/images/00459_3.jpg
#   inflating: aug_data/aug_data/images/00459_4.jpg
#   inflating: aug_data/aug_data/images/00460_0.jpg
#   inflating: aug_data/aug_data/images/00460_1.jpg
#   inflating: aug_data/aug_data/images/00460_2.jpg
#   inflating: aug_data/aug_data/images/00460_3.jpg
#   inflating: aug_data/aug_data/images/00460_4.jpg
#   inflating: aug_data/aug_data/images/00461_0.jpg
#   inflating: aug_data/aug_data/images/00461_1.jpg
#   inflating: aug_data/aug_data/images/00461_2.jpg
#   inflating: aug_data/aug_data/images/00461_3.jpg
#   inflating: aug_data/aug_data/images/00461_4.jpg
#   inflating: aug_data/aug_data/images/00462_0.jpg
#   inflating: aug_data/aug_data/images/00462_1.jpg
#   inflating: aug_data/aug_data/images/00462_2.jpg
#   inflating: aug_data/aug_data/images/00462_3.jpg
#   inflating: aug_data/aug_data/images/00462_4.jpg
#   inflating: aug_data/aug_data/images/00463_0.jpg
#   inflating: aug_data/aug_data/images/00463_1.jpg
#   inflating: aug_data/aug_data/images/00463_2.jpg
#   inflating: aug_data/aug_data/images/00463_3.jpg
#   inflating: aug_data/aug_data/images/00463_4.jpg
#   inflating: aug_data/aug_data/images/00464_0.jpg
#   inflating: aug_data/aug_data/images/00464_1.jpg
#   inflating: aug_data/aug_data/images/00464_2.jpg
#   inflating: aug_data/aug_data/images/00464_3.jpg
#   inflating: aug_data/aug_data/images/00464_4.jpg
#   inflating: aug_data/aug_data/images/00465_0.jpg
#   inflating: aug_data/aug_data/images/00465_1.jpg
#   inflating: aug_data/aug_data/images/00465_2.jpg
#   inflating: aug_data/aug_data/images/00465_3.jpg
#   inflating: aug_data/aug_data/images/00465_4.jpg
#   inflating: aug_data/aug_data/images/00466_0.jpg
#   inflating: aug_data/aug_data/images/00466_1.jpg
#   inflating: aug_data/aug_data/images/00466_2.jpg
#   inflating: aug_data/aug_data/images/00466_3.jpg
#   inflating: aug_data/aug_data/images/00466_4.jpg
#   inflating: aug_data/aug_data/images/00467_0.jpg
#   inflating: aug_data/aug_data/images/00467_1.jpg
#   inflating: aug_data/aug_data/images/00467_2.jpg
#   inflating: aug_data/aug_data/images/00467_3.jpg
#   inflating: aug_data/aug_data/images/00467_4.jpg
#   inflating: aug_data/aug_data/images/00468_0.jpg
#   inflating: aug_data/aug_data/images/00468_1.jpg
#   inflating: aug_data/aug_data/images/00468_2.jpg
#   inflating: aug_data/aug_data/images/00468_3.jpg
#   inflating: aug_data/aug_data/images/00468_4.jpg
#   inflating: aug_data/aug_data/images/00469_0.jpg
#   inflating: aug_data/aug_data/images/00469_1.jpg
#   inflating: aug_data/aug_data/images/00469_2.jpg
#   inflating: aug_data/aug_data/images/00469_3.jpg
#   inflating: aug_data/aug_data/images/00469_4.jpg
#   inflating: aug_data/aug_data/images/00470_0.jpg
#   inflating: aug_data/aug_data/images/00470_1.jpg
#   inflating: aug_data/aug_data/images/00470_2.jpg
#   inflating: aug_data/aug_data/images/00470_3.jpg
#   inflating: aug_data/aug_data/images/00470_4.jpg
#   inflating: aug_data/aug_data/images/00471_0.jpg
#   inflating: aug_data/aug_data/images/00471_1.jpg
#   inflating: aug_data/aug_data/images/00471_2.jpg
#   inflating: aug_data/aug_data/images/00471_3.jpg
#   inflating: aug_data/aug_data/images/00471_4.jpg
#   inflating: aug_data/aug_data/images/00472_0.jpg
#   inflating: aug_data/aug_data/images/00472_1.jpg
#   inflating: aug_data/aug_data/images/00472_2.jpg
#   inflating: aug_data/aug_data/images/00472_3.jpg
#   inflating: aug_data/aug_data/images/00472_4.jpg
#   inflating: aug_data/aug_data/images/00473_0.jpg
#   inflating: aug_data/aug_data/images/00473_1.jpg
#   inflating: aug_data/aug_data/images/00473_2.jpg
#   inflating: aug_data/aug_data/images/00473_3.jpg
#   inflating: aug_data/aug_data/images/00473_4.jpg
#   inflating: aug_data/aug_data/images/00474_0.jpg
#   inflating: aug_data/aug_data/images/00474_1.jpg
#   inflating: aug_data/aug_data/images/00474_2.jpg
#   inflating: aug_data/aug_data/images/00474_3.jpg
#   inflating: aug_data/aug_data/images/00474_4.jpg
#   inflating: aug_data/aug_data/images/00475_0.jpg
#   inflating: aug_data/aug_data/images/00475_1.jpg
#   inflating: aug_data/aug_data/images/00475_2.jpg
#   inflating: aug_data/aug_data/images/00475_3.jpg
#   inflating: aug_data/aug_data/images/00475_4.jpg
#   inflating: aug_data/aug_data/images/00476_0.jpg
#   inflating: aug_data/aug_data/images/00476_1.jpg
#   inflating: aug_data/aug_data/images/00476_2.jpg
#   inflating: aug_data/aug_data/images/00476_3.jpg
#   inflating: aug_data/aug_data/images/00476_4.jpg
#   inflating: aug_data/aug_data/images/00477_0.jpg
#   inflating: aug_data/aug_data/images/00477_1.jpg
#   inflating: aug_data/aug_data/images/00477_2.jpg
#   inflating: aug_data/aug_data/images/00477_3.jpg
#   inflating: aug_data/aug_data/images/00477_4.jpg
#   inflating: aug_data/aug_data/images/00478_0.jpg
#   inflating: aug_data/aug_data/images/00478_1.jpg
#   inflating: aug_data/aug_data/images/00478_2.jpg
#   inflating: aug_data/aug_data/images/00478_3.jpg
#   inflating: aug_data/aug_data/images/00478_4.jpg
#   inflating: aug_data/aug_data/images/00479_0.jpg
#   inflating: aug_data/aug_data/images/00479_1.jpg
#   inflating: aug_data/aug_data/images/00479_2.jpg
#   inflating: aug_data/aug_data/images/00479_3.jpg
#   inflating: aug_data/aug_data/images/00479_4.jpg
#   inflating: aug_data/aug_data/images/00480_0.jpg
#   inflating: aug_data/aug_data/images/00480_1.jpg
#   inflating: aug_data/aug_data/images/00480_2.jpg
#   inflating: aug_data/aug_data/images/00480_3.jpg
#   inflating: aug_data/aug_data/images/00480_4.jpg
#   inflating: aug_data/aug_data/images/00481_0.jpg
#   inflating: aug_data/aug_data/images/00481_1.jpg
#   inflating: aug_data/aug_data/images/00481_2.jpg
#   inflating: aug_data/aug_data/images/00481_3.jpg
#   inflating: aug_data/aug_data/images/00481_4.jpg
#   inflating: aug_data/aug_data/images/00482_0.jpg
#   inflating: aug_data/aug_data/images/00482_1.jpg
#   inflating: aug_data/aug_data/images/00482_2.jpg
#   inflating: aug_data/aug_data/images/00482_3.jpg
#   inflating: aug_data/aug_data/images/00482_4.jpg
#   inflating: aug_data/aug_data/images/00483_0.jpg
#   inflating: aug_data/aug_data/images/00483_1.jpg
#   inflating: aug_data/aug_data/images/00483_2.jpg
#   inflating: aug_data/aug_data/images/00483_3.jpg
#   inflating: aug_data/aug_data/images/00483_4.jpg
#   inflating: aug_data/aug_data/images/00484_0.jpg
#   inflating: aug_data/aug_data/images/00484_1.jpg
#   inflating: aug_data/aug_data/images/00484_2.jpg
#   inflating: aug_data/aug_data/images/00484_3.jpg
#   inflating: aug_data/aug_data/images/00484_4.jpg
#   inflating: aug_data/aug_data/images/00485_0.jpg
#   inflating: aug_data/aug_data/images/00485_1.jpg
#   inflating: aug_data/aug_data/images/00485_2.jpg
#   inflating: aug_data/aug_data/images/00485_3.jpg
#   inflating: aug_data/aug_data/images/00485_4.jpg
#   inflating: aug_data/aug_data/images/00486_0.jpg
#   inflating: aug_data/aug_data/images/00486_1.jpg
#   inflating: aug_data/aug_data/images/00486_2.jpg
#   inflating: aug_data/aug_data/images/00486_3.jpg
#   inflating: aug_data/aug_data/images/00486_4.jpg
#   inflating: aug_data/aug_data/images/00487_0.jpg
#   inflating: aug_data/aug_data/images/00487_1.jpg
#   inflating: aug_data/aug_data/images/00487_2.jpg
#   inflating: aug_data/aug_data/images/00487_3.jpg
#   inflating: aug_data/aug_data/images/00487_4.jpg
#   inflating: aug_data/aug_data/images/00488_0.jpg
#   inflating: aug_data/aug_data/images/00488_1.jpg
#   inflating: aug_data/aug_data/images/00488_2.jpg
#   inflating: aug_data/aug_data/images/00488_3.jpg
#   inflating: aug_data/aug_data/images/00488_4.jpg
#   inflating: aug_data/aug_data/images/00489_0.jpg
#   inflating: aug_data/aug_data/images/00489_1.jpg
#   inflating: aug_data/aug_data/images/00489_2.jpg
#   inflating: aug_data/aug_data/images/00489_3.jpg
#   inflating: aug_data/aug_data/images/00489_4.jpg
#   inflating: aug_data/aug_data/images/00490_0.jpg
#   inflating: aug_data/aug_data/images/00490_1.jpg
#   inflating: aug_data/aug_data/images/00490_2.jpg
#   inflating: aug_data/aug_data/images/00490_3.jpg
#   inflating: aug_data/aug_data/images/00490_4.jpg
#   inflating: aug_data/aug_data/images/00491_0.jpg
#   inflating: aug_data/aug_data/images/00491_1.jpg
#   inflating: aug_data/aug_data/images/00491_2.jpg
#   inflating: aug_data/aug_data/images/00491_3.jpg
#   inflating: aug_data/aug_data/images/00491_4.jpg
#   inflating: aug_data/aug_data/images/00492_0.jpg
#   inflating: aug_data/aug_data/images/00492_1.jpg
#   inflating: aug_data/aug_data/images/00492_2.jpg
#   inflating: aug_data/aug_data/images/00492_3.jpg
#   inflating: aug_data/aug_data/images/00492_4.jpg
#   inflating: aug_data/aug_data/images/00493_0.jpg
#   inflating: aug_data/aug_data/images/00493_1.jpg
#   inflating: aug_data/aug_data/images/00493_2.jpg
#   inflating: aug_data/aug_data/images/00493_3.jpg
#   inflating: aug_data/aug_data/images/00493_4.jpg
#   inflating: aug_data/aug_data/images/00494_0.jpg
#   inflating: aug_data/aug_data/images/00494_1.jpg
#   inflating: aug_data/aug_data/images/00494_2.jpg
#   inflating: aug_data/aug_data/images/00494_3.jpg
#   inflating: aug_data/aug_data/images/00494_4.jpg
#   inflating: aug_data/aug_data/images/00495_0.jpg
#   inflating: aug_data/aug_data/images/00495_1.jpg
#   inflating: aug_data/aug_data/images/00495_2.jpg
#   inflating: aug_data/aug_data/images/00495_3.jpg
#   inflating: aug_data/aug_data/images/00495_4.jpg
#   inflating: aug_data/aug_data/images/00496_0.jpg
#   inflating: aug_data/aug_data/images/00496_1.jpg
#   inflating: aug_data/aug_data/images/00496_2.jpg
#   inflating: aug_data/aug_data/images/00496_3.jpg
#   inflating: aug_data/aug_data/images/00496_4.jpg
#   inflating: aug_data/aug_data/images/00497_0.jpg
#   inflating: aug_data/aug_data/images/00497_1.jpg
#   inflating: aug_data/aug_data/images/00497_2.jpg
#   inflating: aug_data/aug_data/images/00497_3.jpg
#   inflating: aug_data/aug_data/images/00497_4.jpg
#   inflating: aug_data/aug_data/images/00498_0.jpg
#   inflating: aug_data/aug_data/images/00498_1.jpg
#   inflating: aug_data/aug_data/images/00498_2.jpg
#   inflating: aug_data/aug_data/images/00498_3.jpg
#   inflating: aug_data/aug_data/images/00498_4.jpg
#   inflating: aug_data/aug_data/images/00499_0.jpg
#   inflating: aug_data/aug_data/images/00499_1.jpg
#   inflating: aug_data/aug_data/images/00499_2.jpg
#   inflating: aug_data/aug_data/images/00499_3.jpg
#   inflating: aug_data/aug_data/images/00499_4.jpg
#   inflating: aug_data/aug_data/images/00500_0.jpg
#   inflating: aug_data/aug_data/images/00500_1.jpg
#   inflating: aug_data/aug_data/images/00500_2.jpg
#   inflating: aug_data/aug_data/images/00500_3.jpg
#   inflating: aug_data/aug_data/images/00500_4.jpg
#   inflating: aug_data/aug_data/images/00501_0.jpg
#   inflating: aug_data/aug_data/images/00501_1.jpg
#   inflating: aug_data/aug_data/images/00501_2.jpg
#   inflating: aug_data/aug_data/images/00501_3.jpg
#   inflating: aug_data/aug_data/images/00501_4.jpg
#   inflating: aug_data/aug_data/images/00502_0.jpg
#   inflating: aug_data/aug_data/images/00502_1.jpg
#   inflating: aug_data/aug_data/images/00502_2.jpg
#   inflating: aug_data/aug_data/images/00502_3.jpg
#   inflating: aug_data/aug_data/images/00502_4.jpg
#   inflating: aug_data/aug_data/images/00503_0.jpg
#   inflating: aug_data/aug_data/images/00503_1.jpg
#   inflating: aug_data/aug_data/images/00503_2.jpg
#   inflating: aug_data/aug_data/images/00503_3.jpg
#   inflating: aug_data/aug_data/images/00503_4.jpg
#   inflating: aug_data/aug_data/images/00504_0.jpg
#   inflating: aug_data/aug_data/images/00504_1.jpg
#   inflating: aug_data/aug_data/images/00504_2.jpg
#   inflating: aug_data/aug_data/images/00504_3.jpg
#   inflating: aug_data/aug_data/images/00504_4.jpg
#   inflating: aug_data/aug_data/images/00505_0.jpg
#   inflating: aug_data/aug_data/images/00505_1.jpg
#   inflating: aug_data/aug_data/images/00505_2.jpg
#   inflating: aug_data/aug_data/images/00505_3.jpg
#   inflating: aug_data/aug_data/images/00505_4.jpg
#   inflating: aug_data/aug_data/images/00506_0.jpg
#   inflating: aug_data/aug_data/images/00506_1.jpg
#   inflating: aug_data/aug_data/images/00506_2.jpg
#   inflating: aug_data/aug_data/images/00506_3.jpg
#   inflating: aug_data/aug_data/images/00506_4.jpg
#   inflating: aug_data/aug_data/images/00507_0.jpg
#   inflating: aug_data/aug_data/images/00507_1.jpg
#   inflating: aug_data/aug_data/images/00507_2.jpg
#   inflating: aug_data/aug_data/images/00507_3.jpg
#   inflating: aug_data/aug_data/images/00507_4.jpg
#   inflating: aug_data/aug_data/images/00508_0.jpg
#   inflating: aug_data/aug_data/images/00508_1.jpg
#   inflating: aug_data/aug_data/images/00508_2.jpg
#   inflating: aug_data/aug_data/images/00508_3.jpg
#   inflating: aug_data/aug_data/images/00508_4.jpg
#   inflating: aug_data/aug_data/images/00509_0.jpg
#   inflating: aug_data/aug_data/images/00509_1.jpg
#   inflating: aug_data/aug_data/images/00509_2.jpg
#   inflating: aug_data/aug_data/images/00509_3.jpg
#   inflating: aug_data/aug_data/images/00509_4.jpg
#   inflating: aug_data/aug_data/images/00510_0.jpg
#   inflating: aug_data/aug_data/images/00510_1.jpg
#   inflating: aug_data/aug_data/images/00510_2.jpg
#   inflating: aug_data/aug_data/images/00510_3.jpg
#   inflating: aug_data/aug_data/images/00510_4.jpg
#   inflating: aug_data/aug_data/images/00511_0.jpg
#   inflating: aug_data/aug_data/images/00511_1.jpg
#   inflating: aug_data/aug_data/images/00511_2.jpg
#   inflating: aug_data/aug_data/images/00511_3.jpg
#   inflating: aug_data/aug_data/images/00511_4.jpg
#   inflating: aug_data/aug_data/images/00512_0.jpg
#   inflating: aug_data/aug_data/images/00512_1.jpg
#   inflating: aug_data/aug_data/images/00512_2.jpg
#   inflating: aug_data/aug_data/images/00512_3.jpg
#   inflating: aug_data/aug_data/images/00512_4.jpg
#   inflating: aug_data/aug_data/images/00513_0.jpg
#   inflating: aug_data/aug_data/images/00513_1.jpg
#   inflating: aug_data/aug_data/images/00513_2.jpg
#   inflating: aug_data/aug_data/images/00513_3.jpg
#   inflating: aug_data/aug_data/images/00513_4.jpg
#   inflating: aug_data/aug_data/images/00514_0.jpg
#   inflating: aug_data/aug_data/images/00514_1.jpg
#   inflating: aug_data/aug_data/images/00514_2.jpg
#   inflating: aug_data/aug_data/images/00514_3.jpg
#   inflating: aug_data/aug_data/images/00514_4.jpg
#   inflating: aug_data/aug_data/images/00515_0.jpg
#   inflating: aug_data/aug_data/images/00515_1.jpg
#   inflating: aug_data/aug_data/images/00515_2.jpg
#   inflating: aug_data/aug_data/images/00515_3.jpg
#   inflating: aug_data/aug_data/images/00515_4.jpg
#   inflating: aug_data/aug_data/images/00516_0.jpg
#   inflating: aug_data/aug_data/images/00516_1.jpg
#   inflating: aug_data/aug_data/images/00516_2.jpg
#   inflating: aug_data/aug_data/images/00516_3.jpg
#   inflating: aug_data/aug_data/images/00516_4.jpg
#   inflating: aug_data/aug_data/images/00517_0.jpg
#   inflating: aug_data/aug_data/images/00517_1.jpg
#   inflating: aug_data/aug_data/images/00517_2.jpg
#   inflating: aug_data/aug_data/images/00517_3.jpg
#   inflating: aug_data/aug_data/images/00517_4.jpg
#   inflating: aug_data/aug_data/images/00518_0.jpg
#   inflating: aug_data/aug_data/images/00518_1.jpg
#   inflating: aug_data/aug_data/images/00518_2.jpg
#   inflating: aug_data/aug_data/images/00518_3.jpg
#   inflating: aug_data/aug_data/images/00518_4.jpg
#   inflating: aug_data/aug_data/images/00519_0.jpg
#   inflating: aug_data/aug_data/images/00519_1.jpg
#   inflating: aug_data/aug_data/images/00519_2.jpg
#   inflating: aug_data/aug_data/images/00519_3.jpg
#   inflating: aug_data/aug_data/images/00519_4.jpg
#   inflating: aug_data/aug_data/images/00520_0.jpg
#   inflating: aug_data/aug_data/images/00520_1.jpg
#   inflating: aug_data/aug_data/images/00520_2.jpg
#   inflating: aug_data/aug_data/images/00520_3.jpg
#   inflating: aug_data/aug_data/images/00520_4.jpg
#   inflating: aug_data/aug_data/images/00521_0.jpg
#   inflating: aug_data/aug_data/images/00521_1.jpg
#   inflating: aug_data/aug_data/images/00521_2.jpg
#   inflating: aug_data/aug_data/images/00521_3.jpg
#   inflating: aug_data/aug_data/images/00521_4.jpg
#   inflating: aug_data/aug_data/images/00522_0.jpg
#   inflating: aug_data/aug_data/images/00522_1.jpg
#   inflating: aug_data/aug_data/images/00522_2.jpg
#   inflating: aug_data/aug_data/images/00522_3.jpg
#   inflating: aug_data/aug_data/images/00522_4.jpg
#   inflating: aug_data/aug_data/images/00523_0.jpg
#   inflating: aug_data/aug_data/images/00523_1.jpg
#   inflating: aug_data/aug_data/images/00523_2.jpg
#   inflating: aug_data/aug_data/images/00523_3.jpg
#   inflating: aug_data/aug_data/images/00523_4.jpg
#   inflating: aug_data/aug_data/images/00524_0.jpg
#   inflating: aug_data/aug_data/images/00524_1.jpg
#   inflating: aug_data/aug_data/images/00524_2.jpg
#   inflating: aug_data/aug_data/images/00524_3.jpg
#   inflating: aug_data/aug_data/images/00524_4.jpg
#   inflating: aug_data/aug_data/images/00525_0.jpg
#   inflating: aug_data/aug_data/images/00525_1.jpg
#   inflating: aug_data/aug_data/images/00525_2.jpg
#   inflating: aug_data/aug_data/images/00525_3.jpg
#   inflating: aug_data/aug_data/images/00525_4.jpg
#   inflating: aug_data/aug_data/images/00526_0.jpg
#   inflating: aug_data/aug_data/images/00526_1.jpg
#   inflating: aug_data/aug_data/images/00526_2.jpg
#   inflating: aug_data/aug_data/images/00526_3.jpg
#   inflating: aug_data/aug_data/images/00526_4.jpg
#   inflating: aug_data/aug_data/images/00527_0.jpg
#   inflating: aug_data/aug_data/images/00527_1.jpg
#   inflating: aug_data/aug_data/images/00527_2.jpg
#   inflating: aug_data/aug_data/images/00527_3.jpg
#   inflating: aug_data/aug_data/images/00527_4.jpg
#   inflating: aug_data/aug_data/images/00528_0.jpg
#   inflating: aug_data/aug_data/images/00528_1.jpg
#   inflating: aug_data/aug_data/images/00528_2.jpg
#   inflating: aug_data/aug_data/images/00528_3.jpg
#   inflating: aug_data/aug_data/images/00528_4.jpg
#   inflating: aug_data/aug_data/images/00529_0.jpg
#   inflating: aug_data/aug_data/images/00529_1.jpg
#   inflating: aug_data/aug_data/images/00529_2.jpg
#   inflating: aug_data/aug_data/images/00529_3.jpg
#   inflating: aug_data/aug_data/images/00529_4.jpg
#   inflating: aug_data/aug_data/images/00530_0.jpg
#   inflating: aug_data/aug_data/images/00530_1.jpg
#   inflating: aug_data/aug_data/images/00530_2.jpg
#   inflating: aug_data/aug_data/images/00530_3.jpg
#   inflating: aug_data/aug_data/images/00530_4.jpg
#   inflating: aug_data/aug_data/images/00531_0.jpg
#   inflating: aug_data/aug_data/images/00531_1.jpg
#   inflating: aug_data/aug_data/images/00531_2.jpg
#   inflating: aug_data/aug_data/images/00531_3.jpg
#   inflating: aug_data/aug_data/images/00531_4.jpg
#   inflating: aug_data/aug_data/images/00532_0.jpg
#   inflating: aug_data/aug_data/images/00532_1.jpg
#   inflating: aug_data/aug_data/images/00532_2.jpg
#   inflating: aug_data/aug_data/images/00532_3.jpg
#   inflating: aug_data/aug_data/images/00532_4.jpg
#   inflating: aug_data/aug_data/images/00533_0.jpg
#   inflating: aug_data/aug_data/images/00533_1.jpg
#   inflating: aug_data/aug_data/images/00533_2.jpg
#   inflating: aug_data/aug_data/images/00533_3.jpg
#   inflating: aug_data/aug_data/images/00533_4.jpg
#   inflating: aug_data/aug_data/images/00534_0.jpg
#   inflating: aug_data/aug_data/images/00534_1.jpg
#   inflating: aug_data/aug_data/images/00534_2.jpg
#   inflating: aug_data/aug_data/images/00534_3.jpg
#   inflating: aug_data/aug_data/images/00534_4.jpg
#   inflating: aug_data/aug_data/images/00535_0.jpg
#   inflating: aug_data/aug_data/images/00535_1.jpg
#   inflating: aug_data/aug_data/images/00535_2.jpg
#   inflating: aug_data/aug_data/images/00535_3.jpg
#   inflating: aug_data/aug_data/images/00535_4.jpg
#   inflating: aug_data/aug_data/images/00536_0.jpg
#   inflating: aug_data/aug_data/images/00536_1.jpg
#   inflating: aug_data/aug_data/images/00536_2.jpg
#   inflating: aug_data/aug_data/images/00536_3.jpg
#   inflating: aug_data/aug_data/images/00536_4.jpg
#   inflating: aug_data/aug_data/images/00537_0.jpg
#   inflating: aug_data/aug_data/images/00537_1.jpg
#   inflating: aug_data/aug_data/images/00537_2.jpg
#   inflating: aug_data/aug_data/images/00537_3.jpg
#   inflating: aug_data/aug_data/images/00537_4.jpg
#   inflating: aug_data/aug_data/images/00538_0.jpg
#   inflating: aug_data/aug_data/images/00538_1.jpg
#   inflating: aug_data/aug_data/images/00538_2.jpg
#   inflating: aug_data/aug_data/images/00538_3.jpg
#   inflating: aug_data/aug_data/images/00538_4.jpg
#   inflating: aug_data/aug_data/images/00539_0.jpg
#   inflating: aug_data/aug_data/images/00539_1.jpg
#   inflating: aug_data/aug_data/images/00539_2.jpg
#   inflating: aug_data/aug_data/images/00539_3.jpg
#   inflating: aug_data/aug_data/images/00539_4.jpg
#   inflating: aug_data/aug_data/images/00540_0.jpg
#   inflating: aug_data/aug_data/images/00540_1.jpg
#   inflating: aug_data/aug_data/images/00540_2.jpg
#   inflating: aug_data/aug_data/images/00540_3.jpg
#   inflating: aug_data/aug_data/images/00540_4.jpg
#   inflating: aug_data/aug_data/images/00541_0.jpg
#   inflating: aug_data/aug_data/images/00541_1.jpg
#   inflating: aug_data/aug_data/images/00541_2.jpg
#   inflating: aug_data/aug_data/images/00541_3.jpg
#   inflating: aug_data/aug_data/images/00541_4.jpg
#   inflating: aug_data/aug_data/images/00542_0.jpg
#   inflating: aug_data/aug_data/images/00542_1.jpg
#   inflating: aug_data/aug_data/images/00542_2.jpg
#   inflating: aug_data/aug_data/images/00542_3.jpg
#   inflating: aug_data/aug_data/images/00542_4.jpg
#   inflating: aug_data/aug_data/images/00543_0.jpg
#   inflating: aug_data/aug_data/images/00543_1.jpg
#   inflating: aug_data/aug_data/images/00543_2.jpg
#   inflating: aug_data/aug_data/images/00543_3.jpg
#   inflating: aug_data/aug_data/images/00543_4.jpg
#   inflating: aug_data/aug_data/images/00544_0.jpg
#   inflating: aug_data/aug_data/images/00544_1.jpg
#   inflating: aug_data/aug_data/images/00544_2.jpg
#   inflating: aug_data/aug_data/images/00544_3.jpg
#   inflating: aug_data/aug_data/images/00544_4.jpg
#   inflating: aug_data/aug_data/images/00545_0.jpg
#   inflating: aug_data/aug_data/images/00545_1.jpg
#   inflating: aug_data/aug_data/images/00545_2.jpg
#   inflating: aug_data/aug_data/images/00545_3.jpg
#   inflating: aug_data/aug_data/images/00545_4.jpg
#   inflating: aug_data/aug_data/images/00546_0.jpg
#   inflating: aug_data/aug_data/images/00546_1.jpg
#   inflating: aug_data/aug_data/images/00546_2.jpg
#   inflating: aug_data/aug_data/images/00546_3.jpg
#   inflating: aug_data/aug_data/images/00546_4.jpg
#   inflating: aug_data/aug_data/images/00547_0.jpg
#   inflating: aug_data/aug_data/images/00547_1.jpg
#   inflating: aug_data/aug_data/images/00547_2.jpg
#   inflating: aug_data/aug_data/images/00547_3.jpg
#   inflating: aug_data/aug_data/images/00547_4.jpg
#   inflating: aug_data/aug_data/images/00548_0.jpg
#   inflating: aug_data/aug_data/images/00548_1.jpg
#   inflating: aug_data/aug_data/images/00548_2.jpg
#   inflating: aug_data/aug_data/images/00548_3.jpg
#   inflating: aug_data/aug_data/images/00548_4.jpg
#   inflating: aug_data/aug_data/images/00549_0.jpg
#   inflating: aug_data/aug_data/images/00549_1.jpg
#   inflating: aug_data/aug_data/images/00549_2.jpg
#   inflating: aug_data/aug_data/images/00549_3.jpg
#   inflating: aug_data/aug_data/images/00549_4.jpg
#   inflating: aug_data/aug_data/images/00550_0.jpg
#   inflating: aug_data/aug_data/images/00550_1.jpg
#   inflating: aug_data/aug_data/images/00550_2.jpg
#   inflating: aug_data/aug_data/images/00550_3.jpg
#   inflating: aug_data/aug_data/images/00550_4.jpg
#   inflating: aug_data/aug_data/images/00551_0.jpg
#   inflating: aug_data/aug_data/images/00551_1.jpg
#   inflating: aug_data/aug_data/images/00551_2.jpg
#   inflating: aug_data/aug_data/images/00551_3.jpg
#   inflating: aug_data/aug_data/images/00551_4.jpg
#   inflating: aug_data/aug_data/images/00552_0.jpg
#   inflating: aug_data/aug_data/images/00552_1.jpg
#   inflating: aug_data/aug_data/images/00552_2.jpg
#   inflating: aug_data/aug_data/images/00552_3.jpg
#   inflating: aug_data/aug_data/images/00552_4.jpg
#   inflating: aug_data/aug_data/images/00553_0.jpg
#   inflating: aug_data/aug_data/images/00553_1.jpg
#   inflating: aug_data/aug_data/images/00553_2.jpg
#   inflating: aug_data/aug_data/images/00553_3.jpg
#   inflating: aug_data/aug_data/images/00553_4.jpg
#   inflating: aug_data/aug_data/images/00554_0.jpg
#   inflating: aug_data/aug_data/images/00554_1.jpg
#   inflating: aug_data/aug_data/images/00554_2.jpg
#   inflating: aug_data/aug_data/images/00554_3.jpg
#   inflating: aug_data/aug_data/images/00554_4.jpg
#   inflating: aug_data/aug_data/images/00555_0.jpg
#   inflating: aug_data/aug_data/images/00555_1.jpg
#   inflating: aug_data/aug_data/images/00555_2.jpg
#   inflating: aug_data/aug_data/images/00555_3.jpg
#   inflating: aug_data/aug_data/images/00555_4.jpg
#   inflating: aug_data/aug_data/images/00556_0.jpg
#   inflating: aug_data/aug_data/images/00556_1.jpg
#   inflating: aug_data/aug_data/images/00556_2.jpg
#   inflating: aug_data/aug_data/images/00556_3.jpg
#   inflating: aug_data/aug_data/images/00556_4.jpg
#   inflating: aug_data/aug_data/images/00557_0.jpg
#   inflating: aug_data/aug_data/images/00557_1.jpg
#   inflating: aug_data/aug_data/images/00557_2.jpg
#   inflating: aug_data/aug_data/images/00557_3.jpg
#   inflating: aug_data/aug_data/images/00557_4.jpg
#   inflating: aug_data/aug_data/images/00558_0.jpg
#   inflating: aug_data/aug_data/images/00558_1.jpg
#   inflating: aug_data/aug_data/images/00558_2.jpg
#   inflating: aug_data/aug_data/images/00558_3.jpg
#   inflating: aug_data/aug_data/images/00558_4.jpg
#   inflating: aug_data/aug_data/images/00559_0.jpg
#   inflating: aug_data/aug_data/images/00559_1.jpg
#   inflating: aug_data/aug_data/images/00559_2.jpg
#   inflating: aug_data/aug_data/images/00559_3.jpg
#   inflating: aug_data/aug_data/images/00559_4.jpg
#   inflating: aug_data/aug_data/images/00560_0.jpg
#   inflating: aug_data/aug_data/images/00560_1.jpg
#   inflating: aug_data/aug_data/images/00560_2.jpg
#   inflating: aug_data/aug_data/images/00560_3.jpg
#   inflating: aug_data/aug_data/images/00560_4.jpg
#   inflating: aug_data/aug_data/images/00561_0.jpg
#   inflating: aug_data/aug_data/images/00561_1.jpg
#   inflating: aug_data/aug_data/images/00561_2.jpg
#   inflating: aug_data/aug_data/images/00561_3.jpg
#   inflating: aug_data/aug_data/images/00561_4.jpg
#   inflating: aug_data/aug_data/images/00562_0.jpg
#   inflating: aug_data/aug_data/images/00562_1.jpg
#   inflating: aug_data/aug_data/images/00562_2.jpg
#   inflating: aug_data/aug_data/images/00562_3.jpg
#   inflating: aug_data/aug_data/images/00562_4.jpg
#   inflating: aug_data/aug_data/images/00563_0.jpg
#   inflating: aug_data/aug_data/images/00563_1.jpg
#   inflating: aug_data/aug_data/images/00563_2.jpg
#   inflating: aug_data/aug_data/images/00563_3.jpg
#   inflating: aug_data/aug_data/images/00563_4.jpg
#   inflating: aug_data/aug_data/images/00564_0.jpg
#   inflating: aug_data/aug_data/images/00564_1.jpg
#   inflating: aug_data/aug_data/images/00564_2.jpg
#   inflating: aug_data/aug_data/images/00564_3.jpg
#   inflating: aug_data/aug_data/images/00564_4.jpg
#   inflating: aug_data/aug_data/images/00565_0.jpg
#   inflating: aug_data/aug_data/images/00565_1.jpg
#   inflating: aug_data/aug_data/images/00565_2.jpg
#   inflating: aug_data/aug_data/images/00565_3.jpg
#   inflating: aug_data/aug_data/images/00565_4.jpg
#   inflating: aug_data/aug_data/images/00566_0.jpg
#   inflating: aug_data/aug_data/images/00566_1.jpg
#   inflating: aug_data/aug_data/images/00566_2.jpg
#   inflating: aug_data/aug_data/images/00566_3.jpg
#   inflating: aug_data/aug_data/images/00566_4.jpg
#   inflating: aug_data/aug_data/images/00567_0.jpg
#   inflating: aug_data/aug_data/images/00567_1.jpg
#   inflating: aug_data/aug_data/images/00567_2.jpg
#   inflating: aug_data/aug_data/images/00567_3.jpg
#   inflating: aug_data/aug_data/images/00567_4.jpg
#   inflating: aug_data/aug_data/images/00568_0.jpg
#   inflating: aug_data/aug_data/images/00568_1.jpg
#   inflating: aug_data/aug_data/images/00568_2.jpg
#   inflating: aug_data/aug_data/images/00568_3.jpg
#   inflating: aug_data/aug_data/images/00568_4.jpg
#   inflating: aug_data/aug_data/images/00569_0.jpg
#   inflating: aug_data/aug_data/images/00569_1.jpg
#   inflating: aug_data/aug_data/images/00569_2.jpg
#   inflating: aug_data/aug_data/images/00569_3.jpg
#   inflating: aug_data/aug_data/images/00569_4.jpg
#   inflating: aug_data/aug_data/images/00570_0.jpg
#   inflating: aug_data/aug_data/images/00570_1.jpg
#   inflating: aug_data/aug_data/images/00570_2.jpg
#   inflating: aug_data/aug_data/images/00570_3.jpg
#   inflating: aug_data/aug_data/images/00570_4.jpg
#   inflating: aug_data/aug_data/images/00571_0.jpg
#   inflating: aug_data/aug_data/images/00571_1.jpg
#   inflating: aug_data/aug_data/images/00571_2.jpg
#   inflating: aug_data/aug_data/images/00571_3.jpg
#   inflating: aug_data/aug_data/images/00571_4.jpg
#   inflating: aug_data/aug_data/images/00572_0.jpg
#   inflating: aug_data/aug_data/images/00572_1.jpg
#   inflating: aug_data/aug_data/images/00572_2.jpg
#   inflating: aug_data/aug_data/images/00572_3.jpg
#   inflating: aug_data/aug_data/images/00572_4.jpg
#   inflating: aug_data/aug_data/images/00573_0.jpg
#   inflating: aug_data/aug_data/images/00573_1.jpg
#   inflating: aug_data/aug_data/images/00573_2.jpg
#   inflating: aug_data/aug_data/images/00573_3.jpg
#   inflating: aug_data/aug_data/images/00573_4.jpg
#   inflating: aug_data/aug_data/images/00574_0.jpg
#   inflating: aug_data/aug_data/images/00574_1.jpg
#   inflating: aug_data/aug_data/images/00574_2.jpg
#   inflating: aug_data/aug_data/images/00574_3.jpg
#   inflating: aug_data/aug_data/images/00574_4.jpg
#   inflating: aug_data/aug_data/images/00575_0.jpg
#   inflating: aug_data/aug_data/images/00575_1.jpg
#   inflating: aug_data/aug_data/images/00575_2.jpg
#   inflating: aug_data/aug_data/images/00575_3.jpg
#   inflating: aug_data/aug_data/images/00575_4.jpg
#   inflating: aug_data/aug_data/images/00576_0.jpg
#   inflating: aug_data/aug_data/images/00576_1.jpg
#   inflating: aug_data/aug_data/images/00576_2.jpg
#   inflating: aug_data/aug_data/images/00576_3.jpg
#   inflating: aug_data/aug_data/images/00576_4.jpg
#   inflating: aug_data/aug_data/images/00577_0.jpg
#   inflating: aug_data/aug_data/images/00577_1.jpg
#   inflating: aug_data/aug_data/images/00577_2.jpg
#   inflating: aug_data/aug_data/images/00577_3.jpg
#   inflating: aug_data/aug_data/images/00577_4.jpg
#   inflating: aug_data/aug_data/images/00578_0.jpg
#   inflating: aug_data/aug_data/images/00578_1.jpg
#   inflating: aug_data/aug_data/images/00578_2.jpg
#   inflating: aug_data/aug_data/images/00578_3.jpg
#   inflating: aug_data/aug_data/images/00578_4.jpg
#   inflating: aug_data/aug_data/images/00579_0.jpg
#   inflating: aug_data/aug_data/images/00579_1.jpg
#   inflating: aug_data/aug_data/images/00579_2.jpg
#   inflating: aug_data/aug_data/images/00579_3.jpg
#   inflating: aug_data/aug_data/images/00579_4.jpg
#   inflating: aug_data/aug_data/images/00580_0.jpg
#   inflating: aug_data/aug_data/images/00580_1.jpg
#   inflating: aug_data/aug_data/images/00580_2.jpg
#   inflating: aug_data/aug_data/images/00580_3.jpg
#   inflating: aug_data/aug_data/images/00580_4.jpg
#   inflating: aug_data/aug_data/images/00581_0.jpg
#   inflating: aug_data/aug_data/images/00581_1.jpg
#   inflating: aug_data/aug_data/images/00581_2.jpg
#   inflating: aug_data/aug_data/images/00581_3.jpg
#   inflating: aug_data/aug_data/images/00581_4.jpg
#   inflating: aug_data/aug_data/images/00582_0.jpg
#   inflating: aug_data/aug_data/images/00582_1.jpg
#   inflating: aug_data/aug_data/images/00582_2.jpg
#   inflating: aug_data/aug_data/images/00582_3.jpg
#   inflating: aug_data/aug_data/images/00582_4.jpg
#   inflating: aug_data/aug_data/images/00583_0.jpg
#   inflating: aug_data/aug_data/images/00583_1.jpg
#   inflating: aug_data/aug_data/images/00583_2.jpg
#   inflating: aug_data/aug_data/images/00583_3.jpg
#   inflating: aug_data/aug_data/images/00583_4.jpg
#   inflating: aug_data/aug_data/images/00584_0.jpg
#   inflating: aug_data/aug_data/images/00584_1.jpg
#   inflating: aug_data/aug_data/images/00584_2.jpg
#   inflating: aug_data/aug_data/images/00584_3.jpg
#   inflating: aug_data/aug_data/images/00584_4.jpg
#   inflating: aug_data/aug_data/images/00585_0.jpg
#   inflating: aug_data/aug_data/images/00585_1.jpg
#   inflating: aug_data/aug_data/images/00585_2.jpg
#   inflating: aug_data/aug_data/images/00585_3.jpg
#   inflating: aug_data/aug_data/images/00585_4.jpg
#   inflating: aug_data/aug_data/images/00586_0.jpg
#   inflating: aug_data/aug_data/images/00586_1.jpg
#   inflating: aug_data/aug_data/images/00586_2.jpg
#   inflating: aug_data/aug_data/images/00586_3.jpg
#   inflating: aug_data/aug_data/images/00586_4.jpg
#   inflating: aug_data/aug_data/images/00587_0.jpg
#   inflating: aug_data/aug_data/images/00587_1.jpg
#   inflating: aug_data/aug_data/images/00587_2.jpg
#   inflating: aug_data/aug_data/images/00587_3.jpg
#   inflating: aug_data/aug_data/images/00587_4.jpg
#   inflating: aug_data/aug_data/masks/00000_0.png
#   inflating: aug_data/aug_data/masks/00000_1.png
#   inflating: aug_data/aug_data/masks/00000_2.png
#   inflating: aug_data/aug_data/masks/00000_3.png
#   inflating: aug_data/aug_data/masks/00000_4.png
#   inflating: aug_data/aug_data/masks/00001_0.png
#   inflating: aug_data/aug_data/masks/00001_1.png
#   inflating: aug_data/aug_data/masks/00001_2.png
#   inflating: aug_data/aug_data/masks/00001_3.png
#   inflating: aug_data/aug_data/masks/00001_4.png
#   inflating: aug_data/aug_data/masks/00002_0.png
#   inflating: aug_data/aug_data/masks/00002_1.png
#   inflating: aug_data/aug_data/masks/00002_2.png
#   inflating: aug_data/aug_data/masks/00002_3.png
#   inflating: aug_data/aug_data/masks/00002_4.png
#   inflating: aug_data/aug_data/masks/00003_0.png
#   inflating: aug_data/aug_data/masks/00003_1.png
#   inflating: aug_data/aug_data/masks/00003_2.png
#   inflating: aug_data/aug_data/masks/00003_3.png
#   inflating: aug_data/aug_data/masks/00003_4.png
#   inflating: aug_data/aug_data/masks/00004_0.png
#   inflating: aug_data/aug_data/masks/00004_1.png
#   inflating: aug_data/aug_data/masks/00004_2.png
#   inflating: aug_data/aug_data/masks/00004_3.png
#   inflating: aug_data/aug_data/masks/00004_4.png
#   inflating: aug_data/aug_data/masks/00005_0.png
#   inflating: aug_data/aug_data/masks/00005_1.png
#   inflating: aug_data/aug_data/masks/00005_2.png
#   inflating: aug_data/aug_data/masks/00005_3.png
#   inflating: aug_data/aug_data/masks/00005_4.png
#   inflating: aug_data/aug_data/masks/00006_0.png
#   inflating: aug_data/aug_data/masks/00006_1.png
#   inflating: aug_data/aug_data/masks/00006_2.png
#   inflating: aug_data/aug_data/masks/00006_3.png
#   inflating: aug_data/aug_data/masks/00006_4.png
#   inflating: aug_data/aug_data/masks/00007_0.png
#   inflating: aug_data/aug_data/masks/00007_1.png
#   inflating: aug_data/aug_data/masks/00007_2.png
# ...
#   inflating: data/data/masks/00198.png
#   inflating: data/data/masks/00199.png
#   inflating: data/data/masks/00200.png
#   inflating: data/data/masks/00201.png
#   inflating: data/data/masks/00202.png
#   inflating: data/data/masks/00203.png
#   inflating: data/data/masks/00204.png
#   inflating: data/data/masks/00205.png
#   inflating: data/data/masks/00206.png
#   inflating: data/data/masks/00207.png
#   inflating: data/data/masks/00208.png
#   inflating: data/data/masks/00209.png
#   inflating: data/data/masks/00210.png
#   inflating: data/data/masks/00211.png
#   inflating: data/data/masks/00212.png
#   inflating: data/data/masks/00213.png
#   inflating: data/data/masks/00214.png
#   inflating: data/data/masks/00215.png
#   inflating: data/data/masks/00216.png
#   inflating: data/data/masks/00217.png
#   inflating: data/data/masks/00218.png
#   inflating: data/data/masks/00219.png
#   inflating: data/data/masks/00220.png
#   inflating: data/data/masks/00221.png
#   inflating: data/data/masks/00222.png
#   inflating: data/data/masks/00223.png
#   inflating: data/data/masks/00224.png
#   inflating: data/data/masks/00225.png
#   inflating: data/data/masks/00226.png
#   inflating: data/data/masks/00227.png
#   inflating: data/data/masks/00228.png
#   inflating: data/data/masks/00229.png
#   inflating: data/data/masks/00230.png
#   inflating: data/data/masks/00231.png
#   inflating: data/data/masks/00232.png
#   inflating: data/data/masks/00233.png
#   inflating: data/data/masks/00234.png
#   inflating: data/data/masks/00235.png
#   inflating: data/data/masks/00236.png
#   inflating: data/data/masks/00237.png
#   inflating: data/data/masks/00238.png
#   inflating: data/data/masks/00239.png
#   inflating: data/data/masks/00240.png
#   inflating: data/data/masks/00241.png
#   inflating: data/data/masks/00242.png
#   inflating: data/data/masks/00243.png
#   inflating: data/data/masks/00244.png
#   inflating: data/data/masks/00245.png
#   inflating: data/data/masks/00246.png
#   inflating: data/data/masks/00247.png
#   inflating: data/data/masks/00248.png
#   inflating: data/data/masks/00249.png
#   inflating: data/data/masks/00250.png
#   inflating: data/data/masks/00251.png
#   inflating: data/data/masks/00252.png
#   inflating: data/data/masks/00253.png
#   inflating: data/data/masks/00254.png
#   inflating: data/data/masks/00255.png
#   inflating: data/data/masks/00256.png
#   inflating: data/data/masks/00257.png
#   inflating: data/data/masks/00258.png
#   inflating: data/data/masks/00259.png
#   inflating: data/data/masks/00260.png
#   inflating: data/data/masks/00261.png
#   inflating: data/data/masks/00262.png
#   inflating: data/data/masks/00263.png
#   inflating: data/data/masks/00264.png
#   inflating: data/data/masks/00265.png
#   inflating: data/data/masks/00266.png
#   inflating: data/data/masks/00267.png
#   inflating: data/data/masks/00268.png
#   inflating: data/data/masks/00269.png
#   inflating: data/data/masks/00270.png
#   inflating: data/data/masks/00271.png
#   inflating: data/data/masks/00272.png
#   inflating: data/data/masks/00273.png
#   inflating: data/data/masks/00274.png
#   inflating: data/data/masks/00275.png
#   inflating: data/data/masks/00276.png
#   inflating: data/data/masks/00277.png
#   inflating: data/data/masks/00278.png
#   inflating: data/data/masks/00279.png
#   inflating: data/data/masks/00280.png
#   inflating: data/data/masks/00281.png
#   inflating: data/data/masks/00282.png
#   inflating: data/data/masks/00283.png
#   inflating: data/data/masks/00284.png
#   inflating: data/data/masks/00285.png
#   inflating: data/data/masks/00286.png
#   inflating: data/data/masks/00287.png
#   inflating: data/data/masks/00288.png
#   inflating: data/data/masks/00289.png
#   inflating: data/data/masks/00290.png
#   inflating: data/data/masks/00291.png
#   inflating: data/data/masks/00292.png
#   inflating: data/data/masks/00293.png
#   inflating: data/data/masks/00294.png
#   inflating: data/data/masks/00295.png
#   inflating: data/data/masks/00296.png
#   inflating: data/data/masks/00297.png
#   inflating: data/data/masks/00298.png
#   inflating: data/data/masks/00299.png
#   inflating: data/data/masks/00300.png
#   inflating: data/data/masks/00301.png
#   inflating: data/data/masks/00302.png
#   inflating: data/data/masks/00303.png
#   inflating: data/data/masks/00304.png
#   inflating: data/data/masks/00305.png
#   inflating: data/data/masks/00306.png
#   inflating: data/data/masks/00307.png
#   inflating: data/data/masks/00308.png
#   inflating: data/data/masks/00309.png
#   inflating: data/data/masks/00310.png
#   inflating: data/data/masks/00311.png
#   inflating: data/data/masks/00312.png
#   inflating: data/data/masks/00313.png
#   inflating: data/data/masks/00314.png
#   inflating: data/data/masks/00315.png
#   inflating: data/data/masks/00316.png
#   inflating: data/data/masks/00317.png
#   inflating: data/data/masks/00318.png
#   inflating: data/data/masks/00319.png
#   inflating: data/data/masks/00320.png
#   inflating: data/data/masks/00321.png
#   inflating: data/data/masks/00322.png
#   inflating: data/data/masks/00323.png
#   inflating: data/data/masks/00324.png
#   inflating: data/data/masks/00325.png
#   inflating: data/data/masks/00326.png
#   inflating: data/data/masks/00327.png
#   inflating: data/data/masks/00328.png
#   inflating: data/data/masks/00329.png
#   inflating: data/data/masks/00330.png
#   inflating: data/data/masks/00331.png
#   inflating: data/data/masks/00332.png
#   inflating: data/data/masks/00333.png
#   inflating: data/data/masks/00334.png
#   inflating: data/data/masks/00335.png
#   inflating: data/data/masks/00336.png
#   inflating: data/data/masks/00337.png
#   inflating: data/data/masks/00338.png
#   inflating: data/data/masks/00339.png
#   inflating: data/data/masks/00340.png
#   inflating: data/data/masks/00341.png
#   inflating: data/data/masks/00342.png
#   inflating: data/data/masks/00343.png
#   inflating: data/data/masks/00344.png
#   inflating: data/data/masks/00345.png
#   inflating: data/data/masks/00346.png
#   inflating: data/data/masks/00347.png
#   inflating: data/data/masks/00348.png
#   inflating: data/data/masks/00349.png
#   inflating: data/data/masks/00350.png
#   inflating: data/data/masks/00351.png
#   inflating: data/data/masks/00352.png
#   inflating: data/data/masks/00353.png
#   inflating: data/data/masks/00354.png
#   inflating: data/data/masks/00355.png
#   inflating: data/data/masks/00356.png
#   inflating: data/data/masks/00357.png
#   inflating: data/data/masks/00358.png
#   inflating: data/data/masks/00359.png
#   inflating: data/data/masks/00360.png
#   inflating: data/data/masks/00361.png
#   inflating: data/data/masks/00362.png
#   inflating: data/data/masks/00363.png
#   inflating: data/data/masks/00364.png
#   inflating: data/data/masks/00365.png
#   inflating: data/data/masks/00366.png
#   inflating: data/data/masks/00367.png
#   inflating: data/data/masks/00368.png
#   inflating: data/data/masks/00369.png
#   inflating: data/data/masks/00370.png
#   inflating: data/data/masks/00371.png
#   inflating: data/data/masks/00372.png
#   inflating: data/data/masks/00373.png
#   inflating: data/data/masks/00374.png
#   inflating: data/data/masks/00375.png
#   inflating: data/data/masks/00376.png
#   inflating: data/data/masks/00377.png
#   inflating: data/data/masks/00378.png
#   inflating: data/data/masks/00379.png
#   inflating: data/data/masks/00380.png
#   inflating: data/data/masks/00381.png
#   inflating: data/data/masks/00382.png
#   inflating: data/data/masks/00383.png
#   inflating: data/data/masks/00384.png
#   inflating: data/data/masks/00385.png
#   inflating: data/data/masks/00386.png
#   inflating: data/data/masks/00387.png
#   inflating: data/data/masks/00388.png
#   inflating: data/data/masks/00389.png
#   inflating: data/data/masks/00390.png
#   inflating: data/data/masks/00391.png
#   inflating: data/data/masks/00392.png
#   inflating: data/data/masks/00393.png
#   inflating: data/data/masks/00394.png
#   inflating: data/data/masks/00395.png
#   inflating: data/data/masks/00396.png
#   inflating: data/data/masks/00397.png
#   inflating: data/data/masks/00398.png
#   inflating: data/data/masks/00399.png
#   inflating: data/data/masks/00400.png
#   inflating: data/data/masks/00401.png
#   inflating: data/data/masks/00402.png
#   inflating: data/data/masks/00403.png
#   inflating: data/data/masks/00404.png
#   inflating: data/data/masks/00405.png
#   inflating: data/data/masks/00406.png
#   inflating: data/data/masks/00407.png
#   inflating: data/data/masks/00408.png
#   inflating: data/data/masks/00409.png
#   inflating: data/data/masks/00410.png
#   inflating: data/data/masks/00411.png
#   inflating: data/data/masks/00412.png
#   inflating: data/data/masks/00413.png
#   inflating: data/data/masks/00414.png
#   inflating: data/data/masks/00415.png
#   inflating: data/data/masks/00416.png
#   inflating: data/data/masks/00417.png
#   inflating: data/data/masks/00418.png
#   inflating: data/data/masks/00419.png
#   inflating: data/data/masks/00420.png
#   inflating: data/data/masks/00421.png
#   inflating: data/data/masks/00422.png
#   inflating: data/data/masks/00423.png
#   inflating: data/data/masks/00424.png
#   inflating: data/data/masks/00425.png
#   inflating: data/data/masks/00426.png
#   inflating: data/data/masks/00427.png
#   inflating: data/data/masks/00428.png
#   inflating: data/data/masks/00429.png
#   inflating: data/data/masks/00430.png
#   inflating: data/data/masks/00431.png
#   inflating: data/data/masks/00432.png
#   inflating: data/data/masks/00433.png
#   inflating: data/data/masks/00434.png
#   inflating: data/data/masks/00435.png
#   inflating: data/data/masks/00436.png
#   inflating: data/data/masks/00437.png
#   inflating: data/data/masks/00438.png
#   inflating: data/data/masks/00439.png
#   inflating: data/data/masks/00440.png
#   inflating: data/data/masks/00441.png
#   inflating: data/data/masks/00442.png
#   inflating: data/data/masks/00443.png
#   inflating: data/data/masks/00444.png
#   inflating: data/data/masks/00445.png
#   inflating: data/data/masks/00446.png
#   inflating: data/data/masks/00447.png
#   inflating: data/data/masks/00448.png
#   inflating: data/data/masks/00449.png
#   inflating: data/data/masks/00450.png
#   inflating: data/data/masks/00451.png
#   inflating: data/data/masks/00452.png
#   inflating: data/data/masks/00453.png
#   inflating: data/data/masks/00454.png
#   inflating: data/data/masks/00455.png
#   inflating: data/data/masks/00456.png
#   inflating: data/data/masks/00457.png
#   inflating: data/data/masks/00458.png
#   inflating: data/data/masks/00459.png
#   inflating: data/data/masks/00460.png
#   inflating: data/data/masks/00461.png
#   inflating: data/data/masks/00462.png
#   inflating: data/data/masks/00463.png
#   inflating: data/data/masks/00464.png
#   inflating: data/data/masks/00465.png
#   inflating: data/data/masks/00466.png
#   inflating: data/data/masks/00467.png
#   inflating: data/data/masks/00468.png
#   inflating: data/data/masks/00469.png
#   inflating: data/data/masks/00470.png
#   inflating: data/data/masks/00471.png
#   inflating: data/data/masks/00472.png
#   inflating: data/data/masks/00473.png
#   inflating: data/data/masks/00474.png
#   inflating: data/data/masks/00475.png
#   inflating: data/data/masks/00476.png
#   inflating: data/data/masks/00477.png
#   inflating: data/data/masks/00478.png
#   inflating: data/data/masks/00479.png
#   inflating: data/data/masks/00480.png
#   inflating: data/data/masks/00481.png
#   inflating: data/data/masks/00482.png
#   inflating: data/data/masks/00483.png
#   inflating: data/data/masks/00484.png
#   inflating: data/data/masks/00485.png
#   inflating: data/data/masks/00486.png
#   inflating: data/data/masks/00487.png
#   inflating: data/data/masks/00488.png
#   inflating: data/data/masks/00489.png
#   inflating: data/data/masks/00490.png
#   inflating: data/data/masks/00491.png
#   inflating: data/data/masks/00492.png
#   inflating: data/data/masks/00493.png
#   inflating: data/data/masks/00494.png
#   inflating: data/data/masks/00495.png
#   inflating: data/data/masks/00496.png
#   inflating: data/data/masks/00497.png
#   inflating: data/data/masks/00498.png
#   inflating: data/data/masks/00499.png
#   inflating: data/data/masks/00500.png
#   inflating: data/data/masks/00501.png
#   inflating: data/data/masks/00502.png
#   inflating: data/data/masks/00503.png
#   inflating: data/data/masks/00504.png
#   inflating: data/data/masks/00505.png
#   inflating: data/data/masks/00506.png
#   inflating: data/data/masks/00507.png
#   inflating: data/data/masks/00508.png
#   inflating: data/data/masks/00509.png
#   inflating: data/data/masks/00510.png
#   inflating: data/data/masks/00511.png
#   inflating: data/data/masks/00512.png
#   inflating: data/data/masks/00513.png
#   inflating: data/data/masks/00514.png
#   inflating: data/data/masks/00515.png
#   inflating: data/data/masks/00516.png
#   inflating: data/data/masks/00517.png
#   inflating: data/data/masks/00518.png
#   inflating: data/data/masks/00519.png
#   inflating: data/data/masks/00520.png
#   inflating: data/data/masks/00521.png
#   inflating: data/data/masks/00522.png
#   inflating: data/data/masks/00523.png
#   inflating: data/data/masks/00524.png
#   inflating: data/data/masks/00525.png
#   inflating: data/data/masks/00526.png
#   inflating: data/data/masks/00527.png
#   inflating: data/data/masks/00528.png
#   inflating: data/data/masks/00529.png
#   inflating: data/data/masks/00530.png
#   inflating: data/data/masks/00531.png
#   inflating: data/data/masks/00532.png
#   inflating: data/data/masks/00533.png
#   inflating: data/data/masks/00534.png
#   inflating: data/data/masks/00535.png
#   inflating: data/data/masks/00536.png
#   inflating: data/data/masks/00537.png
#   inflating: data/data/masks/00538.png
#   inflating: data/data/masks/00539.png
#   inflating: data/data/masks/00540.png
#   inflating: data/data/masks/00541.png
#   inflating: data/data/masks/00542.png
#   inflating: data/data/masks/00543.png
#   inflating: data/data/masks/00544.png
#   inflating: data/data/masks/00545.png
#   inflating: data/data/masks/00546.png
#   inflating: data/data/masks/00547.png
#   inflating: data/data/masks/00548.png
#   inflating: data/data/masks/00549.png
#   inflating: data/data/masks/00550.png
#   inflating: data/data/masks/00551.png
#   inflating: data/data/masks/00552.png
#   inflating: data/data/masks/00553.png
#   inflating: data/data/masks/00554.png
#   inflating: data/data/masks/00555.png
#   inflating: data/data/masks/00556.png
#   inflating: data/data/masks/00557.png
#   inflating: data/data/masks/00558.png
#   inflating: data/data/masks/00559.png
#   inflating: data/data/masks/00560.png
#   inflating: data/data/masks/00561.png
#   inflating: data/data/masks/00562.png
#   inflating: data/data/masks/00563.png
#   inflating: data/data/masks/00564.png
#   inflating: data/data/masks/00565.png
#   inflating: data/data/masks/00566.png
#   inflating: data/data/masks/00567.png
#   inflating: data/data/masks/00568.png
#   inflating: data/data/masks/00569.png
#   inflating: data/data/masks/00570.png
#   inflating: data/data/masks/00571.png
#   inflating: data/data/masks/00572.png
#   inflating: data/data/masks/00573.png
#   inflating: data/data/masks/00574.png
#   inflating: data/data/masks/00575.png
#   inflating: data/data/masks/00576.png
#   inflating: data/data/masks/00577.png
#   inflating: data/data/masks/00578.png
#   inflating: data/data/masks/00579.png
#   inflating: data/data/masks/00580.png
#   inflating: data/data/masks/00581.png
#   inflating: data/data/masks/00582.png
#   inflating: data/data/masks/00583.png
#   inflating: data/data/masks/00584.png
#   inflating: data/data/masks/00585.png
#   inflating: data/data/masks/00586.png
#   inflating: data/data/masks/00587.png

# %% [markdown]
# # **Data Augmentation**

# %% [markdown]
# **Gaussian Noise - Rotate 90° and 180° - Brightness - Contrast**

# %%
import os
import cv2
import numpy as np
import shutil

# Function to add Gaussian noise to an image
def add_noise(image, mean=0, std_dev=0.66):
    noise = np.random.normal(mean, std_dev, image.shape).astype(np.uint8)
    noisy_image = cv2.add(image, noise)
    return noisy_image

# Function to randomly adjust brightness and contrast of an image
def change_brightness_contrast(image, alpha=None, beta=None):
    if alpha is None:
        alpha = np.random.uniform(0.8, 2)  # Random scale factor for brightness
    if beta is None:
        beta = np.random.randint(-60, 60)  # Random offset for contrast
    adjusted_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)
    return adjusted_image

# Function to apply augmentations (rotations, noise, brightness/contrast) to an image and mask
def augment_image_and_mask(image, mask):
    augmented_images = [image]
    augmented_masks = [mask]

    # Rotate image and mask 90 degrees
    rotated_90 = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
    rotated_mask_90 = cv2.rotate(mask, cv2.ROTATE_90_CLOCKWISE)
    augmented_images.append(rotated_90)
    augmented_masks.append(rotated_mask_90)

    # Rotate image and mask 180 degrees
    rotated_180 = cv2.rotate(image, cv2.ROTATE_180)
    rotated_mask_180 = cv2.rotate(mask, cv2.ROTATE_180)
    augmented_images.append(rotated_180)
    augmented_masks.append(rotated_mask_180)

    # Apply noise to the image
    noisy_image = add_noise(image)
    augmented_images.append(noisy_image)
    augmented_masks.append(mask.copy())

    # Apply brightness and contrast adjustment
    bright_contrast_image = change_brightness_contrast(image)
    augmented_images.append(bright_contrast_image)
    augmented_masks.append(mask.copy())

    return augmented_images, augmented_masks

# Paths to original and augmented image/mask directories
image_dir = '/content/data/data/images/'
mask_dir = '/content/data/data/masks/'
aug_image_dir = 'augment_data_img4'
aug_mask_dir = 'augment_data_mask4'
combined_aug_dir = 'combined_augmented_data4'
zip_dir = 'augmented_data4.zip'

# Create directories for augmented images and masks
os.makedirs(aug_image_dir, exist_ok=True)
os.makedirs(aug_mask_dir, exist_ok=True)
os.makedirs(combined_aug_dir, exist_ok=True)

# Get list of all image and mask files
image_files = [f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.png'))]
mask_files = [f for f in os.listdir(mask_dir) if f.endswith(('.jpg', '.png'))]

# Check if the count of images and masks match
if len(image_files) != len(mask_files):
    raise ValueError("The number of images and masks must be equal.")

# Apply augmentation for each image and corresponding mask
for img_file, mask_file in zip(image_files, mask_files):
    image_path = os.path.join(image_dir, img_file)
    mask_path = os.path.join(mask_dir, mask_file)
    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if image is None:
        raise ValueError(f"Error loading image at {image_path}")
    if mask is None:
        raise ValueError(f"Error loading mask at {mask_path}")

    # Generate augmented versions of image and mask
    augmented_images, augmented_masks = augment_image_and_mask(image, mask)

    # Save each augmented image and mask
    for i, (aug_img, aug_mask) in enumerate(zip(augmented_images, augmented_masks)):
        output_img_path = os.path.join(aug_image_dir, f'augmented_{img_file[:-4]}_{i}.jpg')
        output_mask_path = os.path.join(aug_mask_dir, f'augmented_{mask_file[:-4]}_{i}.png')
        cv2.imwrite(output_img_path, aug_img)
        cv2.imwrite(output_mask_path, aug_mask)
        print(f'Image and mask saved: {output_img_path}, {output_mask_path}')

# Copy augmented data to combined directory for easier access
shutil.copytree(aug_image_dir, os.path.join(combined_aug_dir, 'images'))
shutil.copytree(aug_mask_dir, os.path.join(combined_aug_dir, 'masks'))

# Compress the combined augmented data into a zip file
shutil.make_archive(zip_dir[:-4], 'zip', root_dir='.', base_dir=combined_aug_dir)

# Print the total number of augmented images and masks created
num_aug_images = len(os.listdir(aug_image_dir))
num_aug_masks = len(os.listdir(aug_mask_dir))

print(f'Total augmented images: {num_aug_images}')
print(f'Total augmented masks: {num_aug_masks}')

# %% [markdown]
# # **build train and val directories**

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Paths to the original directories of images and masks
image_dir = '/content/combined_augmented_data4/images/'
mask_dir = '/content/combined_augmented_data4/masks/'

# Directory for organized train and validation sets
output_dir = 'augmented_data'

# Define subdirectories for training and validation images and masks
train_images_dir = os.path.join(output_dir, 'train_images')
train_masks_dir = os.path.join(output_dir, 'train_masks')
val_images_dir = os.path.join(output_dir, 'valid_images')
val_masks_dir = os.path.join(output_dir, 'valid_masks')

# Create directories for training and validation data if they don’t exist
os.makedirs(train_images_dir, exist_ok=True)
os.makedirs(train_masks_dir, exist_ok=True)
os.makedirs(val_images_dir, exist_ok=True)
os.makedirs(val_masks_dir, exist_ok=True)

# List of image and mask files, sorted to ensure alignment between pairs
images = sorted(os.listdir(image_dir))
masks = sorted(os.listdir(mask_dir))

# Check that the number of images matches the number of masks
assert len(images) == len(masks)

# Split data into training (80%) and validation (20%) sets
train_images, val_images, train_masks, val_masks = train_test_split(
    images, masks, test_size=0.2, random_state=42
)

# Function to copy files from a source directory to a destination directory
def copy_files(file_list, source_dir, destination_dir):
    for file_name in file_list:
        shutil.copy(os.path.join(source_dir, file_name), destination_dir)

# Copy training images and masks to their respective directories
copy_files(train_images, image_dir, train_images_dir)
copy_files(train_masks, mask_dir, train_masks_dir)

# Copy validation images and masks to their respective directories
copy_files(val_images, image_dir, val_images_dir)
copy_files(val_masks, mask_dir, val_masks_dir)

# %% [markdown]
# # **Data Seperation**

# %%
import os
import shutil
import random

# Base directory containing all data
DATA_DIR = '/content/augmented_data/'

# Define directories for training images and masks
train_images = os.path.join(DATA_DIR, 'train_images')
train_masks = os.path.join(DATA_DIR, 'train_masks')

# Display initial counts of images and masks in the training directory
print("Before Splitting the train and test")
print(len(os.listdir(train_images)))
print(len(os.listdir(train_masks)))

# Define directories for testing and validation images and masks
test_images = os.path.join(DATA_DIR, 'test_images')
test_masks = os.path.join(DATA_DIR, 'test_masks')
valid_images = os.path.join(DATA_DIR, 'valid_images')
valid_masks = os.path.join(DATA_DIR, 'valid_masks')

# Create test directories if they don't exist
os.makedirs(test_images, exist_ok=True)
os.makedirs(test_masks, exist_ok=True)

# Get lists of images and masks, sorted to keep them in corresponding order
image_files = os.listdir(train_images)
mask_files = os.listdir(train_masks)
image_files.sort()
mask_files.sort()

# Ensure the same number of images and masks
assert len(image_files) == len(mask_files)

# Calculate the number of samples to move to the test set (10% of data)
num_test_samples = int(len(image_files) * 0.1)

# Randomly select indices for test samples
test_indices = random.sample(range(len(image_files)), num_test_samples)

# Move selected images and masks to the test directories
for i in test_indices:
    image_file = image_files[i]
    mask_file = mask_files[i]

    image_src = os.path.join(train_images, image_file)
    image_dest = os.path.join(test_images, image_file)

    mask_src = os.path.join(train_masks, mask_file)
    mask_dest = os.path.join(test_masks, mask_file)

    shutil.move(image_src, image_dest)
    shutil.move(mask_src, mask_dest)

# Print the total number of files moved to the test set
print(f"Moved {num_test_samples} images and masks to the test set.")

# %% [markdown]
# # **Section2:Library import and installation and Gdrive connect**

# %%
# !pip install -q -U segmentation-models-pytorch albumentations > /dev/null

# %% [markdown]
# **`segmentation-models-pytorch` is a PyTorch-based library that provides implementations of cutting-edge image segmentation architectures such as U-Net, DeepLabV3+, and FPN. It includes support for pre-trained models, various loss functions, and evaluation metrics, making it easier to develop and optimize segmentation tasks.**

# %%
# !pip install gdown

# %%
# !pip install segmentation-models-pytorch
# Out:
# Requirement already satisfied: segmentation-models-pytorch in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: efficientnet-pytorch==0.7.1 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.7.1)
# Requirement already satisfied: huggingface-hub>=0.24.6 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.24.7)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (10.4.0)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.7.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (1.16.0)
# Requirement already satisfied: timm==0.9.7 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.9.7)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.20.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (4.66.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.5.0+cu121)
# Requirement already satisfied: munch in /usr/local/lib/python3.10/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.7->segmentation-models-pytorch) (6.0.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.9.7->segmentation-models-pytorch) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.26.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.0.2)

# %%
import os, cv2
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
import segmentation_models_pytorch as smp
from torch.utils.tensorboard import SummaryWriter
import datetime
import matplotlib.pyplot as plt
import albumentations as album
import random

# %% [markdown]
# # **the main dataset for testing all models**

# %% [markdown]
# **connect to GDrive for saving model weights**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **import the main Build for testing model outputs**

# %%
# !gdown --id 1qoadjw0j-_ZMDOJ-OvC7gL9jFDooGDCA
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1qoadjw0j-_ZMDOJ-OvC7gL9jFDooGDCA
# From (redirected): https://drive.google.com/uc?id=1qoadjw0j-_ZMDOJ-OvC7gL9jFDooGDCA&confirm=t&uuid=093e851c-4d6f-4e03-a927-7d5ecef03ab1
# To: /content/dataset.zip
# 100% 709M/709M [00:16<00:00, 44.0MB/s]

# %%
# !unzip "/content/dataset.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: augmented_data/train_images/augmented_00314_2.jpg
#   inflating: augmented_data/train_images/augmented_00363_2.jpg
#   inflating: augmented_data/train_images/augmented_00360_1.jpg
#   inflating: augmented_data/train_images/augmented_00134_3.jpg
#   inflating: augmented_data/train_images/augmented_00504_0.jpg
#   inflating: augmented_data/train_images/augmented_00549_4.jpg
#   inflating: augmented_data/train_images/augmented_00500_0.jpg
#   inflating: augmented_data/train_images/augmented_00468_4.jpg
#   inflating: augmented_data/train_images/augmented_00296_2.jpg
#   inflating: augmented_data/train_images/augmented_00552_3.jpg
#   inflating: augmented_data/train_images/augmented_00579_4.jpg
#   inflating: augmented_data/train_images/augmented_00483_0.jpg
#   inflating: augmented_data/train_images/augmented_00482_2.jpg
#   inflating: augmented_data/train_images/augmented_00584_0.jpg
#   inflating: augmented_data/train_images/augmented_00218_3.jpg
#   inflating: augmented_data/train_images/augmented_00438_3.jpg
#   inflating: augmented_data/train_images/augmented_00152_3.jpg
#   inflating: augmented_data/train_images/augmented_00393_1.jpg
#   inflating: augmented_data/train_images/augmented_00260_1.jpg
#   inflating: augmented_data/train_images/augmented_00078_1.jpg
#   inflating: augmented_data/train_images/augmented_00397_4.jpg
#   inflating: augmented_data/train_images/augmented_00189_0.jpg
#   inflating: augmented_data/train_images/augmented_00367_0.jpg
#   inflating: augmented_data/train_images/augmented_00147_3.jpg
#   inflating: augmented_data/train_images/augmented_00193_0.jpg
#   inflating: augmented_data/train_images/augmented_00075_4.jpg
#   inflating: augmented_data/train_images/augmented_00244_2.jpg
#   inflating: augmented_data/train_images/augmented_00004_1.jpg
#   inflating: augmented_data/train_images/augmented_00151_3.jpg
#   inflating: augmented_data/train_images/augmented_00569_2.jpg
#   inflating: augmented_data/train_images/augmented_00562_1.jpg
#   inflating: augmented_data/train_images/augmented_00488_0.jpg
#   inflating: augmented_data/train_images/augmented_00058_2.jpg
#   inflating: augmented_data/train_images/augmented_00295_1.jpg
#   inflating: augmented_data/train_images/augmented_00220_0.jpg
#   inflating: augmented_data/train_images/augmented_00270_4.jpg
#   inflating: augmented_data/train_images/augmented_00178_2.jpg
#   inflating: augmented_data/train_images/augmented_00224_3.jpg
#   inflating: augmented_data/train_images/augmented_00227_2.jpg
#   inflating: augmented_data/train_images/augmented_00443_2.jpg
#   inflating: augmented_data/train_images/augmented_00002_3.jpg
#   inflating: augmented_data/train_images/augmented_00339_4.jpg
#   inflating: augmented_data/train_images/augmented_00132_4.jpg
#   inflating: augmented_data/train_images/augmented_00456_3.jpg
#   inflating: augmented_data/train_images/augmented_00413_4.jpg
#   inflating: augmented_data/train_images/augmented_00376_1.jpg
#   inflating: augmented_data/train_images/augmented_00211_1.jpg
#   inflating: augmented_data/train_images/augmented_00277_4.jpg
#   inflating: augmented_data/train_images/augmented_00395_4.jpg
#   inflating: augmented_data/train_images/augmented_00492_0.jpg
#   inflating: augmented_data/train_images/augmented_00063_2.jpg
#   inflating: augmented_data/train_images/augmented_00136_2.jpg
#   inflating: augmented_data/train_images/augmented_00074_4.jpg
#   inflating: augmented_data/train_images/augmented_00297_2.jpg
#   inflating: augmented_data/train_images/augmented_00460_3.jpg
#   inflating: augmented_data/train_images/augmented_00270_1.jpg
#   inflating: augmented_data/train_images/augmented_00575_4.jpg
#   inflating: augmented_data/train_images/augmented_00014_2.jpg
#   inflating: augmented_data/train_images/augmented_00326_4.jpg
#   inflating: augmented_data/train_images/augmented_00193_4.jpg
#   inflating: augmented_data/train_images/augmented_00017_3.jpg
#   inflating: augmented_data/train_images/augmented_00142_2.jpg
#   inflating: augmented_data/train_images/augmented_00448_2.jpg
#   inflating: augmented_data/train_images/augmented_00178_4.jpg
#   inflating: augmented_data/train_images/augmented_00068_1.jpg
#   inflating: augmented_data/train_images/augmented_00346_3.jpg
#   inflating: augmented_data/train_images/augmented_00395_1.jpg
#   inflating: augmented_data/train_images/augmented_00441_4.jpg
#   inflating: augmented_data/train_images/augmented_00291_0.jpg
#   inflating: augmented_data/train_images/augmented_00536_4.jpg
#   inflating: augmented_data/train_images/augmented_00315_2.jpg
#   inflating: augmented_data/train_images/augmented_00190_3.jpg
#   inflating: augmented_data/train_images/augmented_00348_4.jpg
#   inflating: augmented_data/train_images/augmented_00459_0.jpg
#   inflating: augmented_data/train_images/augmented_00465_3.jpg
#   inflating: augmented_data/train_images/augmented_00316_2.jpg
#   inflating: augmented_data/train_images/augmented_00449_4.jpg
#   inflating: augmented_data/train_images/augmented_00323_3.jpg
#   inflating: augmented_data/train_images/augmented_00287_0.jpg
#   inflating: augmented_data/train_images/augmented_00095_2.jpg
#   inflating: augmented_data/train_images/augmented_00283_4.jpg
#   inflating: augmented_data/train_images/augmented_00265_3.jpg
#   inflating: augmented_data/train_images/augmented_00536_0.jpg
#   inflating: augmented_data/train_images/augmented_00232_0.jpg
#   inflating: augmented_data/train_images/augmented_00162_1.jpg
#   inflating: augmented_data/train_images/augmented_00397_3.jpg
#   inflating: augmented_data/train_images/augmented_00505_2.jpg
#   inflating: augmented_data/train_images/augmented_00379_4.jpg
#   inflating: augmented_data/train_images/augmented_00250_4.jpg
#   inflating: augmented_data/train_images/augmented_00487_2.jpg
#   inflating: augmented_data/train_images/augmented_00231_3.jpg
#   inflating: augmented_data/train_images/augmented_00259_1.jpg
#   inflating: augmented_data/train_images/augmented_00551_1.jpg
#   inflating: augmented_data/train_images/augmented_00569_0.jpg
#   inflating: augmented_data/train_images/augmented_00183_1.jpg
#   inflating: augmented_data/train_images/augmented_00533_2.jpg
#   inflating: augmented_data/train_images/augmented_00080_1.jpg
#   inflating: augmented_data/train_images/augmented_00128_3.jpg
#   inflating: augmented_data/train_images/augmented_00541_4.jpg
#   inflating: augmented_data/train_images/augmented_00001_4.jpg
#   inflating: augmented_data/train_images/augmented_00358_2.jpg
#   inflating: augmented_data/train_images/augmented_00524_0.jpg
#   inflating: augmented_data/train_images/augmented_00202_3.jpg
#   inflating: augmented_data/train_images/augmented_00526_0.jpg
#   inflating: augmented_data/train_images/augmented_00375_2.jpg
#   inflating: augmented_data/train_images/augmented_00124_3.jpg
#   inflating: augmented_data/train_images/augmented_00583_0.jpg
#   inflating: augmented_data/train_images/augmented_00249_2.jpg
#   inflating: augmented_data/train_images/augmented_00377_2.jpg
#   inflating: augmented_data/train_images/augmented_00434_3.jpg
#   inflating: augmented_data/train_images/augmented_00502_2.jpg
#   inflating: augmented_data/train_images/augmented_00388_4.jpg
#   inflating: augmented_data/train_images/augmented_00431_0.jpg
#   inflating: augmented_data/train_images/augmented_00146_1.jpg
#   inflating: augmented_data/train_images/augmented_00145_3.jpg
#   inflating: augmented_data/train_images/augmented_00257_0.jpg
#   inflating: augmented_data/train_images/augmented_00288_4.jpg
#   inflating: augmented_data/train_images/augmented_00541_0.jpg
#   inflating: augmented_data/train_images/augmented_00142_1.jpg
#   inflating: augmented_data/train_images/augmented_00277_0.jpg
#   inflating: augmented_data/train_images/augmented_00048_1.jpg
#   inflating: augmented_data/train_images/augmented_00321_4.jpg
#   inflating: augmented_data/train_images/augmented_00208_2.jpg
#   inflating: augmented_data/train_images/augmented_00553_0.jpg
#   inflating: augmented_data/train_images/augmented_00473_1.jpg
#   inflating: augmented_data/train_images/augmented_00150_4.jpg
#   inflating: augmented_data/train_images/augmented_00022_3.jpg
#   inflating: augmented_data/train_images/augmented_00289_4.jpg
#   inflating: augmented_data/train_images/augmented_00365_0.jpg
#   inflating: augmented_data/train_images/augmented_00096_2.jpg
#   inflating: augmented_data/train_images/augmented_00082_2.jpg
#   inflating: augmented_data/train_images/augmented_00191_0.jpg
#   inflating: augmented_data/train_images/augmented_00197_3.jpg
#   inflating: augmented_data/train_images/augmented_00005_0.jpg
#   inflating: augmented_data/train_images/augmented_00317_3.jpg
#   inflating: augmented_data/train_images/augmented_00553_4.jpg
#   inflating: augmented_data/train_images/augmented_00213_1.jpg
#   inflating: augmented_data/train_images/augmented_00399_1.jpg
#   inflating: augmented_data/train_images/augmented_00026_3.jpg
#   inflating: augmented_data/train_images/augmented_00366_0.jpg
#   inflating: augmented_data/train_images/augmented_00374_2.jpg
#   inflating: augmented_data/train_images/augmented_00018_4.jpg
#   inflating: augmented_data/train_images/augmented_00389_2.jpg
#   inflating: augmented_data/train_images/augmented_00055_4.jpg
#   inflating: augmented_data/train_images/augmented_00063_4.jpg
#   inflating: augmented_data/train_images/augmented_00022_0.jpg
#   inflating: augmented_data/train_images/augmented_00573_1.jpg
#   inflating: augmented_data/train_images/augmented_00313_2.jpg
#   inflating: augmented_data/train_images/augmented_00387_4.jpg
#   inflating: augmented_data/train_images/augmented_00264_3.jpg
#   inflating: augmented_data/train_images/augmented_00415_1.jpg
#   inflating: augmented_data/train_images/augmented_00281_4.jpg
#   inflating: augmented_data/train_images/augmented_00280_2.jpg
#   inflating: augmented_data/train_images/augmented_00134_2.jpg
#   inflating: augmented_data/train_images/augmented_00176_2.jpg
#   inflating: augmented_data/train_images/augmented_00234_4.jpg
#   inflating: augmented_data/train_images/augmented_00583_1.jpg
#   inflating: augmented_data/train_images/augmented_00269_2.jpg
#   inflating: augmented_data/train_images/augmented_00173_1.jpg
#   inflating: augmented_data/train_images/augmented_00398_3.jpg
#   inflating: augmented_data/train_images/augmented_00315_3.jpg
#   inflating: augmented_data/train_images/augmented_00185_2.jpg
#   inflating: augmented_data/train_images/augmented_00241_4.jpg
#   inflating: augmented_data/train_images/augmented_00010_3.jpg
#   inflating: augmented_data/train_images/augmented_00562_4.jpg
#   inflating: augmented_data/train_images/augmented_00282_1.jpg
#   inflating: augmented_data/train_images/augmented_00500_1.jpg
#   inflating: augmented_data/train_images/augmented_00178_3.jpg
#   inflating: augmented_data/train_images/augmented_00240_2.jpg
#   inflating: augmented_data/train_images/augmented_00265_0.jpg
#   inflating: augmented_data/train_images/augmented_00430_1.jpg
#   inflating: augmented_data/train_images/augmented_00511_4.jpg
#   inflating: augmented_data/train_images/augmented_00420_1.jpg
#   inflating: augmented_data/train_images/augmented_00166_2.jpg
#   inflating: augmented_data/train_images/augmented_00386_4.jpg
#   inflating: augmented_data/train_images/augmented_00521_0.jpg
#   inflating: augmented_data/train_images/augmented_00031_3.jpg
#   inflating: augmented_data/train_images/augmented_00529_0.jpg
#   inflating: augmented_data/train_images/augmented_00365_2.jpg
#   inflating: augmented_data/train_images/augmented_00512_3.jpg
#   inflating: augmented_data/train_images/augmented_00087_0.jpg
#   inflating: augmented_data/train_images/augmented_00487_0.jpg
#   inflating: augmented_data/train_images/augmented_00137_1.jpg
#   inflating: augmented_data/train_images/augmented_00411_2.jpg
#   inflating: augmented_data/train_images/augmented_00105_1.jpg
#   inflating: augmented_data/train_images/augmented_00056_4.jpg
#   inflating: augmented_data/train_images/augmented_00367_3.jpg
#   inflating: augmented_data/train_images/augmented_00256_2.jpg
#   inflating: augmented_data/train_images/augmented_00045_3.jpg
#   inflating: augmented_data/train_images/augmented_00033_1.jpg
#   inflating: augmented_data/train_images/augmented_00512_2.jpg
#   inflating: augmented_data/train_images/augmented_00421_1.jpg
#   inflating: augmented_data/train_images/augmented_00139_4.jpg
#   inflating: augmented_data/train_images/augmented_00270_3.jpg
#   inflating: augmented_data/train_images/augmented_00141_3.jpg
#   inflating: augmented_data/train_images/augmented_00331_4.jpg
#   inflating: augmented_data/train_images/augmented_00089_0.jpg
#   inflating: augmented_data/train_images/augmented_00132_1.jpg
#   inflating: augmented_data/train_images/augmented_00033_0.jpg
#   inflating: augmented_data/train_images/augmented_00401_2.jpg
#   inflating: augmented_data/train_images/augmented_00126_4.jpg
#   inflating: augmented_data/train_images/augmented_00239_2.jpg
#   inflating: augmented_data/train_images/augmented_00477_3.jpg
#   inflating: augmented_data/train_images/augmented_00384_1.jpg
#   inflating: augmented_data/train_images/augmented_00364_0.jpg
#   inflating: augmented_data/train_images/augmented_00358_4.jpg
#   inflating: augmented_data/train_images/augmented_00142_0.jpg
#   inflating: augmented_data/train_images/augmented_00145_0.jpg
#   inflating: augmented_data/train_images/augmented_00162_4.jpg
#   inflating: augmented_data/train_images/augmented_00244_0.jpg
#   inflating: augmented_data/train_images/augmented_00405_4.jpg
#   inflating: augmented_data/train_images/augmented_00482_3.jpg
#   inflating: augmented_data/train_images/augmented_00005_3.jpg
#   inflating: augmented_data/train_images/augmented_00330_3.jpg
#   inflating: augmented_data/train_images/augmented_00252_2.jpg
#   inflating: augmented_data/train_images/augmented_00302_0.jpg
#   inflating: augmented_data/train_images/augmented_00014_4.jpg
#   inflating: augmented_data/train_images/augmented_00567_0.jpg
#   inflating: augmented_data/train_images/augmented_00263_4.jpg
#   inflating: augmented_data/train_images/augmented_00508_4.jpg
#   inflating: augmented_data/train_images/augmented_00202_0.jpg
#   inflating: augmented_data/train_images/augmented_00248_0.jpg
#   inflating: augmented_data/train_images/augmented_00141_2.jpg
#   inflating: augmented_data/train_images/augmented_00421_2.jpg
#   inflating: augmented_data/train_images/augmented_00160_3.jpg
#   inflating: augmented_data/train_images/augmented_00266_0.jpg
#   inflating: augmented_data/train_images/augmented_00109_1.jpg
#   inflating: augmented_data/train_images/augmented_00052_1.jpg
#   inflating: augmented_data/train_images/augmented_00386_0.jpg
#   inflating: augmented_data/train_images/augmented_00125_4.jpg
#   inflating: augmented_data/train_images/augmented_00192_0.jpg
#   inflating: augmented_data/train_images/augmented_00180_4.jpg
#   inflating: augmented_data/train_images/augmented_00569_1.jpg
#   inflating: augmented_data/train_images/augmented_00313_4.jpg
#   inflating: augmented_data/train_images/augmented_00382_4.jpg
#   inflating: augmented_data/train_images/augmented_00215_0.jpg
#   inflating: augmented_data/train_images/augmented_00383_1.jpg
#   inflating: augmented_data/train_images/augmented_00119_0.jpg
#   inflating: augmented_data/train_images/augmented_00450_4.jpg
#   inflating: augmented_data/train_images/augmented_00269_0.jpg
#   inflating: augmented_data/train_images/augmented_00318_0.jpg
#   inflating: augmented_data/train_images/augmented_00582_3.jpg
#   inflating: augmented_data/train_images/augmented_00471_3.jpg
#   inflating: augmented_data/train_images/augmented_00430_4.jpg
#   inflating: augmented_data/train_images/augmented_00124_4.jpg
#   inflating: augmented_data/train_images/augmented_00493_0.jpg
#   inflating: augmented_data/train_images/augmented_00377_4.jpg
#   inflating: augmented_data/train_images/augmented_00052_4.jpg
#   inflating: augmented_data/train_images/augmented_00392_3.jpg
#   inflating: augmented_data/train_images/augmented_00038_0.jpg
#   inflating: augmented_data/train_images/augmented_00157_3.jpg
#   inflating: augmented_data/train_images/augmented_00459_1.jpg
#   inflating: augmented_data/train_images/augmented_00337_0.jpg
#   inflating: augmented_data/train_images/augmented_00269_3.jpg
#   inflating: augmented_data/train_images/augmented_00209_1.jpg
#   inflating: augmented_data/train_images/augmented_00519_2.jpg
#   inflating: augmented_data/train_images/augmented_00409_0.jpg
#   inflating: augmented_data/train_images/augmented_00327_2.jpg
#   inflating: augmented_data/train_images/augmented_00492_1.jpg
#   inflating: augmented_data/train_images/augmented_00486_0.jpg
#   inflating: augmented_data/train_images/augmented_00482_1.jpg
#   inflating: augmented_data/train_images/augmented_00004_0.jpg
#   inflating: augmented_data/train_images/augmented_00339_1.jpg
#   inflating: augmented_data/train_images/augmented_00570_0.jpg
#   inflating: augmented_data/train_images/augmented_00456_2.jpg
#   inflating: augmented_data/train_images/augmented_00478_3.jpg
#   inflating: augmented_data/train_images/augmented_00343_4.jpg
#   inflating: augmented_data/train_images/augmented_00048_2.jpg
#   inflating: augmented_data/train_images/augmented_00376_3.jpg
#   inflating: augmented_data/train_images/augmented_00329_0.jpg
#   inflating: augmented_data/train_images/augmented_00404_1.jpg
#   inflating: augmented_data/train_images/augmented_00566_2.jpg
#   inflating: augmented_data/train_images/augmented_00049_0.jpg
#   inflating: augmented_data/train_images/augmented_00194_4.jpg
#   inflating: augmented_data/train_images/augmented_00235_2.jpg
#   inflating: augmented_data/train_images/augmented_00379_2.jpg
#   inflating: augmented_data/train_images/augmented_00039_3.jpg
#   inflating: augmented_data/train_images/augmented_00320_4.jpg
#   inflating: augmented_data/train_images/augmented_00239_3.jpg
#   inflating: augmented_data/train_images/augmented_00370_4.jpg
#   inflating: augmented_data/train_images/augmented_00420_0.jpg
#   inflating: augmented_data/train_images/augmented_00058_3.jpg
#   inflating: augmented_data/train_images/augmented_00479_3.jpg
#   inflating: augmented_data/train_images/augmented_00460_2.jpg
#   inflating: augmented_data/train_images/augmented_00000_4.jpg
#   inflating: augmented_data/train_images/augmented_00237_4.jpg
#   inflating: augmented_data/train_images/augmented_00408_1.jpg
#   inflating: augmented_data/train_images/augmented_00352_0.jpg
#   inflating: augmented_data/train_images/augmented_00518_2.jpg
#   inflating: augmented_data/train_images/augmented_00253_0.jpg
#   inflating: augmented_data/train_images/augmented_00481_0.jpg
#   inflating: augmented_data/train_images/augmented_00448_1.jpg
#   inflating: augmented_data/train_images/augmented_00438_2.jpg
#   inflating: augmented_data/train_images/augmented_00585_2.jpg
#   inflating: augmented_data/train_images/augmented_00304_3.jpg
#   inflating: augmented_data/train_images/augmented_00550_1.jpg
#   inflating: augmented_data/train_images/augmented_00389_1.jpg
#   inflating: augmented_data/train_images/augmented_00148_0.jpg
#   inflating: augmented_data/train_images/augmented_00463_1.jpg
#   inflating: augmented_data/train_images/augmented_00304_2.jpg
#   inflating: augmented_data/train_images/augmented_00275_3.jpg
#   inflating: augmented_data/train_images/augmented_00141_4.jpg
#   inflating: augmented_data/train_images/augmented_00443_4.jpg
#   inflating: augmented_data/train_images/augmented_00516_3.jpg
#   inflating: augmented_data/train_images/augmented_00531_0.jpg
#   inflating: augmented_data/train_images/augmented_00048_4.jpg
#   inflating: augmented_data/train_images/augmented_00234_1.jpg
#   inflating: augmented_data/train_images/augmented_00187_4.jpg
#   inflating: augmented_data/train_images/augmented_00065_1.jpg
#   inflating: augmented_data/train_images/augmented_00493_4.jpg
#   inflating: augmented_data/train_images/augmented_00112_2.jpg
#   inflating: augmented_data/train_images/augmented_00168_1.jpg
#   inflating: augmented_data/train_images/augmented_00068_3.jpg
#   inflating: augmented_data/train_images/augmented_00399_4.jpg
#   inflating: augmented_data/train_images/augmented_00192_1.jpg
#   inflating: augmented_data/train_images/augmented_00089_3.jpg
#   inflating: augmented_data/train_images/augmented_00305_3.jpg
#   inflating: augmented_data/train_images/augmented_00417_3.jpg
#   inflating: augmented_data/train_images/augmented_00233_0.jpg
#   inflating: augmented_data/train_images/augmented_00568_0.jpg
#   inflating: augmented_data/train_images/augmented_00054_4.jpg
#   inflating: augmented_data/train_images/augmented_00496_0.jpg
#   inflating: augmented_data/train_images/augmented_00573_0.jpg
#   inflating: augmented_data/train_images/augmented_00236_1.jpg
#   inflating: augmented_data/train_images/augmented_00208_0.jpg
#   inflating: augmented_data/train_images/augmented_00031_0.jpg
#   inflating: augmented_data/train_images/augmented_00264_4.jpg
#   inflating: augmented_data/train_images/augmented_00402_3.jpg
#   inflating: augmented_data/train_images/augmented_00426_2.jpg
#   inflating: augmented_data/train_images/augmented_00251_1.jpg
#   inflating: augmented_data/train_images/augmented_00358_1.jpg
#   inflating: augmented_data/train_images/augmented_00444_2.jpg
#   inflating: augmented_data/train_images/augmented_00052_3.jpg
#   inflating: augmented_data/train_images/augmented_00391_0.jpg
#   inflating: augmented_data/train_images/augmented_00430_0.jpg
#   inflating: augmented_data/train_images/augmented_00131_0.jpg
#   inflating: augmented_data/train_images/augmented_00035_1.jpg
#   inflating: augmented_data/train_images/augmented_00361_2.jpg
#   inflating: augmented_data/train_images/augmented_00515_0.jpg
#   inflating: augmented_data/train_images/augmented_00068_0.jpg
#   inflating: augmented_data/train_images/augmented_00009_1.jpg
#   inflating: augmented_data/train_images/augmented_00120_4.jpg
#   inflating: augmented_data/train_images/augmented_00405_1.jpg
#   inflating: augmented_data/train_images/augmented_00004_3.jpg
#   inflating: augmented_data/train_images/augmented_00079_1.jpg
#   inflating: augmented_data/train_images/augmented_00543_1.jpg
#   inflating: augmented_data/train_images/augmented_00275_1.jpg
#   inflating: augmented_data/train_images/augmented_00374_3.jpg
#   inflating: augmented_data/train_images/augmented_00089_2.jpg
#   inflating: augmented_data/train_images/augmented_00086_4.jpg
#   inflating: augmented_data/train_images/augmented_00346_0.jpg
#   inflating: augmented_data/train_images/augmented_00300_4.jpg
#   inflating: augmented_data/train_images/augmented_00479_0.jpg
#   inflating: augmented_data/train_images/augmented_00123_4.jpg
#   inflating: augmented_data/train_images/augmented_00046_4.jpg
#   inflating: augmented_data/train_images/augmented_00274_2.jpg
#   inflating: augmented_data/train_images/augmented_00351_3.jpg
#   inflating: augmented_data/train_images/augmented_00466_4.jpg
#   inflating: augmented_data/train_images/augmented_00458_1.jpg
#   inflating: augmented_data/train_images/augmented_00279_1.jpg
#   inflating: augmented_data/train_images/augmented_00040_4.jpg
#   inflating: augmented_data/train_images/augmented_00396_2.jpg
#   inflating: augmented_data/train_images/augmented_00294_3.jpg
#   inflating: augmented_data/train_images/augmented_00225_4.jpg
#   inflating: augmented_data/train_images/augmented_00052_2.jpg
#   inflating: augmented_data/train_images/augmented_00019_4.jpg
#   inflating: augmented_data/train_images/augmented_00214_2.jpg
#   inflating: augmented_data/train_images/augmented_00114_1.jpg
#   inflating: augmented_data/train_images/augmented_00145_1.jpg
#   inflating: augmented_data/train_images/augmented_00132_2.jpg
#   inflating: augmented_data/train_images/augmented_00511_3.jpg
#   inflating: augmented_data/train_images/augmented_00067_2.jpg
#   inflating: augmented_data/train_images/augmented_00434_1.jpg
#   inflating: augmented_data/train_images/augmented_00469_2.jpg
#   inflating: augmented_data/train_images/augmented_00183_4.jpg
#   inflating: augmented_data/train_images/augmented_00244_3.jpg
#   inflating: augmented_data/train_images/augmented_00121_4.jpg
#   inflating: augmented_data/train_images/augmented_00163_4.jpg
#   inflating: augmented_data/train_images/augmented_00394_3.jpg
#   inflating: augmented_data/train_images/augmented_00103_1.jpg
#   inflating: augmented_data/train_images/augmented_00508_2.jpg
#   inflating: augmented_data/train_images/augmented_00439_1.jpg
#   inflating: augmented_data/train_images/augmented_00050_0.jpg
#   inflating: augmented_data/train_images/augmented_00195_2.jpg
#   inflating: augmented_data/train_images/augmented_00329_4.jpg
#   inflating: augmented_data/train_images/augmented_00537_0.jpg
#   inflating: augmented_data/train_images/augmented_00027_3.jpg
#   inflating: augmented_data/train_images/augmented_00276_4.jpg
#   inflating: augmented_data/train_images/augmented_00454_1.jpg
#   inflating: augmented_data/train_images/augmented_00238_1.jpg
#   inflating: augmented_data/train_images/augmented_00499_0.jpg
#   inflating: augmented_data/train_images/augmented_00028_0.jpg
#   inflating: augmented_data/train_images/augmented_00490_4.jpg
#   inflating: augmented_data/train_images/augmented_00268_4.jpg
#   inflating: augmented_data/train_images/augmented_00416_3.jpg
#   inflating: augmented_data/train_images/augmented_00067_1.jpg
#   inflating: augmented_data/train_images/augmented_00355_3.jpg
#   inflating: augmented_data/train_images/augmented_00182_3.jpg
#   inflating: augmented_data/train_images/augmented_00227_1.jpg
#   inflating: augmented_data/train_images/augmented_00307_2.jpg
#   inflating: augmented_data/train_images/augmented_00029_1.jpg
#   inflating: augmented_data/train_images/augmented_00147_1.jpg
#   inflating: augmented_data/train_images/augmented_00354_4.jpg
#   inflating: augmented_data/train_images/augmented_00510_3.jpg
#   inflating: augmented_data/train_images/augmented_00129_0.jpg
#   inflating: augmented_data/train_images/augmented_00237_2.jpg
#   inflating: augmented_data/train_images/augmented_00536_3.jpg
#   inflating: augmented_data/train_images/augmented_00126_1.jpg
#   inflating: augmented_data/train_images/augmented_00474_2.jpg
#   inflating: augmented_data/train_images/augmented_00171_2.jpg
#   inflating: augmented_data/train_images/augmented_00256_4.jpg
#   inflating: augmented_data/train_images/augmented_00550_3.jpg
#   inflating: augmented_data/train_images/augmented_00063_1.jpg
#   inflating: augmented_data/train_images/augmented_00284_3.jpg
#   inflating: augmented_data/train_images/augmented_00445_3.jpg
#   inflating: augmented_data/train_images/augmented_00097_4.jpg
#   inflating: augmented_data/train_images/augmented_00393_2.jpg
#   inflating: augmented_data/train_images/augmented_00087_2.jpg
#   inflating: augmented_data/train_images/augmented_00074_3.jpg
#   inflating: augmented_data/train_images/augmented_00284_0.jpg
#   inflating: augmented_data/train_images/augmented_00272_0.jpg
#   inflating: augmented_data/train_images/augmented_00359_2.jpg
#   inflating: augmented_data/train_images/augmented_00053_1.jpg
#   inflating: augmented_data/train_images/augmented_00380_1.jpg
#   inflating: augmented_data/train_images/augmented_00165_2.jpg
#   inflating: augmented_data/train_images/augmented_00117_0.jpg
#   inflating: augmented_data/train_images/augmented_00197_0.jpg
#   inflating: augmented_data/train_images/augmented_00099_2.jpg
#   inflating: augmented_data/train_images/augmented_00345_4.jpg
#   inflating: augmented_data/train_images/augmented_00155_4.jpg
#   inflating: augmented_data/train_images/augmented_00380_0.jpg
#   inflating: augmented_data/train_images/augmented_00371_0.jpg
#   inflating: augmented_data/train_images/augmented_00355_0.jpg
#   inflating: augmented_data/train_images/augmented_00046_2.jpg
#   inflating: augmented_data/train_images/augmented_00448_4.jpg
#   inflating: augmented_data/train_images/augmented_00286_2.jpg
#   inflating: augmented_data/train_images/augmented_00007_2.jpg
#   inflating: augmented_data/train_images/augmented_00071_0.jpg
#   inflating: augmented_data/train_images/augmented_00558_1.jpg
#   inflating: augmented_data/train_images/augmented_00319_1.jpg
#   inflating: augmented_data/train_images/augmented_00001_1.jpg
#   inflating: augmented_data/train_images/augmented_00360_0.jpg
#   inflating: augmented_data/train_images/augmented_00065_2.jpg
#   inflating: augmented_data/train_images/augmented_00561_4.jpg
#   inflating: augmented_data/train_images/augmented_00150_2.jpg
#   inflating: augmented_data/train_images/augmented_00230_4.jpg
#   inflating: augmented_data/train_images/augmented_00147_4.jpg
#   inflating: augmented_data/train_images/augmented_00061_0.jpg
#   inflating: augmented_data/train_images/augmented_00391_4.jpg
#   inflating: augmented_data/train_images/augmented_00397_1.jpg
#   inflating: augmented_data/train_images/augmented_00340_0.jpg
#   inflating: augmented_data/train_images/augmented_00435_3.jpg
#   inflating: augmented_data/train_images/augmented_00084_1.jpg
#   inflating: augmented_data/train_images/augmented_00217_0.jpg
#   inflating: augmented_data/train_images/augmented_00156_3.jpg
#   inflating: augmented_data/train_images/augmented_00247_3.jpg
#   inflating: augmented_data/train_images/augmented_00199_2.jpg
#   inflating: augmented_data/train_images/augmented_00405_2.jpg
#   inflating: augmented_data/train_images/augmented_00143_4.jpg
#   inflating: augmented_data/train_images/augmented_00114_4.jpg
#   inflating: augmented_data/train_images/augmented_00096_1.jpg
#   inflating: augmented_data/train_images/augmented_00177_0.jpg
#   inflating: augmented_data/train_images/augmented_00479_1.jpg
#   inflating: augmented_data/train_images/augmented_00356_4.jpg
#   inflating: augmented_data/train_images/augmented_00520_4.jpg
#   inflating: augmented_data/train_images/augmented_00455_3.jpg
#   inflating: augmented_data/train_images/augmented_00545_3.jpg
#   inflating: augmented_data/train_images/augmented_00125_3.jpg
#   inflating: augmented_data/train_images/augmented_00164_3.jpg
#   inflating: augmented_data/train_images/augmented_00107_4.jpg
#   inflating: augmented_data/train_images/augmented_00421_3.jpg
#   inflating: augmented_data/train_images/augmented_00098_0.jpg
#   inflating: augmented_data/train_images/augmented_00355_2.jpg
#   inflating: augmented_data/train_images/augmented_00439_2.jpg
#   inflating: augmented_data/train_images/augmented_00365_4.jpg
#   inflating: augmented_data/train_images/augmented_00378_3.jpg
#   inflating: augmented_data/train_images/augmented_00288_3.jpg
#   inflating: augmented_data/train_images/augmented_00349_4.jpg
#   inflating: augmented_data/train_images/augmented_00485_1.jpg
#   inflating: augmented_data/train_images/augmented_00470_4.jpg
#   inflating: augmented_data/train_images/augmented_00334_2.jpg
#   inflating: augmented_data/train_images/augmented_00433_1.jpg
#   inflating: augmented_data/train_images/augmented_00340_4.jpg
#   inflating: augmented_data/train_images/augmented_00387_1.jpg
#   inflating: augmented_data/train_images/augmented_00129_4.jpg
#   inflating: augmented_data/train_images/augmented_00140_3.jpg
#   inflating: augmented_data/train_images/augmented_00184_3.jpg
#   inflating: augmented_data/train_images/augmented_00475_4.jpg
#   inflating: augmented_data/train_images/augmented_00384_2.jpg
#   inflating: augmented_data/train_images/augmented_00261_4.jpg
#   inflating: augmented_data/train_images/augmented_00302_3.jpg
#   inflating: augmented_data/train_images/augmented_00464_3.jpg
#   inflating: augmented_data/train_images/augmented_00457_0.jpg
#   inflating: augmented_data/train_images/augmented_00427_4.jpg
#   inflating: augmented_data/train_images/augmented_00280_4.jpg
#   inflating: augmented_data/train_images/augmented_00333_2.jpg
#   inflating: augmented_data/train_images/augmented_00169_0.jpg
#   inflating: augmented_data/train_images/augmented_00215_1.jpg
#   inflating: augmented_data/train_images/augmented_00096_3.jpg
#   inflating: augmented_data/train_images/augmented_00300_1.jpg
#   inflating: augmented_data/train_images/augmented_00298_3.jpg
#   inflating: augmented_data/train_images/augmented_00037_4.jpg
#   inflating: augmented_data/train_images/augmented_00454_2.jpg
#   inflating: augmented_data/train_images/augmented_00025_3.jpg
#   inflating: augmented_data/train_images/augmented_00239_4.jpg
#   inflating: augmented_data/train_images/augmented_00320_1.jpg
#   inflating: augmented_data/train_images/augmented_00496_1.jpg
#   inflating: augmented_data/train_images/augmented_00556_1.jpg
#   inflating: augmented_data/train_images/augmented_00238_2.jpg
#   inflating: augmented_data/train_images/augmented_00391_2.jpg
#   inflating: augmented_data/train_images/augmented_00294_1.jpg
#   inflating: augmented_data/train_images/augmented_00413_2.jpg
#   inflating: augmented_data/train_images/augmented_00501_3.jpg
#   inflating: augmented_data/train_images/augmented_00375_4.jpg
#   inflating: augmented_data/train_images/augmented_00360_4.jpg
#   inflating: augmented_data/train_images/augmented_00545_1.jpg
#   inflating: augmented_data/train_images/augmented_00136_1.jpg
#   inflating: augmented_data/train_images/augmented_00009_4.jpg
#   inflating: augmented_data/train_images/augmented_00336_3.jpg
#   inflating: augmented_data/train_images/augmented_00496_4.jpg
#   inflating: augmented_data/train_images/augmented_00023_0.jpg
#   inflating: augmented_data/train_images/augmented_00587_2.jpg
#   inflating: augmented_data/train_images/augmented_00102_0.jpg
#   inflating: augmented_data/train_images/augmented_00329_2.jpg
#   inflating: augmented_data/train_images/augmented_00201_3.jpg
#   inflating: augmented_data/train_images/augmented_00227_4.jpg
#   inflating: augmented_data/train_images/augmented_00580_4.jpg
#   inflating: augmented_data/train_images/augmented_00267_0.jpg
#   inflating: augmented_data/train_images/augmented_00389_0.jpg
#   inflating: augmented_data/train_images/augmented_00390_1.jpg
#   inflating: augmented_data/train_images/augmented_00445_2.jpg
#   inflating: augmented_data/train_images/augmented_00178_0.jpg
#   inflating: augmented_data/train_images/augmented_00394_0.jpg
#   inflating: augmented_data/train_images/augmented_00557_4.jpg
#   inflating: augmented_data/train_images/augmented_00483_1.jpg
#   inflating: augmented_data/train_images/augmented_00098_3.jpg
#   inflating: augmented_data/train_images/augmented_00359_1.jpg
#   inflating: augmented_data/train_images/augmented_00131_2.jpg
#   inflating: augmented_data/train_images/augmented_00189_3.jpg
#   inflating: augmented_data/train_images/augmented_00144_4.jpg
#   inflating: augmented_data/train_images/augmented_00555_3.jpg
#   inflating: augmented_data/train_images/augmented_00105_0.jpg
#   inflating: augmented_data/train_images/augmented_00032_0.jpg
#   inflating: augmented_data/train_images/augmented_00331_2.jpg
#   inflating: augmented_data/train_images/augmented_00463_2.jpg
#   inflating: augmented_data/train_images/augmented_00432_2.jpg
#   inflating: augmented_data/train_images/augmented_00359_3.jpg
#   inflating: augmented_data/train_images/augmented_00324_2.jpg
#   inflating: augmented_data/train_images/augmented_00575_1.jpg
#   inflating: augmented_data/train_images/augmented_00097_3.jpg
#   inflating: augmented_data/train_images/augmented_00011_0.jpg
#   inflating: augmented_data/train_images/augmented_00586_2.jpg
#   inflating: augmented_data/train_images/augmented_00406_3.jpg
#   inflating: augmented_data/train_images/augmented_00160_1.jpg
#   inflating: augmented_data/train_images/augmented_00377_3.jpg
#   inflating: augmented_data/train_images/augmented_00137_3.jpg
#   inflating: augmented_data/train_images/augmented_00291_1.jpg
#   inflating: augmented_data/train_images/augmented_00351_4.jpg
#   inflating: augmented_data/train_images/augmented_00283_0.jpg
#   inflating: augmented_data/train_images/augmented_00115_4.jpg
#   inflating: augmented_data/train_images/augmented_00062_2.jpg
#   inflating: augmented_data/train_images/augmented_00466_0.jpg
#   inflating: augmented_data/train_images/augmented_00279_2.jpg
#   inflating: augmented_data/train_images/augmented_00024_3.jpg
#   inflating: augmented_data/train_images/augmented_00440_0.jpg
#   inflating: augmented_data/train_images/augmented_00043_0.jpg
#   inflating: augmented_data/train_images/augmented_00100_3.jpg
#   inflating: augmented_data/train_images/augmented_00319_3.jpg
#   inflating: augmented_data/train_images/augmented_00544_4.jpg
#   inflating: augmented_data/train_images/augmented_00230_0.jpg
#   inflating: augmented_data/train_images/augmented_00076_1.jpg
#   inflating: augmented_data/train_images/augmented_00043_1.jpg
#   inflating: augmented_data/train_images/augmented_00475_0.jpg
#   inflating: augmented_data/train_images/augmented_00414_1.jpg
#   inflating: augmented_data/train_images/augmented_00314_4.jpg
#   inflating: augmented_data/train_images/augmented_00306_1.jpg
#   inflating: augmented_data/train_images/augmented_00428_4.jpg
#   inflating: augmented_data/train_images/augmented_00478_4.jpg
#   inflating: augmented_data/train_images/augmented_00177_2.jpg
#   inflating: augmented_data/train_images/augmented_00071_1.jpg
#   inflating: augmented_data/train_images/augmented_00293_0.jpg
#   inflating: augmented_data/train_images/augmented_00554_2.jpg
#   inflating: augmented_data/train_images/augmented_00244_1.jpg
#   inflating: augmented_data/train_images/augmented_00166_0.jpg
#   inflating: augmented_data/train_images/augmented_00190_4.jpg
#   inflating: augmented_data/train_images/augmented_00323_2.jpg
#   inflating: augmented_data/train_images/augmented_00520_1.jpg
#   inflating: augmented_data/train_images/augmented_00069_0.jpg
#   inflating: augmented_data/train_images/augmented_00051_0.jpg
#   inflating: augmented_data/train_images/augmented_00067_4.jpg
#   inflating: augmented_data/train_images/augmented_00330_0.jpg
#   inflating: augmented_data/train_images/augmented_00190_0.jpg
#   inflating: augmented_data/train_images/augmented_00346_2.jpg
#   inflating: augmented_data/train_images/augmented_00362_0.jpg
#   inflating: augmented_data/train_images/augmented_00585_0.jpg
#   inflating: augmented_data/train_images/augmented_00205_2.jpg
#   inflating: augmented_data/train_images/augmented_00469_0.jpg
#   inflating: augmented_data/train_images/augmented_00307_3.jpg
#   inflating: augmented_data/train_images/augmented_00469_4.jpg
#   inflating: augmented_data/train_images/augmented_00440_2.jpg
#   inflating: augmented_data/train_images/augmented_00006_4.jpg
#   inflating: augmented_data/train_images/augmented_00412_0.jpg
#   inflating: augmented_data/train_images/augmented_00273_4.jpg
#   inflating: augmented_data/train_images/augmented_00337_2.jpg
#   inflating: augmented_data/train_images/augmented_00128_1.jpg
#   inflating: augmented_data/train_images/augmented_00440_1.jpg
#   inflating: augmented_data/train_images/augmented_00057_2.jpg
#   inflating: augmented_data/train_images/augmented_00070_1.jpg
#   inflating: augmented_data/train_images/augmented_00240_3.jpg
#   inflating: augmented_data/train_images/augmented_00163_3.jpg
#   inflating: augmented_data/train_images/augmented_00472_1.jpg
#   inflating: augmented_data/train_images/augmented_00374_0.jpg
#   inflating: augmented_data/train_images/augmented_00088_2.jpg
#   inflating: augmented_data/train_images/augmented_00387_0.jpg
#   inflating: augmented_data/train_images/augmented_00565_3.jpg
#   inflating: augmented_data/train_images/augmented_00508_0.jpg
#   inflating: augmented_data/train_images/augmented_00401_1.jpg
#   inflating: augmented_data/train_images/augmented_00026_2.jpg
#   inflating: augmented_data/train_images/augmented_00441_3.jpg
#   inflating: augmented_data/train_images/augmented_00144_0.jpg
#   inflating: augmented_data/train_images/augmented_00351_1.jpg
#   inflating: augmented_data/train_images/augmented_00406_0.jpg
#   inflating: augmented_data/train_images/augmented_00546_0.jpg
#   inflating: augmented_data/train_images/augmented_00509_2.jpg
#   inflating: augmented_data/train_images/augmented_00023_4.jpg
#   inflating: augmented_data/train_images/augmented_00216_3.jpg
#   inflating: augmented_data/train_images/augmented_00191_2.jpg
#   inflating: augmented_data/train_images/augmented_00154_1.jpg
#   inflating: augmented_data/train_images/augmented_00111_3.jpg
#   inflating: augmented_data/train_images/augmented_00167_1.jpg
#   inflating: augmented_data/train_images/augmented_00130_2.jpg
#   inflating: augmented_data/train_images/augmented_00181_3.jpg
#   inflating: augmented_data/train_images/augmented_00571_0.jpg
#   inflating: augmented_data/train_images/augmented_00443_0.jpg
#   inflating: augmented_data/train_images/augmented_00409_2.jpg
#   inflating: augmented_data/train_images/augmented_00000_0.jpg
#   inflating: augmented_data/train_images/augmented_00280_1.jpg
#   inflating: augmented_data/train_images/augmented_00452_2.jpg
#   inflating: augmented_data/train_images/augmented_00262_2.jpg
#   inflating: augmented_data/train_images/augmented_00413_3.jpg
#   inflating: augmented_data/train_images/augmented_00551_4.jpg
#   inflating: augmented_data/train_images/augmented_00094_3.jpg
#   inflating: augmented_data/train_images/augmented_00097_2.jpg
#   inflating: augmented_data/train_images/augmented_00561_3.jpg
#   inflating: augmented_data/train_images/augmented_00229_1.jpg
#   inflating: augmented_data/train_images/augmented_00015_0.jpg
#   inflating: augmented_data/train_images/augmented_00118_2.jpg
#   inflating: augmented_data/train_images/augmented_00041_0.jpg
#   inflating: augmented_data/train_images/augmented_00573_3.jpg
#   inflating: augmented_data/train_images/augmented_00214_0.jpg
#   inflating: augmented_data/train_images/augmented_00085_0.jpg
#   inflating: augmented_data/train_images/augmented_00197_2.jpg
#   inflating: augmented_data/train_images/augmented_00234_0.jpg
#   inflating: augmented_data/train_images/augmented_00302_2.jpg
#   inflating: augmented_data/train_images/augmented_00504_4.jpg
#   inflating: augmented_data/train_images/augmented_00268_1.jpg
#   inflating: augmented_data/train_images/augmented_00013_1.jpg
#   inflating: augmented_data/train_images/augmented_00156_0.jpg
#   inflating: augmented_data/train_images/augmented_00107_1.jpg
#   inflating: augmented_data/train_images/augmented_00083_3.jpg
#   inflating: augmented_data/train_images/augmented_00270_2.jpg
#   inflating: augmented_data/train_images/augmented_00144_1.jpg
#   inflating: augmented_data/train_images/augmented_00389_3.jpg
#   inflating: augmented_data/train_images/augmented_00186_1.jpg
#   inflating: augmented_data/train_images/augmented_00450_0.jpg
#   inflating: augmented_data/train_images/augmented_00123_3.jpg
#   inflating: augmented_data/train_images/augmented_00423_3.jpg
#   inflating: augmented_data/train_images/augmented_00277_2.jpg
#   inflating: augmented_data/train_images/augmented_00489_0.jpg
#   inflating: augmented_data/train_images/augmented_00488_4.jpg
#   inflating: augmented_data/train_images/augmented_00179_1.jpg
#   inflating: augmented_data/train_images/augmented_00250_3.jpg
#   inflating: augmented_data/train_images/augmented_00375_0.jpg
#   inflating: augmented_data/train_images/augmented_00464_4.jpg
#   inflating: augmented_data/train_images/augmented_00193_3.jpg
#   inflating: augmented_data/train_images/augmented_00516_2.jpg
#   inflating: augmented_data/train_images/augmented_00289_0.jpg
#   inflating: augmented_data/train_images/augmented_00303_1.jpg
#   inflating: augmented_data/train_images/augmented_00577_1.jpg
#   inflating: augmented_data/train_images/augmented_00042_3.jpg
#   inflating: augmented_data/train_images/augmented_00152_1.jpg
#   inflating: augmented_data/train_images/augmented_00221_3.jpg
#   inflating: augmented_data/train_images/augmented_00542_3.jpg
#   inflating: augmented_data/train_images/augmented_00226_2.jpg
#   inflating: augmented_data/train_images/augmented_00252_3.jpg
#   inflating: augmented_data/train_images/augmented_00274_3.jpg
#   inflating: augmented_data/train_images/augmented_00570_3.jpg
#   inflating: augmented_data/train_images/augmented_00266_3.jpg
#   inflating: augmented_data/train_images/augmented_00442_4.jpg
#   inflating: augmented_data/train_images/augmented_00419_4.jpg
#   inflating: augmented_data/train_images/augmented_00341_0.jpg
#   inflating: augmented_data/train_images/augmented_00576_4.jpg
#   inflating: augmented_data/train_images/augmented_00530_3.jpg
#   inflating: augmented_data/train_images/augmented_00149_0.jpg
#   inflating: augmented_data/train_images/augmented_00248_4.jpg
#   inflating: augmented_data/train_images/augmented_00255_1.jpg
#   inflating: augmented_data/train_images/augmented_00411_0.jpg
#   inflating: augmented_data/train_images/augmented_00443_1.jpg
#   inflating: augmented_data/train_images/augmented_00450_3.jpg
#   inflating: augmented_data/train_images/augmented_00014_1.jpg
#   inflating: augmented_data/train_images/augmented_00488_1.jpg
#   inflating: augmented_data/train_images/augmented_00350_4.jpg
#   inflating: augmented_data/train_images/augmented_00562_0.jpg
#   inflating: augmented_data/train_images/augmented_00229_4.jpg
#   inflating: augmented_data/train_images/augmented_00261_1.jpg
#   inflating: augmented_data/train_images/augmented_00104_4.jpg
#   inflating: augmented_data/train_images/augmented_00437_3.jpg
#   inflating: augmented_data/train_images/augmented_00566_1.jpg
#   inflating: augmented_data/train_images/augmented_00302_4.jpg
#   inflating: augmented_data/train_images/augmented_00575_2.jpg
#   inflating: augmented_data/train_images/augmented_00505_0.jpg
#   inflating: augmented_data/train_images/augmented_00551_0.jpg
#   inflating: augmented_data/train_images/augmented_00093_0.jpg
#   inflating: augmented_data/train_images/augmented_00362_4.jpg
#   inflating: augmented_data/train_images/augmented_00320_2.jpg
#   inflating: augmented_data/train_images/augmented_00008_0.jpg
#   inflating: augmented_data/train_images/augmented_00185_1.jpg
#   inflating: augmented_data/train_images/augmented_00326_2.jpg
#   inflating: augmented_data/train_images/augmented_00535_4.jpg
#   inflating: augmented_data/train_images/augmented_00136_4.jpg
#   inflating: augmented_data/train_images/augmented_00204_4.jpg
#   inflating: augmented_data/train_images/augmented_00348_2.jpg
#   inflating: augmented_data/train_images/augmented_00017_1.jpg
#   inflating: augmented_data/train_images/augmented_00350_2.jpg
#   inflating: augmented_data/train_images/augmented_00016_4.jpg
#   inflating: augmented_data/train_images/augmented_00052_0.jpg
#   inflating: augmented_data/train_images/augmented_00338_1.jpg
#   inflating: augmented_data/train_images/augmented_00431_4.jpg
#   inflating: augmented_data/train_images/augmented_00109_3.jpg
#   inflating: augmented_data/train_images/augmented_00487_3.jpg
#   inflating: augmented_data/train_images/augmented_00336_2.jpg
#   inflating: augmented_data/train_images/augmented_00482_0.jpg
#   inflating: augmented_data/train_images/augmented_00286_0.jpg
#   inflating: augmented_data/train_images/augmented_00232_1.jpg
#   inflating: augmented_data/train_images/augmented_00096_0.jpg
#   inflating: augmented_data/train_images/augmented_00022_4.jpg
#   inflating: augmented_data/train_images/augmented_00033_2.jpg
# ...
#   inflating: augmented_data/train_masks/augmented_00252_4.png
#   inflating: augmented_data/train_masks/augmented_00332_0.png
#   inflating: augmented_data/train_masks/augmented_00117_2.png
#   inflating: augmented_data/train_masks/augmented_00041_0.png
#   inflating: augmented_data/train_masks/augmented_00204_1.png
#   inflating: augmented_data/train_masks/augmented_00514_3.png
#   inflating: augmented_data/train_masks/augmented_00321_1.png
#   inflating: augmented_data/train_masks/augmented_00139_4.png
#   inflating: augmented_data/train_masks/augmented_00559_2.png
#   inflating: augmented_data/train_masks/augmented_00348_1.png
#   inflating: augmented_data/train_masks/augmented_00227_2.png
#   inflating: augmented_data/train_masks/augmented_00406_2.png
#   inflating: augmented_data/train_masks/augmented_00465_3.png
#   inflating: augmented_data/train_masks/augmented_00279_4.png
#   inflating: augmented_data/train_masks/augmented_00556_1.png
#   inflating: augmented_data/train_masks/augmented_00503_3.png
#   inflating: augmented_data/train_masks/augmented_00238_2.png
#   inflating: augmented_data/train_masks/augmented_00031_0.png
#   inflating: augmented_data/train_masks/augmented_00251_3.png
#   inflating: augmented_data/train_masks/augmented_00347_4.png
#   inflating: augmented_data/train_masks/augmented_00418_0.png
#   inflating: augmented_data/train_masks/augmented_00193_1.png
#   inflating: augmented_data/train_masks/augmented_00022_0.png
#   inflating: augmented_data/train_masks/augmented_00214_2.png
#   inflating: augmented_data/train_masks/augmented_00579_4.png
#   inflating: augmented_data/train_masks/augmented_00146_2.png
#   inflating: augmented_data/train_masks/augmented_00060_3.png
#   inflating: augmented_data/train_masks/augmented_00063_0.png
#   inflating: augmented_data/train_masks/augmented_00552_2.png
#   inflating: augmented_data/train_masks/augmented_00259_3.png
#   inflating: augmented_data/train_masks/augmented_00149_2.png
#   inflating: augmented_data/train_masks/augmented_00546_2.png
#   inflating: augmented_data/train_masks/augmented_00088_1.png
#   inflating: augmented_data/train_masks/augmented_00012_2.png
#   inflating: augmented_data/train_masks/augmented_00005_0.png
#   inflating: augmented_data/train_masks/augmented_00424_2.png
#   inflating: augmented_data/train_masks/augmented_00390_1.png
#   inflating: augmented_data/train_masks/augmented_00299_1.png
#   inflating: augmented_data/train_masks/augmented_00089_2.png
#   inflating: augmented_data/train_masks/augmented_00506_0.png
#   inflating: augmented_data/train_masks/augmented_00050_3.png
#   inflating: augmented_data/train_masks/augmented_00074_2.png
#   inflating: augmented_data/train_masks/augmented_00580_0.png
#   inflating: augmented_data/train_masks/augmented_00043_1.png
#   inflating: augmented_data/train_masks/augmented_00235_1.png
#   inflating: augmented_data/train_masks/augmented_00391_0.png
#   inflating: augmented_data/train_masks/augmented_00055_4.png
#   inflating: augmented_data/train_masks/augmented_00119_0.png
#   inflating: augmented_data/train_masks/augmented_00287_1.png
#   inflating: augmented_data/train_masks/augmented_00159_4.png
#   inflating: augmented_data/train_masks/augmented_00509_2.png
#   inflating: augmented_data/train_masks/augmented_00463_1.png
#   inflating: augmented_data/train_masks/augmented_00144_2.png
#   inflating: augmented_data/train_masks/augmented_00270_3.png
#   inflating: augmented_data/train_masks/augmented_00550_1.png
#   inflating: augmented_data/train_masks/augmented_00042_4.png
#   inflating: augmented_data/train_masks/augmented_00545_3.png
#   inflating: augmented_data/train_masks/augmented_00034_4.png
#   inflating: augmented_data/train_masks/augmented_00479_0.png
#   inflating: augmented_data/train_masks/augmented_00391_1.png
#   inflating: augmented_data/train_masks/augmented_00063_4.png
#   inflating: augmented_data/train_masks/augmented_00346_3.png
#   inflating: augmented_data/train_masks/augmented_00491_4.png
#   inflating: augmented_data/train_masks/augmented_00552_0.png
#   inflating: augmented_data/train_masks/augmented_00167_2.png
#   inflating: augmented_data/train_masks/augmented_00276_1.png
#   inflating: augmented_data/train_masks/augmented_00318_4.png
#   inflating: augmented_data/train_masks/augmented_00263_0.png
#   inflating: augmented_data/train_masks/augmented_00074_1.png
#   inflating: augmented_data/train_masks/augmented_00482_0.png
#   inflating: augmented_data/train_masks/augmented_00154_0.png
#   inflating: augmented_data/train_masks/augmented_00155_2.png
#   inflating: augmented_data/train_masks/augmented_00058_3.png
#   inflating: augmented_data/train_masks/augmented_00160_0.png
#   inflating: augmented_data/train_masks/augmented_00184_3.png
#   inflating: augmented_data/train_masks/augmented_00477_0.png
#   inflating: augmented_data/train_masks/augmented_00393_3.png
#   inflating: augmented_data/train_masks/augmented_00470_4.png
#   inflating: augmented_data/train_masks/augmented_00183_1.png
#   inflating: augmented_data/train_masks/augmented_00172_0.png
#   inflating: augmented_data/train_masks/augmented_00382_4.png
#   inflating: augmented_data/train_masks/augmented_00565_1.png
#   inflating: augmented_data/train_masks/augmented_00317_3.png
#   inflating: augmented_data/train_masks/augmented_00413_4.png
#   inflating: augmented_data/train_masks/augmented_00328_4.png
#   inflating: augmented_data/train_masks/augmented_00421_2.png
#   inflating: augmented_data/train_masks/augmented_00089_4.png
#   inflating: augmented_data/train_masks/augmented_00309_1.png
#   inflating: augmented_data/train_masks/augmented_00247_4.png
#   inflating: augmented_data/train_masks/augmented_00296_4.png
#   inflating: augmented_data/train_masks/augmented_00483_1.png
#   inflating: augmented_data/train_masks/augmented_00568_0.png
#   inflating: augmented_data/train_masks/augmented_00139_3.png
#   inflating: augmented_data/train_masks/augmented_00511_3.png
#   inflating: augmented_data/train_masks/augmented_00445_4.png
#   inflating: augmented_data/train_masks/augmented_00493_1.png
#   inflating: augmented_data/train_masks/augmented_00528_0.png
#   inflating: augmented_data/train_masks/augmented_00438_3.png
#   inflating: augmented_data/train_masks/augmented_00247_3.png
#   inflating: augmented_data/train_masks/augmented_00026_3.png
#   inflating: augmented_data/train_masks/augmented_00131_1.png
#   inflating: augmented_data/train_masks/augmented_00036_1.png
#   inflating: augmented_data/train_masks/augmented_00584_2.png
#   inflating: augmented_data/train_masks/augmented_00254_3.png
#   inflating: augmented_data/train_masks/augmented_00243_1.png
#   inflating: augmented_data/train_masks/augmented_00275_3.png
#   inflating: augmented_data/train_masks/augmented_00287_2.png
#   inflating: augmented_data/train_masks/augmented_00218_4.png
#   inflating: augmented_data/train_masks/augmented_00454_3.png
#   inflating: augmented_data/train_masks/augmented_00339_4.png
#   inflating: augmented_data/train_masks/augmented_00564_2.png
#   inflating: augmented_data/train_masks/augmented_00208_2.png
#   inflating: augmented_data/train_masks/augmented_00010_3.png
#   inflating: augmented_data/train_masks/augmented_00037_4.png
#   inflating: augmented_data/train_masks/augmented_00397_0.png
#   inflating: augmented_data/train_masks/augmented_00411_0.png
#   inflating: augmented_data/train_masks/augmented_00341_1.png
#   inflating: augmented_data/train_masks/augmented_00194_3.png
#   inflating: augmented_data/train_masks/augmented_00356_4.png
#   inflating: augmented_data/train_masks/augmented_00478_3.png
#   inflating: augmented_data/train_masks/augmented_00315_4.png
#   inflating: augmented_data/train_masks/augmented_00079_0.png
#   inflating: augmented_data/train_masks/augmented_00155_3.png
#   inflating: augmented_data/train_masks/augmented_00009_4.png
#   inflating: augmented_data/train_masks/augmented_00090_4.png
#   inflating: augmented_data/train_masks/augmented_00097_2.png
#   inflating: augmented_data/train_masks/augmented_00012_0.png
#   inflating: augmented_data/train_masks/augmented_00556_2.png
#   inflating: augmented_data/train_masks/augmented_00449_0.png
#   inflating: augmented_data/train_masks/augmented_00326_1.png
#   inflating: augmented_data/train_masks/augmented_00199_1.png
#   inflating: augmented_data/train_masks/augmented_00366_4.png
#   inflating: augmented_data/train_masks/augmented_00089_3.png
#   inflating: augmented_data/train_masks/augmented_00220_2.png
#   inflating: augmented_data/train_masks/augmented_00499_3.png
#   inflating: augmented_data/train_masks/augmented_00170_3.png
#   inflating: augmented_data/train_masks/augmented_00280_2.png
#   inflating: augmented_data/train_masks/augmented_00371_0.png
#   inflating: augmented_data/train_masks/augmented_00352_2.png
#   inflating: augmented_data/train_masks/augmented_00113_1.png
#   inflating: augmented_data/train_masks/augmented_00107_1.png
#   inflating: augmented_data/train_masks/augmented_00433_1.png
#   inflating: augmented_data/train_masks/augmented_00198_0.png
#   inflating: augmented_data/train_masks/augmented_00287_3.png
#   inflating: augmented_data/train_masks/augmented_00387_1.png
#   inflating: augmented_data/train_masks/augmented_00310_3.png
#   inflating: augmented_data/train_masks/augmented_00241_0.png
#   inflating: augmented_data/train_masks/augmented_00353_3.png
#   inflating: augmented_data/train_masks/augmented_00136_3.png
#   inflating: augmented_data/train_masks/augmented_00168_3.png
#   inflating: augmented_data/train_masks/augmented_00572_4.png
#   inflating: augmented_data/train_masks/augmented_00222_0.png
#   inflating: augmented_data/train_masks/augmented_00328_3.png
#   inflating: augmented_data/train_masks/augmented_00327_2.png
#   inflating: augmented_data/train_masks/augmented_00179_0.png
#   inflating: augmented_data/train_masks/augmented_00114_0.png
#   inflating: augmented_data/train_masks/augmented_00093_1.png
#   inflating: augmented_data/train_masks/augmented_00497_4.png
#   inflating: augmented_data/train_masks/augmented_00048_2.png
#   inflating: augmented_data/train_masks/augmented_00278_0.png
#   inflating: augmented_data/train_masks/augmented_00401_4.png
#   inflating: augmented_data/train_masks/augmented_00570_1.png
#   inflating: augmented_data/train_masks/augmented_00138_2.png
#   inflating: augmented_data/train_masks/augmented_00152_2.png
#   inflating: augmented_data/train_masks/augmented_00568_3.png
#   inflating: augmented_data/train_masks/augmented_00004_2.png
#   inflating: augmented_data/train_masks/augmented_00455_1.png
#   inflating: augmented_data/train_masks/augmented_00442_4.png
#   inflating: augmented_data/train_masks/augmented_00378_3.png
#   inflating: augmented_data/train_masks/augmented_00060_1.png
#   inflating: augmented_data/train_masks/augmented_00430_0.png
#   inflating: augmented_data/train_masks/augmented_00142_4.png
#   inflating: augmented_data/train_masks/augmented_00260_1.png
#   inflating: augmented_data/train_masks/augmented_00136_4.png
#   inflating: augmented_data/train_masks/augmented_00023_4.png
#   inflating: augmented_data/train_masks/augmented_00386_1.png
#   inflating: augmented_data/train_masks/augmented_00098_4.png
#   inflating: augmented_data/train_masks/augmented_00168_4.png
#   inflating: augmented_data/train_masks/augmented_00432_1.png
#   inflating: augmented_data/train_masks/augmented_00553_1.png
#   inflating: augmented_data/train_masks/augmented_00100_3.png
#   inflating: augmented_data/train_masks/augmented_00370_4.png
#   inflating: augmented_data/train_masks/augmented_00458_1.png
#   inflating: augmented_data/train_masks/augmented_00584_4.png
#   inflating: augmented_data/train_masks/augmented_00007_0.png
#   inflating: augmented_data/train_masks/augmented_00493_4.png
#   inflating: augmented_data/train_masks/augmented_00276_4.png
#   inflating: augmented_data/train_masks/augmented_00575_1.png
#   inflating: augmented_data/train_masks/augmented_00103_1.png
#   inflating: augmented_data/train_masks/augmented_00052_1.png
#   inflating: augmented_data/train_masks/augmented_00245_4.png
#   inflating: augmented_data/train_masks/augmented_00010_2.png
#   inflating: augmented_data/train_masks/augmented_00274_2.png
#   inflating: augmented_data/train_masks/augmented_00565_3.png
#   inflating: augmented_data/train_masks/augmented_00347_2.png
#   inflating: augmented_data/train_masks/augmented_00414_1.png
#   inflating: augmented_data/train_masks/augmented_00275_1.png
#   inflating: augmented_data/train_masks/augmented_00293_0.png
#   inflating: augmented_data/train_masks/augmented_00261_1.png
#   inflating: augmented_data/train_masks/augmented_00527_3.png
#   inflating: augmented_data/train_masks/augmented_00258_2.png
#   inflating: augmented_data/train_masks/augmented_00582_3.png
#   inflating: augmented_data/train_masks/augmented_00146_1.png
#   inflating: augmented_data/train_masks/augmented_00482_1.png
#   inflating: augmented_data/train_masks/augmented_00543_4.png
#   inflating: augmented_data/train_masks/augmented_00479_3.png
#   inflating: augmented_data/train_masks/augmented_00208_0.png
#   inflating: augmented_data/train_masks/augmented_00555_3.png
#   inflating: augmented_data/train_masks/augmented_00407_4.png
#   inflating: augmented_data/train_masks/augmented_00287_0.png
#   inflating: augmented_data/train_masks/augmented_00411_2.png
#   inflating: augmented_data/train_masks/augmented_00018_2.png
#   inflating: augmented_data/train_masks/augmented_00525_4.png
#   inflating: augmented_data/train_masks/augmented_00319_3.png
#   inflating: augmented_data/train_masks/augmented_00582_0.png
#   inflating: augmented_data/train_masks/augmented_00336_1.png
#   inflating: augmented_data/train_masks/augmented_00512_3.png
#   inflating: augmented_data/train_masks/augmented_00484_3.png
#   inflating: augmented_data/train_masks/augmented_00152_0.png
#   inflating: augmented_data/train_masks/augmented_00380_0.png
#   inflating: augmented_data/train_masks/augmented_00523_1.png
#   inflating: augmented_data/train_masks/augmented_00030_0.png
#   inflating: augmented_data/train_masks/augmented_00184_4.png
#   inflating: augmented_data/train_masks/augmented_00232_0.png
#   inflating: augmented_data/train_masks/augmented_00415_2.png
#   inflating: augmented_data/train_masks/augmented_00198_4.png
#   inflating: augmented_data/train_masks/augmented_00180_4.png
#   inflating: augmented_data/train_masks/augmented_00047_3.png
#   inflating: augmented_data/train_masks/augmented_00080_0.png
#   inflating: augmented_data/train_masks/augmented_00125_4.png
#   inflating: augmented_data/train_masks/augmented_00540_1.png
#   inflating: augmented_data/train_masks/augmented_00206_1.png
#   inflating: augmented_data/train_masks/augmented_00341_0.png
#   inflating: augmented_data/train_masks/augmented_00183_4.png
#   inflating: augmented_data/train_masks/augmented_00316_1.png
#   inflating: augmented_data/train_masks/augmented_00552_4.png
#   inflating: augmented_data/train_masks/augmented_00393_1.png
#   inflating: augmented_data/train_masks/augmented_00101_3.png
#   inflating: augmented_data/train_masks/augmented_00380_4.png
#   inflating: augmented_data/train_masks/augmented_00145_1.png
#   inflating: augmented_data/train_masks/augmented_00551_3.png
#   inflating: augmented_data/train_masks/augmented_00315_0.png
#   inflating: augmented_data/train_masks/augmented_00077_1.png
#   inflating: augmented_data/train_masks/augmented_00293_1.png
#   inflating: augmented_data/train_masks/augmented_00079_4.png
#   inflating: augmented_data/train_masks/augmented_00443_4.png
#   inflating: augmented_data/train_masks/augmented_00147_2.png
#   inflating: augmented_data/train_masks/augmented_00431_0.png
#   inflating: augmented_data/train_masks/augmented_00091_3.png
#   inflating: augmented_data/train_masks/augmented_00270_1.png

# %%
train_images="/content/augmented_data/train_images/"
train_masks="/content/augmented_data/train_masks/"
test_images ="/content/augmented_data/test_images/"
test_masks="/content/augmented_data/test_masks/"
valid_images="/content/augmented_data/valid_images/"
valid_masks="/content/augmented_data/valid_masks/"

# %% [markdown]
# # **To check RGB class in binary masked image**

# %%
import numpy as np
from PIL import Image

# Function to find unique RGB colors in an image
def find_unique_colors(image_path):
    # Open the image, convert it to RGB mode to ensure it's in 3 channels
    image = Image.open(image_path).convert('RGB')

    # Convert the image to a numpy array
    image_array = np.array(image)

    # Reshape the image array to a 2D array (flatten the image) and find unique colors (by axis 0, each color is a row)
    unique_colors = np.unique(image_array.reshape(-1, image_array.shape[2]), axis=0)

    # Convert the unique colors (rows) into tuples for readability
    unique_colors_list = [tuple(color) for color in unique_colors]

    return unique_colors_list

# Define the path to the image you want to analyze
image_path = test_masks + '/augmented_00016_1.png'

# Call the function to find unique colors
unique_colors = find_unique_colors(image_path)

# Initialize a list to store color information
color = []

# Print out the unique RGB colors and assign each one to a class
print("Unique RGB colors in the image:")
for idx, color in enumerate(unique_colors):
    print(f"Class {idx}: {color}")

# %%
print(len(os.listdir(train_images)))
print(len(os.listdir(train_masks)))
print(len(os.listdir(test_images)))
print(len(os.listdir(test_masks)))
print(len(os.listdir(valid_images)))
print(len(os.listdir(valid_masks)))
# Out:
# 2117
# 2117
# 235
# 235
# 588
# 588

# %% [markdown]
# # **Set Classes**

# %%
class_names = ['background','affected']
class_rgb_values = [[0, 0, 0], color]

select_classes = class_names

select_class_indices = [class_names.index(cls.lower()) for cls in select_classes]
select_class_rgb_values =  np.array(class_rgb_values)[select_class_indices]

print('Selected classes and their corresponding RGB values in labels:')
print('Class Names: ', class_names)
print('Class RGB values: ', class_rgb_values)
# Out:
# Selected classes and their corresponding RGB values in labels:
# Class Names:  ['background', 'affected']
# Class RGB values:  [[0, 0, 0], (38, 38, 38)]

# %% [markdown]
# # **Custom Class for Pre Process**

# %% [markdown]
# # **visualizer**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to visualize multiple images in one plot
def visualize(**images):
    n_images = len(images)
    plt.figure(figsize=(20, 8))
    for idx, (name, image) in enumerate(images.items()):
        plt.subplot(1, n_images, idx + 1)  # Place each image in a subplot
        plt.xticks([])  # Remove x-axis ticks
        plt.yticks([])  # Remove y-axis ticks
        plt.title(name.replace('_', ' ').title(), fontsize=20)  # Title for each image
        plt.imshow(image)  # Display image
    plt.show()

# Function for one-hot encoding of segmentation labels
def one_hot_encode(label, label_values):
    semantic_map = []
    for colour in label_values:
        # Check for equality between the image label and the current class color
        equality = np.equal(label, colour)
        class_map = np.all(equality, axis=-1)  # All channels must match
        semantic_map.append(class_map)

    # Stack all class maps to form a one-hot encoded image (each class in its own channel)
    semantic_map = np.stack(semantic_map, axis=-1)

    return semantic_map

# Function to reverse one-hot encoding and convert back to the original label values
def reverse_one_hot(image):
    x = np.argmax(image, axis=-1)  # Find index of the maximum value along channels
    return x

# Function to apply colour coding to segmented images
def colour_code_segmentation(image, label_values):
    colour_codes = np.array(label_values)
    # Convert the image indices into corresponding RGB color values
    x = colour_codes[image.astype(int)]

    # Add an alpha channel for transparency
    if x.shape[2] == 3:
        x_with_alpha = np.dstack([x, np.ones((x.shape[0], x.shape[1]), dtype=np.uint8) * 255])
    else:
        x_with_alpha = x

    # Masks for black and grey pixels
    black_mask = (x[:, :, 0] == 0) & (x[:, :, 1] == 0) & (x[:, :, 2] == 0)
    grey_mask = (x[:, :, 0] == 38) & (x[:, :, 1] == 38) & (x[:, :, 2] == 38)

    # Modify alpha for black pixels (make them fully transparent)
    x_with_alpha[black_mask, 3] = 0
    # Modify color for grey pixels (turn them to blue)
    x_with_alpha[grey_mask, 0] = 0  # Red channel to 0
    x_with_alpha[grey_mask, 1] = 0  # Green channel to 0
    x_with_alpha[grey_mask, 2] = 255  # Blue channel to 255
    return x_with_alpha

import cv2

# Function to overlay ground truth mask on the original image
def overlay_ground_truth(original_image, ground_truth_mask):
    # If the original image is grayscale, convert it to RGB
    if original_image.shape[2] == 1:
        original_image = cv2.cvtColor(original_image, cv2.COLOR_GRAY2RGB)

    # Resize the ground truth mask to match the size of the original image if necessary
    if ground_truth_mask.shape[:2] != original_image.shape[:2]:
        ground_truth_mask = cv2.resize(ground_truth_mask, (original_image.shape[1], original_image.shape[0]))

    # Add an alpha channel to the ground truth mask if it doesn't already have one
    if ground_truth_mask.shape[2] == 3:
        ground_truth_mask = np.dstack([ground_truth_mask, np.ones((ground_truth_mask.shape[0], ground_truth_mask.shape[1]), dtype=np.uint8) * 255])

    # Create a copy of the original image to overlay the mask
    overlay_image = original_image.copy()

    # Loop through each pixel and apply the mask (only pixels with non-zero alpha are modified)
    for y in range(original_image.shape[0]):
        for x in range(original_image.shape[1]):
            if ground_truth_mask[y, x, 3] > 0:
                overlay_image[y, x] = ground_truth_mask[y, x, :3]  # Apply the mask's RGB values

    return overlay_image

# %% [markdown]
# # **Plant Dataset class**

# %%
import os
import cv2
import torch

# Custom dataset class for plant disease segmentation
class PlantDiseaseDataset(torch.utils.data.Dataset):
    def __init__(
            self,
            images_dir,
            masks_dir,
            class_rgb_values=None,  # Class RGB values for one-hot encoding
            augmentation=None,  # Optional data augmentation pipeline
            preprocessing=None,  # Optional preprocessing pipeline
    ):
        # Get list of all image and mask file paths
        self.image_paths = [os.path.join(images_dir, image_id) for image_id in sorted(os.listdir(images_dir))]
        self.mask_paths = [os.path.join(masks_dir, image_id) for image_id in sorted(os.listdir(masks_dir))]

        # Store class RGB values, augmentation, and preprocessing functions
        self.class_rgb_values = class_rgb_values
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):
        # Read the image and mask files
        image = cv2.cvtColor(cv2.imread(self.image_paths[i]), cv2.COLOR_BGR2RGB)  # Convert image to RGB
        mask = cv2.cvtColor(cv2.imread(self.mask_paths[i]), cv2.COLOR_BGR2RGB)  # Convert mask to RGB

        # Resize image and mask to a fixed size (256x256)
        image = cv2.resize(image, (256, 256), interpolation=cv2.INTER_LINEAR)
        mask = cv2.resize(mask, (256, 256), interpolation=cv2.INTER_NEAREST)

        # One-hot encode the mask based on class RGB values
        mask = one_hot_encode(mask, self.class_rgb_values).astype('float')

        # Apply augmentations (if provided)
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        # Apply preprocessing (if provided)
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        # Return the processed image and mask
        return image, mask

    def __len__(self):
        # Return the total number of samples in the dataset
        return len(self.image_paths)

# %%
dataset = PlantDiseaseDataset(train_images, train_masks, class_rgb_values=select_class_rgb_values)
random_idx = random.randint(0, len(dataset)-1)
image, mask = dataset[2]
ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values)

visualize(
    original_image = image,
    ground_truth_mask =colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values) ,
    one_hot_encoded_mask = reverse_one_hot(mask),
    overlay_ground_truth=overlay_ground_truth(image,ground_truth_mask)

)

# %% [markdown]
# # **Augmented Image**

# %% [markdown]
# **NOTE:Augmentation has been done Before so the p is 0**

# %%
# Function to apply data augmentation techniques during training
def get_training_augmentation():
    train_transform = [
        album.OneOf(
            [  # Apply one of the following transformations randomly
                album.HorizontalFlip(p=1),   # Horizontal flip with 100% probability
                album.VerticalFlip(p=1),     # Vertical flip with 100% probability
                album.RandomRotate90(p=1),   # Random 90-degree rotation with 100% probability
            ],
            p=0.0,  # Set the probability of applying this block to 0 (i.e., no augmentation)
        ),
    ]
    return album.Compose(train_transform)  # Return the composed transformations for training

# Function to apply padding during validation to ensure the image dimensions are divisible by 32
def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        album.PadIfNeeded(
            min_height=256,               # Ensure the image height is at least 256
            min_width=256,                # Ensure the image width is at least 256
            always_apply=True,            # Always apply this transformation
            border_mode=0,                # Use constant padding (black padding)
            value=0                        # Black padding color (0)
        ),
    ]
    return album.Compose(test_transform)  # Return the composed transformations for validation

# Function to convert image and mask to tensor format for PyTorch
def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')  # Transpose image channels to CxHxW format and convert to float32

# Function to return preprocessing transformations that apply the given function
def get_preprocessing(preprocessing_fn=None):
    _transform = []  # List to store transformations
    if preprocessing_fn:  # If a preprocessing function is provided
        _transform.append(album.Lambda(image=preprocessing_fn))  # Apply the custom preprocessing function
    _transform.append(album.Lambda(image=to_tensor, mask=to_tensor))  # Convert image and mask to tensor format

    return album.Compose(_transform)  # Return the composed preprocessing transformations

# %%
# Create an augmented dataset with training images and masks, applying the defined augmentation techniques
augmented_dataset = PlantDiseaseDataset(
    train_images, train_masks,
    augmentation=get_training_augmentation(),  # Apply training augmentations
    class_rgb_values=select_class_rgb_values,  # RGB values for classes in the segmentation mask
)

# Randomly select an index from the augmented dataset
random_idx = random.randint(0, len(augmented_dataset)-1)
print(len(augmented_dataset))  # Print the length of the augmented dataset for verification

# Loop through a single sample for visualization
for i in range(1):
    # Get the image and its corresponding mask from the dataset
    image, mask = augmented_dataset[random_idx]

    # Generate the ground truth mask by converting the one-hot encoded mask to RGB colors
    ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values)

    # Visualize the image along with the ground truth and one-hot encoded mask
    visualize(
        original_image=image,  # The original image
        ground_truth_mask=ground_truth_mask,  # The ground truth mask in RGB
        one_hot_encoded_mask=reverse_one_hot(mask),  # The one-hot encoded mask
        overlay_ground_truth=overlay_ground_truth(image, ground_truth_mask)  # Overlay the ground truth mask on the image
    )

# %% [markdown]
# # **Model Architecture**

# %%
import segmentation_models_pytorch as smp

# %% [markdown]
# # **model in essay**

# %% [markdown]
# **FPN+efficientnet-b0**

# %% [markdown]
# *FPN (Feature Pyramid Network) combined with EfficientNet-B0 leverages EfficientNet's efficient architecture for feature extraction while utilizing FPN's multi-scale feature fusion for improved performance in tasks like object detection and segmentation.*

# %%
import segmentation_models_pytorch as smp

model = smp.FPN(
    encoder_name='efficientnet-b0',
    encoder_depth=3,
    encoder_weights='imagenet',
    decoder_pyramid_channels=256,
    decoder_segmentation_channels=128,
    decoder_merge_policy='add',
    in_channels=3,
    classes=2,
    activation='sigmoid',
    upsampling=1
)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 90.2MB/s]

# %% [markdown]
# **MA-Net**

# %% [markdown]
# *MA-Net (Multi-Attention Network) enhances image segmentation by integrating multiple attention mechanisms, improving feature extraction and segmentation accuracy.*

# %%
import segmentation_models_pytorch as smp

model = smp.MAnet(
    encoder_weights='imagenet',
    decoder_channels=(256, 128, 64, 32, 16),
    decoder_pab_channels=64,
    in_channels=3,
    classes=2,
    activation='sigmoid'
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 147MB/s]

# %% [markdown]
# **Linknet**

# %% [markdown]
# *LinkNet is a semantic segmentation model that combines an encoder-decoder structure with efficient skip connections, optimizing both performance and inference speed.*

# %%
model = smp.Linknet(
    encoder_weights='imagenet',
    in_channels=3,
    classes=2,
    activation='sigmoid'
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 115MB/s]

# %% [markdown]
# **PSPNet**

# %% [markdown]
# *PSPNet (Pyramid Scene Parsing Network) enhances semantic segmentation by leveraging a pyramid pooling module that captures contextual information across multiple scales to improve segmentation accuracy in complex scenes.*

# %%
model = smp.PSPNet(
    encoder_weights='imagenet',
    encoder_depth=3,
    psp_out_channels=512,
    in_channels=3,
    classes=2,
    activation='sigmoid',
    upsampling=8
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 395MB/s]

# %% [markdown]
# **Deeplabv3+**

# %% [markdown]
# *Deeplabv3+ is an advanced deep learning model for semantic segmentation, enhancing the original Deeplabv3 with a depthwise separable convolutional decoder to better capture spatial details and improve performance on pixel-level segmentation tasks.*

# %%
model = smp.DeepLabV3Plus(
    encoder_weights='imagenet',
    in_channels=3,
    classes=2,
    activation='sigmoid',
)

# %% [markdown]
# # **SCSE Mechanism**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Channel Attention Layer (cSE)
class ChannelSELayer(nn.Module):
    def __init__(self, num_channels, reduction_ratio=2):
        # Initialization of layers for channel attention (Squeeze-and-Excitation)
        super(ChannelSELayer, self).__init__()
        num_channels_reduced = num_channels // reduction_ratio  # Reduced channels for FC layer
        self.reduction_ratio = reduction_ratio
        self.fc1 = nn.Linear(num_channels, num_channels_reduced, bias=True)  # Fully connected layer 1
        self.fc2 = nn.Linear(num_channels_reduced, num_channels, bias=True)  # Fully connected layer 2
        self.relu = nn.ReLU()  # Activation function
        self.sigmoid = nn.Sigmoid()  # Activation function for scaling channels

    def forward(self, input_tensor):
        batch_size, num_channels, H, W = input_tensor.size()  # Get input tensor dimensions
        # Squeeze operation: average pooling over channels
        squeeze_tensor = input_tensor.view(batch_size, num_channels, -1).mean(dim=2)

        # Excitation: FC layers to learn importance of channels
        fc_out_1 = self.relu(self.fc1(squeeze_tensor))  # Apply first FC layer + ReLU
        fc_out_2 = self.sigmoid(self.fc2(fc_out_1))  # Apply second FC layer + Sigmoid for scaling

        a, b = squeeze_tensor.size()
        output_tensor = torch.mul(input_tensor, fc_out_2.view(a, b, 1, 1))  # Rescale input tensor
        return output_tensor

# Spatial Attention Layer (sSE)
class SpatialSELayer(nn.Module):
    def __init__(self, num_channels):
        super(SpatialSELayer, self).__init__()
        self.conv = nn.Conv2d(num_channels, 1, 1)  # 1x1 convolution to learn spatial attention
        self.sigmoid = nn.Sigmoid()  # Sigmoid for excitation

    def forward(self, input_tensor, weights=None):
        batch_size, channel, a, b = input_tensor.size()  # Get input tensor dimensions

        # If weights are provided, compute weighted sum over channels
        if weights is not None:
            weights = torch.mean(weights, dim=0)  # Take mean of weights
            weights = weights.view(1, channel, 1, 1)  # Reshape for convolution
            out = F.conv2d(input_tensor, weights)  # Apply convolution
        else:
            out = self.conv(input_tensor)  # Otherwise apply the learnable convolution

        squeeze_tensor = self.sigmoid(out)  # Apply sigmoid to get spatial attention map

        # Excitation: Rescale the input tensor by the attention map
        squeeze_tensor = squeeze_tensor.view(batch_size, 1, a, b)
        output_tensor = torch.mul(input_tensor, squeeze_tensor)  # Apply spatial excitation
        return output_tensor

# Combined Channel + Spatial Attention Layer (cSE + sSE)
class ChannelSpatialSELayer(nn.Module):
    def __init__(self, num_channels, reduction_ratio=2):
        super(ChannelSpatialSELayer, self).__init__()
        self.cSE = ChannelSELayer(num_channels, reduction_ratio)  # Channel SE
        self.sSE = SpatialSELayer(num_channels)  # Spatial SE

    def forward(self, input_tensor):
        # Combine channel and spatial attention
        # Alternative: Could use max instead of sum for combination
        output_tensor = self.cSE(input_tensor) + self.sSE(input_tensor)
        return output_tensor

# %% [markdown]
# **My model**

# %%
model = smp.Unet(
    encoder_name="resnet50",
    encoder_weights="imagenet",
    in_channels=3,
    classes=2,
    activation='sigmoid',
    decoder_attention_type='scse'
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 344MB/s]

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # **Train and Validation Instance**

# %%
import segmentation_models_pytorch.utils

# %%
# Get train and val dataset instances
train_dataset = PlantDiseaseDataset(
    train_images, train_masks,
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn=None),
    class_rgb_values=select_class_rgb_values,
)

valid_dataset = PlantDiseaseDataset(
    valid_images, valid_masks,
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn=None),
    class_rgb_values=select_class_rgb_values,
)

# Get train and val data loaders
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=12)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# # **Hyper Parameter Tunning**

# %%
# Flag to control if training is enabled
TRAINING = True

# Number of training epochs (iterations over the entire dataset)
EPOCHS = 35

# Set the device for training (CUDA if available, otherwise CPU)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Loss function: DiceLoss is commonly used for segmentation tasks to measure overlap between predicted and true masks
loss = smp.utils.losses.DiceLoss()

# Metrics to evaluate the model's performance, using IoU (Intersection over Union) with a threshold of 0.5
metrics = [
    smp.utils.metrics.IoU(threshold=0.5),
]

# Optimizer: Adam optimizer is used for efficient training with an initial learning rate of 0.0001
optimizer = torch.optim.Adam([
    dict(params=model.parameters(), lr=0.0001),  # Specify the parameters of the model and the learning rate
])

# Learning Rate Scheduler: CosineAnnealingWarmRestarts adjusts the learning rate during training to improve performance
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,   # The optimizer whose learning rate will be adjusted
    T_0=1,       # Initial number of iterations for the first restart
    T_mult=2,    # Multiplier for the period length after each restart
    eta_min=5e-5,  # Minimum learning rate
)

# %% [markdown]
# # **Choose the model  weights Path**

# %%
m_path = '/content/drive/MyDrive/my model.pth'

if os.path.exists(m_path):
    model = torch.load(m_path, map_location=DEVICE)

# %%
# Set up the training epoch with loss, metrics, and optimizer
train_epoch = smp.utils.train.TrainEpoch(
    model, loss=loss, metrics=metrics, optimizer=optimizer, device=DEVICE, verbose=True
)

# Set up the validation epoch with loss, metrics, and device
valid_epoch = smp.utils.train.ValidEpoch(
    model, loss=loss, metrics=metrics, device=DEVICE, verbose=True
)

# %% [markdown]
# # **Models Training**

# %% [markdown]
# **efficientnet-b0+FPN**

# %%
# %%time

if TRAINING:

    best_iou_score = 0.0
    train_logs_list, valid_logs_list = [], []

    for i in range(0, EPOCHS):

        # Perform training & validation
        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(valid_loader)
        train_logs_list.append(train_logs)
        valid_logs_list.append(valid_logs)

        # Save model if a better val IoU score is obtained
        if best_iou_score < valid_logs['iou_score']:
            best_iou_score = valid_logs['iou_score']
            torch.save(model, m_path)
            print('Model saved!')
# Out:
# Epoch: 0
# train: 100%|██████████| 265/265 [01:54<00:00,  2.32it/s, dice_loss - 0.1445, iou_score - 0.7549]
# valid: 100%|██████████| 588/588 [00:24<00:00, 23.70it/s, dice_loss - 0.1271, iou_score - 0.7909]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 265/265 [01:55<00:00,  2.30it/s, dice_loss - 0.1255, iou_score - 0.7805]
# valid: 100%|██████████| 588/588 [00:22<00:00, 25.72it/s, dice_loss - 0.1219, iou_score - 0.7981]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 265/265 [01:52<00:00,  2.36it/s, dice_loss - 0.1229, iou_score - 0.7848]
# valid: 100%|██████████| 588/588 [00:25<00:00, 22.96it/s, dice_loss - 0.1196, iou_score - 0.8005]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 265/265 [01:52<00:00,  2.36it/s, dice_loss - 0.1201, iou_score - 0.7886]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.00it/s, dice_loss - 0.117, iou_score - 0.8035]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 265/265 [01:53<00:00,  2.33it/s, dice_loss - 0.1181, iou_score - 0.7918]
# valid: 100%|██████████| 588/588 [00:26<00:00, 22.54it/s, dice_loss - 0.1149, iou_score - 0.8062]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 265/265 [01:51<00:00,  2.37it/s, dice_loss - 0.1168, iou_score - 0.7938]
# valid: 100%|██████████| 588/588 [00:24<00:00, 24.27it/s, dice_loss - 0.1142, iou_score - 0.8078]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 265/265 [01:55<00:00,  2.30it/s, dice_loss - 0.1153, iou_score - 0.796]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.33it/s, dice_loss - 0.1138, iou_score - 0.8061]
#
# Epoch: 7
# train: 100%|██████████| 265/265 [01:52<00:00,  2.36it/s, dice_loss - 0.1098, iou_score - 0.8057]
# valid: 100%|██████████| 588/588 [00:24<00:00, 23.79it/s, dice_loss - 0.08668, iou_score - 0.8528]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 265/265 [01:54<00:00,  2.31it/s, dice_loss - 0.08539, iou_score - 0.8478]
# valid: 100%|██████████| 588/588 [00:22<00:00, 25.74it/s, dice_loss - 0.08452, iou_score - 0.8568]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 265/265 [01:52<00:00,  2.35it/s, dice_loss - 0.07951, iou_score - 0.857]
# valid: 100%|██████████| 588/588 [00:24<00:00, 23.76it/s, dice_loss - 0.08061, iou_score - 0.8624]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 265/265 [01:52<00:00,  2.35it/s, dice_loss - 0.07798, iou_score - 0.8594]
# valid: 100%|██████████| 588/588 [00:24<00:00, 24.32it/s, dice_loss - 0.0791, iou_score - 0.865]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 265/265 [01:54<00:00,  2.32it/s, dice_loss - 0.07497, iou_score - 0.8645]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.47it/s, dice_loss - 0.07537, iou_score - 0.8699]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 265/265 [01:51<00:00,  2.37it/s, dice_loss - 0.07338, iou_score - 0.8672]
# valid: 100%|██████████| 588/588 [00:24<00:00, 24.04it/s, dice_loss - 0.074, iou_score - 0.8721]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 265/265 [01:55<00:00,  2.30it/s, dice_loss - 0.07228, iou_score - 0.869]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.35it/s, dice_loss - 0.07322, iou_score - 0.8729]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 265/265 [01:52<00:00,  2.35it/s, dice_loss - 0.06905, iou_score - 0.8745]
# valid: 100%|██████████| 588/588 [00:24<00:00, 23.82it/s, dice_loss - 0.0732, iou_score - 0.8729]
#
# Epoch: 15
# train: 100%|██████████| 265/265 [01:54<00:00,  2.31it/s, dice_loss - 0.06689, iou_score - 0.8783]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.30it/s, dice_loss - 0.07102, iou_score - 0.8763]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 265/265 [01:52<00:00,  2.36it/s, dice_loss - 0.06519, iou_score - 0.8812]
# valid: 100%|██████████| 588/588 [00:25<00:00, 23.50it/s, dice_loss - 0.06983, iou_score - 0.8787]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 265/265 [01:54<00:00,  2.31it/s, dice_loss - 0.06445, iou_score - 0.8824]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.12it/s, dice_loss - 0.0697, iou_score - 0.8784]
#
# Epoch: 18
# train: 100%|██████████| 265/265 [01:54<00:00,  2.32it/s, dice_loss - 0.06274, iou_score - 0.8853]
# valid: 100%|██████████| 588/588 [00:24<00:00, 23.71it/s, dice_loss - 0.0686, iou_score - 0.8801]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 265/265 [01:55<00:00,  2.30it/s, dice_loss - 0.06185, iou_score - 0.8868]
# valid: 100%|██████████| 588/588 [00:23<00:00, 24.70it/s, dice_loss - 0.06754, iou_score - 0.8817]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 265/265 [01:52<00:00,  2.36it/s, dice_loss - 0.05996, iou_score - 0.8901]
# valid: 100%|██████████| 588/588 [00:25<00:00, 23.00it/s, dice_loss - 0.06838, iou_score - 0.8811]
#
# Epoch: 21
# train: 100%|██████████| 265/265 [01:51<00:00,  2.37it/s, dice_loss - 0.05895, iou_score - 0.8918]
# valid: 100%|██████████| 588/588 [00:24<00:00, 24.36it/s, dice_loss - 0.06398, iou_score - 0.8869]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 265/265 [01:54<00:00,  2.31it/s, dice_loss - 0.05847, iou_score - 0.8925]
# valid: 100%|██████████| 588/588 [00:25<00:00, 23.48it/s, dice_loss - 0.06315, iou_score - 0.8885]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 265/265 [01:52<00:00,  2.36it/s, dice_loss - 0.05655, iou_score - 0.8958]
# valid: 100%|██████████| 588/588 [00:25<00:00, 23.34it/s, dice_loss - 0.06489, iou_score - 0.8863]
#
# Epoch: 24
# train: 100%|██████████| 265/265 [01:54<00:00,  2.32it/s, dice_loss - 0.05773, iou_score - 0.8939]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.54it/s, dice_loss - 0.06191, iou_score - 0.8903]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████| 265/265 [01:53<00:00,  2.34it/s, dice_loss - 0.05694, iou_score - 0.8951]
# valid: 100%|██████████| 588/588 [00:25<00:00, 23.25it/s, dice_loss - 0.07185, iou_score - 0.8742]
#
# Epoch: 26
# train: 100%|██████████| 265/265 [01:52<00:00,  2.35it/s, dice_loss - 0.05507, iou_score - 0.8983]
# valid: 100%|██████████| 588/588 [00:24<00:00, 24.36it/s, dice_loss - 0.06295, iou_score - 0.889]
#
# Epoch: 27
# train: 100%|██████████| 265/265 [01:55<00:00,  2.29it/s, dice_loss - 0.05393, iou_score - 0.9004]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.21it/s, dice_loss - 0.0611, iou_score - 0.8919]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 265/265 [01:53<00:00,  2.34it/s, dice_loss - 0.05259, iou_score - 0.9026]
# valid: 100%|██████████| 588/588 [00:25<00:00, 23.33it/s, dice_loss - 0.06577, iou_score - 0.885]
#
# Epoch: 29
# train: 100%|██████████| 265/265 [01:54<00:00,  2.32it/s, dice_loss - 0.05261, iou_score - 0.9026]
# valid: 100%|██████████| 588/588 [00:23<00:00, 24.94it/s, dice_loss - 0.06063, iou_score - 0.8928]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 265/265 [01:53<00:00,  2.34it/s, dice_loss - 0.05152, iou_score - 0.9046]
# valid: 100%|██████████| 588/588 [00:23<00:00, 24.51it/s, dice_loss - 0.05922, iou_score - 0.8947]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 265/265 [01:54<00:00,  2.31it/s, dice_loss - 0.05083, iou_score - 0.9057]
# valid: 100%|██████████| 588/588 [00:23<00:00, 24.76it/s, dice_loss - 0.06117, iou_score - 0.8915]
#
# Epoch: 32
# train: 100%|██████████| 265/265 [01:52<00:00,  2.35it/s, dice_loss - 0.05134, iou_score - 0.9048]
# valid: 100%|██████████| 588/588 [00:24<00:00, 23.83it/s, dice_loss - 0.06343, iou_score - 0.8882]
#
# Epoch: 33
# train: 100%|██████████| 265/265 [01:52<00:00,  2.35it/s, dice_loss - 0.05111, iou_score - 0.9052]
# valid: 100%|██████████| 588/588 [00:24<00:00, 24.02it/s, dice_loss - 0.05846, iou_score - 0.8962]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 265/265 [01:53<00:00,  2.34it/s, dice_loss - 0.04948, iou_score - 0.908]
# valid: 100%|██████████| 588/588 [00:25<00:00, 22.98it/s, dice_loss - 0.06075, iou_score - 0.8925]
# CPU times: user 53min 10s, sys: 1min 55s, total: 55min 6s
# Wall time: 1h 20min 29s

# %% [markdown]
# **MA-Net**

# %%
# %%time

if TRAINING:

    best_iou_score = 0.0
    train_logs_list, valid_logs_list = [], []

    for i in range(0, EPOCHS):

        # Perform training & validation
        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(valid_loader)
        train_logs_list.append(train_logs)
        valid_logs_list.append(valid_logs)

        # Save model if a better val IoU score is obtained
        if best_iou_score < valid_logs['iou_score']:
            best_iou_score = valid_logs['iou_score']
            torch.save(model, m_path)
            print('Model saved!')
# Out:
# Epoch: 0
# train: 100%|██████████| 265/265 [01:00<00:00,  4.39it/s, dice_loss - 0.2465, iou_score - 0.7473]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.52it/s, dice_loss - 0.1365, iou_score - 0.8517]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 265/265 [00:54<00:00,  4.84it/s, dice_loss - 0.1179, iou_score - 0.8456]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.51it/s, dice_loss - 0.0963, iou_score - 0.8705]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 265/265 [00:55<00:00,  4.74it/s, dice_loss - 0.08792, iou_score - 0.8661]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.69it/s, dice_loss - 0.08045, iou_score - 0.8783]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 265/265 [00:56<00:00,  4.70it/s, dice_loss - 0.07265, iou_score - 0.882]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.91it/s, dice_loss - 0.07217, iou_score - 0.8851]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 265/265 [00:56<00:00,  4.71it/s, dice_loss - 0.0641, iou_score - 0.892]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.45it/s, dice_loss - 0.065, iou_score - 0.8926]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 265/265 [00:57<00:00,  4.62it/s, dice_loss - 0.06053, iou_score - 0.8949]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.82it/s, dice_loss - 0.06051, iou_score - 0.8976]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 265/265 [00:56<00:00,  4.67it/s, dice_loss - 0.05167, iou_score - 0.9086]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.37it/s, dice_loss - 0.05797, iou_score - 0.9012]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 265/265 [00:55<00:00,  4.77it/s, dice_loss - 0.05767, iou_score - 0.8969]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.45it/s, dice_loss - 0.078, iou_score - 0.8684]
#
# Epoch: 8
# train: 100%|██████████| 265/265 [00:55<00:00,  4.74it/s, dice_loss - 0.05701, iou_score - 0.8965]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.66it/s, dice_loss - 0.06242, iou_score - 0.8906]
#
# Epoch: 9
# train: 100%|██████████| 265/265 [00:55<00:00,  4.79it/s, dice_loss - 0.04979, iou_score - 0.9087]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.00it/s, dice_loss - 0.06184, iou_score - 0.8928]
#
# Epoch: 10
# train: 100%|██████████| 265/265 [00:55<00:00,  4.75it/s, dice_loss - 0.04469, iou_score - 0.9176]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.77it/s, dice_loss - 0.05517, iou_score - 0.9029]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 265/265 [00:57<00:00,  4.63it/s, dice_loss - 0.04173, iou_score - 0.9225]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.50it/s, dice_loss - 0.05082, iou_score - 0.9101]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 265/265 [00:57<00:00,  4.62it/s, dice_loss - 0.03751, iou_score - 0.9299]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.26it/s, dice_loss - 0.04734, iou_score - 0.9152]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 265/265 [00:55<00:00,  4.75it/s, dice_loss - 0.03522, iou_score - 0.934]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.67it/s, dice_loss - 0.04638, iou_score - 0.9164]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 265/265 [00:56<00:00,  4.67it/s, dice_loss - 0.03392, iou_score - 0.9361]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.84it/s, dice_loss - 0.0456, iou_score - 0.9179]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 265/265 [00:54<00:00,  4.85it/s, dice_loss - 0.03232, iou_score - 0.9389]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.50it/s, dice_loss - 0.04453, iou_score - 0.9191]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 265/265 [00:57<00:00,  4.62it/s, dice_loss - 0.03069, iou_score - 0.9418]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.78it/s, dice_loss - 0.04484, iou_score - 0.9187]
#
# Epoch: 17
# train: 100%|██████████| 265/265 [00:55<00:00,  4.74it/s, dice_loss - 0.03034, iou_score - 0.9423]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.07it/s, dice_loss - 0.04381, iou_score - 0.9207]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 265/265 [00:56<00:00,  4.65it/s, dice_loss - 0.02954, iou_score - 0.9437]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.18it/s, dice_loss - 0.04584, iou_score - 0.9169]
#
# Epoch: 19
# train: 100%|██████████| 265/265 [00:56<00:00,  4.68it/s, dice_loss - 0.03499, iou_score - 0.9334]
# valid: 100%|██████████| 588/588 [00:19<00:00, 29.75it/s, dice_loss - 0.04834, iou_score - 0.9134]
#
# Epoch: 20
# train: 100%|██████████| 265/265 [00:57<00:00,  4.64it/s, dice_loss - 0.02954, iou_score - 0.9435]
# valid: 100%|██████████| 588/588 [00:18<00:00, 30.96it/s, dice_loss - 0.04414, iou_score - 0.9196]
#
# Epoch: 21
# train: 100%|██████████| 265/265 [00:57<00:00,  4.65it/s, dice_loss - 0.02874, iou_score - 0.945]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.67it/s, dice_loss - 0.04146, iou_score - 0.9241]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 265/265 [00:54<00:00,  4.85it/s, dice_loss - 0.02764, iou_score - 0.9469]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.48it/s, dice_loss - 0.0432, iou_score - 0.9219]
#
# Epoch: 23
# train: 100%|██████████| 265/265 [00:54<00:00,  4.83it/s, dice_loss - 0.0316, iou_score - 0.9396]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.63it/s, dice_loss - 0.05557, iou_score - 0.9015]
#
# Epoch: 24
# train: 100%|██████████| 265/265 [00:55<00:00,  4.75it/s, dice_loss - 0.02987, iou_score - 0.9427]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.40it/s, dice_loss - 0.04833, iou_score - 0.9129]
#
# Epoch: 25
# train: 100%|██████████| 265/265 [00:55<00:00,  4.81it/s, dice_loss - 0.02948, iou_score - 0.9434]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.88it/s, dice_loss - 0.04459, iou_score - 0.9194]
#
# Epoch: 26
# train: 100%|██████████| 265/265 [00:55<00:00,  4.77it/s, dice_loss - 0.02673, iou_score - 0.9485]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.86it/s, dice_loss - 0.04168, iou_score - 0.9243]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 265/265 [00:56<00:00,  4.73it/s, dice_loss - 0.03077, iou_score - 0.941]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.20it/s, dice_loss - 0.04982, iou_score - 0.9097]
#
# Epoch: 28
# train: 100%|██████████| 265/265 [00:56<00:00,  4.67it/s, dice_loss - 0.03263, iou_score - 0.9375]
# valid: 100%|██████████| 588/588 [00:19<00:00, 30.13it/s, dice_loss - 0.04522, iou_score - 0.9186]
#
# Epoch: 29
# train: 100%|██████████| 265/265 [00:55<00:00,  4.77it/s, dice_loss - 0.02652, iou_score - 0.9488]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.58it/s, dice_loss - 0.04076, iou_score - 0.9253]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 265/265 [00:55<00:00,  4.80it/s, dice_loss - 0.02437, iou_score - 0.9529]
# valid: 100%|██████████| 588/588 [00:17<00:00, 32.76it/s, dice_loss - 0.03886, iou_score - 0.9287]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 265/265 [00:56<00:00,  4.70it/s, dice_loss - 0.02513, iou_score - 0.9514]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.99it/s, dice_loss - 0.04275, iou_score - 0.9223]
#
# Epoch: 32
# train: 100%|██████████| 265/265 [00:55<00:00,  4.79it/s, dice_loss - 0.02392, iou_score - 0.9537]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.21it/s, dice_loss - 0.04118, iou_score - 0.9254]
#
# Epoch: 33
# train: 100%|██████████| 265/265 [00:56<00:00,  4.70it/s, dice_loss - 0.02781, iou_score - 0.9464]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.02it/s, dice_loss - 0.04599, iou_score - 0.9162]
#
# Epoch: 34
# train: 100%|██████████| 265/265 [00:57<00:00,  4.63it/s, dice_loss - 0.02602, iou_score - 0.9497]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.18it/s, dice_loss - 0.04101, iou_score - 0.9254]
# CPU times: user 19min 58s, sys: 1min 31s, total: 21min 29s
# Wall time: 43min 56s

# %% [markdown]
# **Linknet**

# %%
# %%time

if TRAINING:

    best_iou_score = 0.0
    train_logs_list, valid_logs_list = [], []

    for i in range(0, EPOCHS):

        # Perform training & validation
        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(valid_loader)
        train_logs_list.append(train_logs)
        valid_logs_list.append(valid_logs)

        # Save model if a better val IoU score is obtained
        if best_iou_score < valid_logs['iou_score']:
            best_iou_score = valid_logs['iou_score']
            torch.save(model, m_path)
            print('Model saved!')
# Out:
# Epoch: 0
# train:   0%|          | 0/265 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# train: 100%|██████████| 265/265 [00:54<00:00,  4.90it/s, dice_loss - 0.3286, iou_score - 0.7081]
# valid:   0%|          | 0/588 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.47it/s, dice_loss - 0.2395, iou_score - 0.8186]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 265/265 [00:49<00:00,  5.33it/s, dice_loss - 0.2037, iou_score - 0.8343]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.51it/s, dice_loss - 0.1717, iou_score - 0.8601]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 265/265 [00:47<00:00,  5.54it/s, dice_loss - 0.1458, iou_score - 0.8723]
# valid: 100%|██████████| 588/588 [00:17<00:00, 33.48it/s, dice_loss - 0.1286, iou_score - 0.8833]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 265/265 [00:47<00:00,  5.60it/s, dice_loss - 0.1124, iou_score - 0.8901]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.90it/s, dice_loss - 0.1046, iou_score - 0.8847]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 265/265 [00:46<00:00,  5.67it/s, dice_loss - 0.08901, iou_score - 0.9034]
# valid: 100%|██████████| 588/588 [00:16<00:00, 35.34it/s, dice_loss - 0.08798, iou_score - 0.8975]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 265/265 [00:48<00:00,  5.51it/s, dice_loss - 0.07872, iou_score - 0.9033]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.53it/s, dice_loss - 0.08125, iou_score - 0.8949]
#
# Epoch: 6
# train: 100%|██████████| 265/265 [00:48<00:00,  5.43it/s, dice_loss - 0.0666, iou_score - 0.9135]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.82it/s, dice_loss - 0.07105, iou_score - 0.9034]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 265/265 [00:48<00:00,  5.51it/s, dice_loss - 0.05609, iou_score - 0.9241]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.76it/s, dice_loss - 0.06035, iou_score - 0.9138]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 265/265 [00:47<00:00,  5.55it/s, dice_loss - 0.04744, iou_score - 0.9339]
# valid: 100%|██████████| 588/588 [00:17<00:00, 33.75it/s, dice_loss - 0.05645, iou_score - 0.9161]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 265/265 [00:48<00:00,  5.46it/s, dice_loss - 0.04175, iou_score - 0.9393]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.85it/s, dice_loss - 0.05362, iou_score - 0.9167]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 265/265 [00:48<00:00,  5.44it/s, dice_loss - 0.03738, iou_score - 0.9436]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.22it/s, dice_loss - 0.04907, iou_score - 0.9216]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 265/265 [00:49<00:00,  5.37it/s, dice_loss - 0.03433, iou_score - 0.9465]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.25it/s, dice_loss - 0.04917, iou_score - 0.92]
#
# Epoch: 12
# train: 100%|██████████| 265/265 [00:47<00:00,  5.58it/s, dice_loss - 0.0329, iou_score - 0.9472]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.10it/s, dice_loss - 0.0507, iou_score - 0.9162]
#
# Epoch: 13
# train: 100%|██████████| 265/265 [00:48<00:00,  5.52it/s, dice_loss - 0.04042, iou_score - 0.931]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.48it/s, dice_loss - 0.05118, iou_score - 0.9139]
#
# Epoch: 14
# train: 100%|██████████| 265/265 [00:47<00:00,  5.54it/s, dice_loss - 0.03389, iou_score - 0.9421]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.26it/s, dice_loss - 0.04768, iou_score - 0.9185]
#
# Epoch: 15
# train: 100%|██████████| 265/265 [00:46<00:00,  5.65it/s, dice_loss - 0.02952, iou_score - 0.9491]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.91it/s, dice_loss - 0.04372, iou_score - 0.9245]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 265/265 [00:47<00:00,  5.63it/s, dice_loss - 0.02696, iou_score - 0.953]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.42it/s, dice_loss - 0.04194, iou_score - 0.9266]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 265/265 [00:48<00:00,  5.47it/s, dice_loss - 0.0252, iou_score - 0.9556]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.66it/s, dice_loss - 0.04257, iou_score - 0.9255]
#
# Epoch: 18
# train: 100%|██████████| 265/265 [00:47<00:00,  5.57it/s, dice_loss - 0.0258, iou_score - 0.9538]
# valid: 100%|██████████| 588/588 [00:17<00:00, 33.53it/s, dice_loss - 0.04322, iou_score - 0.9234]
#
# Epoch: 19
# train: 100%|██████████| 265/265 [00:47<00:00,  5.54it/s, dice_loss - 0.02379, iou_score - 0.957]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.52it/s, dice_loss - 0.04086, iou_score - 0.927]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 265/265 [00:48<00:00,  5.44it/s, dice_loss - 0.0225, iou_score - 0.9591]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.63it/s, dice_loss - 0.03954, iou_score - 0.9292]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 265/265 [00:47<00:00,  5.61it/s, dice_loss - 0.02167, iou_score - 0.9603]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.52it/s, dice_loss - 0.03999, iou_score - 0.9281]
#
# Epoch: 22
# train: 100%|██████████| 265/265 [00:46<00:00,  5.68it/s, dice_loss - 0.02084, iou_score - 0.9615]
# valid: 100%|██████████| 588/588 [00:17<00:00, 34.42it/s, dice_loss - 0.0395, iou_score - 0.9289]
#
# Epoch: 23
# train: 100%|██████████| 265/265 [00:45<00:00,  5.78it/s, dice_loss - 0.01988, iou_score - 0.9631]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.60it/s, dice_loss - 0.03863, iou_score - 0.93]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 265/265 [00:47<00:00,  5.59it/s, dice_loss - 0.01966, iou_score - 0.9633]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.60it/s, dice_loss - 0.04038, iou_score - 0.9269]
#
# Epoch: 25
# train: 100%|██████████| 265/265 [00:46<00:00,  5.73it/s, dice_loss - 0.01916, iou_score - 0.964]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.72it/s, dice_loss - 0.03898, iou_score - 0.929]
#
# Epoch: 26
# train: 100%|██████████| 265/265 [00:46<00:00,  5.67it/s, dice_loss - 0.01872, iou_score - 0.9647]
# valid: 100%|██████████| 588/588 [00:16<00:00, 34.80it/s, dice_loss - 0.03784, iou_score - 0.9308]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 265/265 [00:48<00:00,  5.49it/s, dice_loss - 0.01809, iou_score - 0.9657]
# valid: 100%|██████████| 588/588 [00:17<00:00, 33.18it/s, dice_loss - 0.03849, iou_score - 0.9301]
#
# Epoch: 28
# train: 100%|██████████| 265/265 [00:49<00:00,  5.40it/s, dice_loss - 0.01758, iou_score - 0.9666]
# valid: 100%|██████████| 588/588 [00:18<00:00, 31.78it/s, dice_loss - 0.03813, iou_score - 0.9307]
#
# Epoch: 29
# train: 100%|██████████| 265/265 [00:48<00:00,  5.42it/s, dice_loss - 0.0172, iou_score - 0.9672]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.09it/s, dice_loss - 0.03734, iou_score - 0.9319]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 265/265 [00:49<00:00,  5.33it/s, dice_loss - 0.01671, iou_score - 0.9681]
# valid: 100%|██████████| 588/588 [00:17<00:00, 33.07it/s, dice_loss - 0.03763, iou_score - 0.9313]
#
# Epoch: 31
# train: 100%|██████████| 265/265 [00:47<00:00,  5.64it/s, dice_loss - 0.01644, iou_score - 0.9685]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.63it/s, dice_loss - 0.03745, iou_score - 0.9317]
#
# Epoch: 32
# train: 100%|██████████| 265/265 [00:47<00:00,  5.62it/s, dice_loss - 0.01653, iou_score - 0.9682]
# valid: 100%|██████████| 588/588 [00:18<00:00, 32.30it/s, dice_loss - 0.03915, iou_score - 0.9291]
#
# Epoch: 33
# train: 100%|██████████| 265/265 [00:47<00:00,  5.54it/s, dice_loss - 0.01601, iou_score - 0.9692]
# valid: 100%|██████████| 588/588 [00:17<00:00, 32.95it/s, dice_loss - 0.03818, iou_score - 0.9311]
#
# Epoch: 34
# train: 100%|██████████| 265/265 [00:46<00:00,  5.68it/s, dice_loss - 0.01582, iou_score - 0.9695]
# valid: 100%|██████████| 588/588 [00:17<00:00, 33.14it/s, dice_loss - 0.03903, iou_score - 0.9297]
# CPU times: user 14min 46s, sys: 1min 28s, total: 16min 14s
# Wall time: 38min 11s

# %% [markdown]
# **PSPNet**

# %%
# %%time

if TRAINING:

    best_iou_score = 0.0
    train_logs_list, valid_logs_list = [], []

    for i in range(0, EPOCHS):

        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(valid_loader)
        train_logs_list.append(train_logs)
        valid_logs_list.append(valid_logs)

        if best_iou_score < valid_logs['iou_score']:
            best_iou_score = valid_logs['iou_score']
            torch.save(model, m_path)
            print('Model saved!')
# Out:
# Epoch: 0
# train: 100%|██████████| 265/265 [00:49<00:00,  5.31it/s, dice_loss - 0.1618, iou_score - 0.7435]
# valid: 100%|██████████| 588/588 [00:17<00:00, 33.60it/s, dice_loss - 0.1267, iou_score - 0.794]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 265/265 [00:44<00:00,  5.94it/s, dice_loss - 0.1211, iou_score - 0.7907]
# valid: 100%|██████████| 588/588 [00:14<00:00, 39.51it/s, dice_loss - 0.1185, iou_score - 0.812]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 265/265 [00:42<00:00,  6.29it/s, dice_loss - 0.09434, iou_score - 0.8362]
# valid: 100%|██████████| 588/588 [00:15<00:00, 37.43it/s, dice_loss - 0.08998, iou_score - 0.8504]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 265/265 [00:52<00:00,  5.10it/s, dice_loss - 0.08318, iou_score - 0.8536]
# valid: 100%|██████████| 588/588 [00:14<00:00, 39.24it/s, dice_loss - 0.08189, iou_score - 0.862]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 265/265 [00:42<00:00,  6.24it/s, dice_loss - 0.07546, iou_score - 0.866]
# valid: 100%|██████████| 588/588 [00:15<00:00, 37.41it/s, dice_loss - 0.08268, iou_score - 0.8595]
#
# Epoch: 5
# train: 100%|██████████| 265/265 [00:48<00:00,  5.44it/s, dice_loss - 0.06793, iou_score - 0.8785]
# valid: 100%|██████████| 588/588 [00:14<00:00, 39.66it/s, dice_loss - 0.07367, iou_score - 0.8735]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 265/265 [00:42<00:00,  6.21it/s, dice_loss - 0.06394, iou_score - 0.8852]
# valid: 100%|██████████| 588/588 [00:16<00:00, 35.36it/s, dice_loss - 0.07487, iou_score - 0.8721]
#
# Epoch: 7
# train: 100%|██████████| 265/265 [00:46<00:00,  5.69it/s, dice_loss - 0.06014, iou_score - 0.8913]
# valid: 100%|██████████| 588/588 [00:14<00:00, 40.93it/s, dice_loss - 0.07487, iou_score - 0.8715]
#
# Epoch: 8
# train: 100%|██████████| 265/265 [00:41<00:00,  6.36it/s, dice_loss - 0.0558, iou_score - 0.8986]
# valid: 100%|██████████| 588/588 [00:16<00:00, 35.47it/s, dice_loss - 0.06837, iou_score - 0.8811]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 265/265 [00:49<00:00,  5.39it/s, dice_loss - 0.05401, iou_score - 0.9017]
# valid: 100%|██████████| 588/588 [00:14<00:00, 40.04it/s, dice_loss - 0.06728, iou_score - 0.8819]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 265/265 [00:42<00:00,  6.18it/s, dice_loss - 0.05141, iou_score - 0.906]
# valid: 100%|██████████| 588/588 [00:16<00:00, 35.95it/s, dice_loss - 0.06601, iou_score - 0.8849]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 265/265 [00:49<00:00,  5.36it/s, dice_loss - 0.04817, iou_score - 0.9114]
# valid: 100%|██████████| 588/588 [00:15<00:00, 38.98it/s, dice_loss - 0.06505, iou_score - 0.886]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 265/265 [00:42<00:00,  6.21it/s, dice_loss - 0.04654, iou_score - 0.9143]
# valid: 100%|██████████| 588/588 [00:16<00:00, 36.54it/s, dice_loss - 0.06358, iou_score - 0.8883]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 265/265 [00:48<00:00,  5.41it/s, dice_loss - 0.04533, iou_score - 0.9162]
# valid: 100%|██████████| 588/588 [00:14<00:00, 39.69it/s, dice_loss - 0.06649, iou_score - 0.8836]
#
# Epoch: 14
# train: 100%|██████████| 265/265 [00:42<00:00,  6.29it/s, dice_loss - 0.04379, iou_score - 0.9189]
# valid: 100%|██████████| 588/588 [00:16<00:00, 36.62it/s, dice_loss - 0.06278, iou_score - 0.8895]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 265/265 [00:47<00:00,  5.57it/s, dice_loss - 0.04241, iou_score - 0.9213]
# valid: 100%|██████████| 588/588 [00:14<00:00, 40.22it/s, dice_loss - 0.07019, iou_score - 0.878]
#
# Epoch: 16
# train: 100%|██████████| 265/265 [00:42<00:00,  6.23it/s, dice_loss - 0.04105, iou_score - 0.9236]
# valid: 100%|██████████| 588/588 [00:16<00:00, 36.70it/s, dice_loss - 0.06151, iou_score - 0.8916]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 265/265 [00:47<00:00,  5.63it/s, dice_loss - 0.03973, iou_score - 0.9259]
# valid: 100%|██████████| 588/588 [00:14<00:00, 41.29it/s, dice_loss - 0.06122, iou_score - 0.8918]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 265/265 [00:42<00:00,  6.20it/s, dice_loss - 0.03924, iou_score - 0.9268]
# valid: 100%|██████████| 588/588 [00:16<00:00, 36.32it/s, dice_loss - 0.06463, iou_score - 0.8859]
#
# Epoch: 19
# train: 100%|██████████| 265/265 [00:47<00:00,  5.60it/s, dice_loss - 0.03766, iou_score - 0.9295]
# valid: 100%|██████████| 588/588 [00:14<00:00, 39.67it/s, dice_loss - 0.06216, iou_score - 0.8904]
#
# Epoch: 20
# train: 100%|██████████| 265/265 [00:41<00:00,  6.43it/s, dice_loss - 0.0367, iou_score - 0.9312]
# valid: 100%|██████████| 588/588 [00:16<00:00, 36.55it/s, dice_loss - 0.05943, iou_score - 0.8942]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 265/265 [00:47<00:00,  5.58it/s, dice_loss - 0.03634, iou_score - 0.9318]
# valid: 100%|██████████| 588/588 [00:14<00:00, 40.24it/s, dice_loss - 0.06017, iou_score - 0.8935]
#
# Epoch: 22
# train: 100%|██████████| 265/265 [00:41<00:00,  6.35it/s, dice_loss - 0.03523, iou_score - 0.9338]
# valid: 100%|██████████| 588/588 [00:16<00:00, 36.57it/s, dice_loss - 0.05911, iou_score - 0.8951]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 265/265 [00:47<00:00,  5.58it/s, dice_loss - 0.03443, iou_score - 0.9353]
# valid: 100%|██████████| 588/588 [00:15<00:00, 38.36it/s, dice_loss - 0.05983, iou_score - 0.8936]
#
# Epoch: 24
# train: 100%|██████████| 265/265 [00:42<00:00,  6.28it/s, dice_loss - 0.03375, iou_score - 0.9364]
# valid: 100%|██████████| 588/588 [00:16<00:00, 36.22it/s, dice_loss - 0.0597, iou_score - 0.8942]
#
# Epoch: 25
# train: 100%|██████████| 265/265 [00:47<00:00,  5.54it/s, dice_loss - 0.03301, iou_score - 0.9377]
# valid: 100%|██████████| 588/588 [00:14<00:00, 40.68it/s, dice_loss - 0.06055, iou_score - 0.8925]
#
# Epoch: 26
# train: 100%|██████████| 265/265 [00:41<00:00,  6.39it/s, dice_loss - 0.0321, iou_score - 0.9393]
# valid: 100%|██████████| 588/588 [00:16<00:00, 35.36it/s, dice_loss - 0.06174, iou_score - 0.8911]
#
# Epoch: 27
# train: 100%|██████████| 265/265 [00:46<00:00,  5.66it/s, dice_loss - 0.03208, iou_score - 0.9394]
# valid: 100%|██████████| 588/588 [00:14<00:00, 40.79it/s, dice_loss - 0.05816, iou_score - 0.8967]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 265/265 [00:42<00:00,  6.29it/s, dice_loss - 0.03136, iou_score - 0.9406]
# valid: 100%|██████████| 588/588 [00:16<00:00, 35.93it/s, dice_loss - 0.06151, iou_score - 0.8913]
#
# Epoch: 29
# train: 100%|██████████| 265/265 [00:45<00:00,  5.79it/s, dice_loss - 0.03287, iou_score - 0.9379]
# valid: 100%|██████████| 588/588 [00:14<00:00, 40.51it/s, dice_loss - 0.05986, iou_score - 0.8942]
#
# Epoch: 30
# train: 100%|██████████| 265/265 [00:41<00:00,  6.35it/s, dice_loss - 0.03013, iou_score - 0.9428]
# valid: 100%|██████████| 588/588 [00:15<00:00, 37.10it/s, dice_loss - 0.05806, iou_score - 0.8966]
#
# Epoch: 31
# train: 100%|██████████| 265/265 [00:46<00:00,  5.69it/s, dice_loss - 0.02972, iou_score - 0.9436]
# valid: 100%|██████████| 588/588 [00:14<00:00, 41.50it/s, dice_loss - 0.05739, iou_score - 0.8981]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 265/265 [00:42<00:00,  6.23it/s, dice_loss - 0.02974, iou_score - 0.9436]
# valid: 100%|██████████| 588/588 [00:15<00:00, 36.86it/s, dice_loss - 0.05931, iou_score - 0.8954]
#
# Epoch: 33
# train: 100%|██████████| 265/265 [00:47<00:00,  5.64it/s, dice_loss - 0.02986, iou_score - 0.9433]
# valid: 100%|██████████| 588/588 [00:14<00:00, 39.68it/s, dice_loss - 0.05915, iou_score - 0.8945]
#
# Epoch: 34
# train: 100%|██████████| 265/265 [00:42<00:00,  6.24it/s, dice_loss - 0.02899, iou_score - 0.9449]
# valid: 100%|██████████| 588/588 [00:16<00:00, 35.89it/s, dice_loss - 0.0587, iou_score - 0.8953]
# CPU times: user 8min 18s, sys: 1min 29s, total: 9min 48s
# Wall time: 35min 26s

# %% [markdown]
# **my model**

# %%
# %%time

if TRAINING:

    best_iou_score = 0.0
    train_logs_list, valid_logs_list = [], []

    for i in range(0, EPOCHS):

        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(valid_loader)
        train_logs_list.append(train_logs)
        valid_logs_list.append(valid_logs)

        if best_iou_score < valid_logs['iou_score']:
            best_iou_score = valid_logs['iou_score']
            torch.save(model, m_path)
            print('Model saved!')
# Out:
# Epoch: 0
# train: 100%|██████████| 265/265 [01:19<00:00,  3.32it/s, dice_loss - 0.2369, iou_score - 0.7924]
# valid: 100%|██████████| 588/588 [00:23<00:00, 25.38it/s, dice_loss - 0.136, iou_score - 0.8737]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 265/265 [01:14<00:00,  3.54it/s, dice_loss - 0.1116, iou_score - 0.8703]
# valid: 100%|██████████| 588/588 [00:21<00:00, 26.78it/s, dice_loss - 0.09047, iou_score - 0.8875]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 265/265 [01:10<00:00,  3.74it/s, dice_loss - 0.077, iou_score - 0.8912]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.40it/s, dice_loss - 0.06659, iou_score - 0.9048]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 265/265 [01:11<00:00,  3.72it/s, dice_loss - 0.06417, iou_score - 0.8989]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.59it/s, dice_loss - 0.06039, iou_score - 0.9047]
#
# Epoch: 4
# train: 100%|██████████| 265/265 [01:10<00:00,  3.76it/s, dice_loss - 0.05562, iou_score - 0.9073]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.45it/s, dice_loss - 0.056, iou_score - 0.9076]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 265/265 [01:11<00:00,  3.73it/s, dice_loss - 0.04942, iou_score - 0.9149]
# valid: 100%|██████████| 588/588 [00:21<00:00, 26.83it/s, dice_loss - 0.05073, iou_score - 0.9131]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 265/265 [01:11<00:00,  3.70it/s, dice_loss - 0.04499, iou_score - 0.9205]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.25it/s, dice_loss - 0.05444, iou_score - 0.9067]
#
# Epoch: 7
# train: 100%|██████████| 265/265 [01:11<00:00,  3.73it/s, dice_loss - 0.04341, iou_score - 0.9217]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.34it/s, dice_loss - 0.04564, iou_score - 0.9198]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 265/265 [01:10<00:00,  3.73it/s, dice_loss - 0.03523, iou_score - 0.9357]
# valid: 100%|██████████| 588/588 [00:21<00:00, 27.14it/s, dice_loss - 0.04325, iou_score - 0.9231]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 265/265 [01:11<00:00,  3.72it/s, dice_loss - 0.032, iou_score - 0.941]
# valid: 100%|██████████| 588/588 [00:21<00:00, 27.00it/s, dice_loss - 0.04274, iou_score - 0.9236]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 265/265 [01:11<00:00,  3.70it/s, dice_loss - 0.03011, iou_score - 0.944]
# valid: 100%|██████████| 588/588 [00:21<00:00, 26.84it/s, dice_loss - 0.04075, iou_score - 0.9266]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 265/265 [01:11<00:00,  3.70it/s, dice_loss - 0.0285, iou_score - 0.9466]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.71it/s, dice_loss - 0.03995, iou_score - 0.9278]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 265/265 [01:11<00:00,  3.71it/s, dice_loss - 0.0273, iou_score - 0.9486]
# valid: 100%|██████████| 588/588 [00:21<00:00, 27.02it/s, dice_loss - 0.04165, iou_score - 0.9251]
#
# Epoch: 13
# train: 100%|██████████| 265/265 [01:10<00:00,  3.78it/s, dice_loss - 0.02973, iou_score - 0.9438]
# valid: 100%|██████████| 588/588 [00:21<00:00, 27.08it/s, dice_loss - 0.04096, iou_score - 0.9257]
#
# Epoch: 14
# train: 100%|██████████| 265/265 [01:09<00:00,  3.80it/s, dice_loss - 0.03198, iou_score - 0.9395]
# valid: 100%|██████████| 588/588 [00:21<00:00, 26.96it/s, dice_loss - 0.04756, iou_score - 0.9141]
#
# Epoch: 15
# train: 100%|██████████| 265/265 [01:11<00:00,  3.70it/s, dice_loss - 0.02863, iou_score - 0.9455]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.59it/s, dice_loss - 0.04152, iou_score - 0.9246]
#
# Epoch: 16
# train: 100%|██████████| 265/265 [01:10<00:00,  3.78it/s, dice_loss - 0.02512, iou_score - 0.952]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.52it/s, dice_loss - 0.03781, iou_score - 0.9305]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 265/265 [01:12<00:00,  3.67it/s, dice_loss - 0.02325, iou_score - 0.9555]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.70it/s, dice_loss - 0.03767, iou_score - 0.9311]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 265/265 [01:11<00:00,  3.73it/s, dice_loss - 0.02225, iou_score - 0.9573]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.46it/s, dice_loss - 0.0385, iou_score - 0.9295]
#
# Epoch: 19
# train: 100%|██████████| 265/265 [01:10<00:00,  3.76it/s, dice_loss - 0.03004, iou_score - 0.9426]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.43it/s, dice_loss - 0.0418, iou_score - 0.9241]
#
# Epoch: 20
# train: 100%|██████████| 265/265 [01:09<00:00,  3.80it/s, dice_loss - 0.02436, iou_score - 0.9532]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.68it/s, dice_loss - 0.03947, iou_score - 0.928]
#
# Epoch: 21
# train: 100%|██████████| 265/265 [01:10<00:00,  3.75it/s, dice_loss - 0.02405, iou_score - 0.9537]
# valid: 100%|██████████| 588/588 [00:21<00:00, 26.80it/s, dice_loss - 0.03811, iou_score - 0.9303]
#
# Epoch: 22
# train: 100%|██████████| 265/265 [01:10<00:00,  3.75it/s, dice_loss - 0.02538, iou_score - 0.9512]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.35it/s, dice_loss - 0.04308, iou_score - 0.9212]
#
# Epoch: 23
# train: 100%|██████████| 265/265 [01:10<00:00,  3.76it/s, dice_loss - 0.02381, iou_score - 0.9541]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.59it/s, dice_loss - 0.03632, iou_score - 0.9331]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 265/265 [01:11<00:00,  3.73it/s, dice_loss - 0.02039, iou_score - 0.9606]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.03it/s, dice_loss - 0.03481, iou_score - 0.936]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████| 265/265 [01:11<00:00,  3.70it/s, dice_loss - 0.01886, iou_score - 0.9634]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.22it/s, dice_loss - 0.03416, iou_score - 0.9368]
# Model saved!
#
# Epoch: 26
# train: 100%|██████████| 265/265 [01:12<00:00,  3.67it/s, dice_loss - 0.01812, iou_score - 0.9648]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.04it/s, dice_loss - 0.03341, iou_score - 0.9384]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 265/265 [01:12<00:00,  3.65it/s, dice_loss - 0.01732, iou_score - 0.9663]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.52it/s, dice_loss - 0.03337, iou_score - 0.9383]
#
# Epoch: 28
# train: 100%|██████████| 265/265 [01:10<00:00,  3.74it/s, dice_loss - 0.01671, iou_score - 0.9675]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.66it/s, dice_loss - 0.0337, iou_score - 0.9379]
#
# Epoch: 29
# train: 100%|██████████| 265/265 [01:10<00:00,  3.76it/s, dice_loss - 0.01629, iou_score - 0.9683]
# valid: 100%|██████████| 588/588 [00:22<00:00, 26.40it/s, dice_loss - 0.03283, iou_score - 0.9393]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 265/265 [01:12<00:00,  3.68it/s, dice_loss - 0.01584, iou_score - 0.9692]
# valid: 100%|██████████| 588/588 [00:21<00:00, 27.07it/s, dice_loss - 0.03332, iou_score - 0.9385]
#
# Epoch: 31
# train: 100%|██████████| 265/265 [01:10<00:00,  3.77it/s, dice_loss - 0.0156, iou_score - 0.9696]
# valid: 100%|██████████| 588/588 [00:21<00:00, 27.09it/s, dice_loss - 0.033, iou_score - 0.9388]
#
# Epoch: 32
# train: 100%|██████████| 265/265 [01:10<00:00,  3.75it/s, dice_loss - 0.01525, iou_score - 0.9703]
# valid: 100%|██████████| 588/588 [00:21<00:00, 26.78it/s, dice_loss - 0.03305, iou_score - 0.9386]
#
# Epoch: 33
# train: 100%|██████████| 265/265 [01:10<00:00,  3.74it/s, dice_loss - 0.01481, iou_score - 0.9711]
# valid: 100%|██████████| 588/588 [00:21<00:00, 27.00it/s, dice_loss - 0.03452, iou_score - 0.9365]
#
# Epoch: 34
# train: 100%|██████████| 265/265 [01:09<00:00,  3.79it/s, dice_loss - 0.01452, iou_score - 0.9716]
# valid: 100%|██████████| 588/588 [00:21<00:00, 26.86it/s, dice_loss - 0.0331, iou_score - 0.9387]
# CPU times: user 30min 10s, sys: 1min 51s, total: 32min 1s
# Wall time: 54min 41s

# %% [markdown]
# # **Testing Model**

# %%
# load best saved model checkpoint from the current run
if os.path.exists(m_path):
    best_model = torch.load(m_path, map_location=DEVICE)
    print('Loaded UNet model from this run.')

# load best saved model checkpoint from previous commit (if present)
elif os.path.exists(m_path):
    best_model = torch.load(m_path, map_location=DEVICE)
    print('Loaded UNet model from a previous commit.')
# Out:
# <ipython-input-26-930c4b47167f>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model = torch.load(m_path, map_location=DEVICE)
# Loaded UNet model from this run.

# %%
test_dataset = PlantDiseaseDataset(
    test_images,
    test_masks,
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn=None),
    class_rgb_values=select_class_rgb_values,
)

# %%
test_dataloader = DataLoader(test_dataset)

test_dataset_vis = PlantDiseaseDataset(
    test_images, test_masks,
    augmentation=get_validation_augmentation(),
    class_rgb_values=select_class_rgb_values,
)

# get a random test image/mask index
random_idx = random.randint(0, len(test_dataset_vis)-1)
image, mask = test_dataset_vis[random_idx]
ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values)
visualize(
    original_image = image,
    ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
    one_hot_encoded_mask = reverse_one_hot(mask),
    overlay_ground_truth=overlay_ground_truth(image,ground_truth_mask)

)

# %%
# Define the directory path where sample predictions will be stored
sample_preds_folder = 'sample_predictionss/'

# Check if the directory already exists, if not, create it
if not os.path.exists(sample_preds_folder):
    # Create the directory to store predictions if it does not exist
    os.makedirs(sample_preds_folder)

# %%
sample_preds_folder = 'sample_predictionss/'
if not os.path.exists(sample_preds_folder):
    os.makedirs(sample_preds_folder)

# %%
len(test_dataset)
# Out:
# 235

# %% [markdown]
# **show some output samples on test dataset**

# %%
# Loop through the first 10 images in the test dataset
for idx in range(10):
    # Get the image and ground truth mask from the dataset
    image, gt_mask = test_dataset[idx]

    # Crop the image for visualization
    image_vis = crop_image(test_dataset_vis[idx][0].astype('uint8'))

    # Convert the image to a tensor and move it to the specified device (GPU or CPU)
    x_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)

    # Get the predicted mask from the model
    pred_mask = best_model(x_tensor)

    # Detach the prediction from the computation graph, squeeze it to remove extra dimensions, and convert to a numpy array
    pred_mask = pred_mask.detach().squeeze().cpu().numpy()

    # Reorder the dimensions of the predicted mask for proper visualization
    pred_mask = np.transpose(pred_mask, (1, 2, 0))

    # Extract the 'affected' class heatmap from the prediction
    pred_building_heatmap = pred_mask[:, :, select_classes.index('affected')]

    # Perform color coding and reverse one-hot encoding on the predicted mask
    pred_mask = crop_image(colour_code_segmentation(reverse_one_hot(pred_mask), select_class_rgb_values))

    # Reorder and crop the ground truth mask for visualization
    gt_mask = np.transpose(gt_mask, (1, 2, 0))
    gt_mask = crop_image(colour_code_segmentation(reverse_one_hot(gt_mask), select_class_rgb_values))

    # Resize the ground truth and predicted masks to match the image size
    gt_mask = cv2.resize(gt_mask[:, :, :3], (image_vis.shape[1], image_vis.shape[0])).astype('uint8')
    pred_mask = cv2.resize(pred_mask[:, :, :3], (image_vis.shape[1], image_vis.shape[0])).astype('uint8')

    # Combine the original image, ground truth mask, and predicted mask horizontally
    combined_image = np.hstack([image_vis, gt_mask, pred_mask])[:, :, ::-1]

    # Save the combined image to the specified folder
    cv2.imwrite(os.path.join(sample_preds_folder, f"sample_pred_{idx}.png"), combined_image)

    # Visualize the original image, ground truth, and predicted masks
    visualize(
        original_image=image_vis,
        ground_truth_mask=gt_mask,
        predicted_mask=pred_mask,
    )

# %% [markdown]
# **output mtrics on test data**

# %%
# Initialize the validation epoch for evaluating the model's performance on the test data
test_epoch = smp.utils.train.ValidEpoch(
    model,
    loss=loss,
    metrics=metrics,
    device=DEVICE,
    verbose=True,

# Run the validation on the test dataset and store the results
valid_logs = test_epoch.run(test_dataloader)

# Output the evaluation results (mean IoU and Dice score) to the console
print("Evaluation on Test Data: ")
print(f"Mean IoU Score: {valid_logs['iou_score']:.4f}")
print(f"Mean Dice Loss: {valid_logs['dice_loss']:.4f}")

# %%
import pandas as pd

train_logs_df = pd.DataFrame(train_logs_list)
valid_logs_df = pd.DataFrame(valid_logs_list)
train_logs_df.T
# Out:
#                  0         1         2         3         4         5   \
# dice_loss  0.236859  0.111639  0.077002  0.064168  0.055616  0.049416
# iou_score  0.792437  0.870272  0.891184  0.898905  0.907349  0.914929
#
#                  6        7         8         9   ...        25        26  \
# dice_loss  0.044987  0.04341  0.035229  0.032001  ...  0.018865  0.018122
# iou_score  0.920513  0.92174  0.935746  0.941043  ...  0.963438  0.964833
#
#                  27        28        29        30        31        32  \
# dice_loss  0.017322  0.016707  0.016295  0.015836  0.015602  0.015247
# iou_score  0.966336  0.967513  0.968278  0.969165  0.969601  0.970254
#
#                  33        34
# dice_loss  0.014814  0.014518
# iou_score  0.971085  0.971646
#
# [2 rows x 35 columns]

# %% [markdown]
# **iou score for train and validation over epochs**

# %%
plt.figure(figsize=(20,8))
plt.plot(train_logs_df.index.tolist(), train_logs_df.iou_score.tolist(), lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.iou_score.tolist(), lw=3, label = 'Valid')
plt.xlabel('Epochs', fontsize=21)
plt.ylabel('IoU Score', fontsize=21)
plt.title('IoU Score Plot', fontsize=21)
plt.legend(loc='best', fontsize=16)
plt.grid()
plt.savefig('iou_score_plot.png')
plt.show()

# %% [markdown]
# **Dice loss for train and validation over epochs**

# %%
plt.figure(figsize=(20,8))
plt.plot(train_logs_df.index.tolist(), train_logs_df.dice_loss.tolist(), lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.dice_loss.tolist(), lw=3, label = 'Valid')
plt.xlabel('Epochs', fontsize=21)
plt.ylabel('Dice Loss', fontsize=21)
plt.title('Dice Loss Plot', fontsize=21)
plt.legend(loc='best', fontsize=16)
plt.grid()
plt.savefig('dice_loss_plot.png')
plt.show()
